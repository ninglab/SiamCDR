# %% [markdown]
# # Import

# %%
import os, joblib
import numpy as np
import pandas as pd

from itertools import product

import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Helvetica'

import seaborn as sns

from tensorflow.keras.models import load_model, Model
from tensorflow.keras.layers import Input, Concatenate

from scipy.stats import ttest_ind as ttest

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Define funcs

# %%
def loadEncoder(path, which='rna'):
    try:
        snn = load_model(path)
        encoder = snn.get_layer('model')
        encoder._name = f'{which}Encoder'
        return encoder
    except AttributeError:
        return None
    
def getModel(rnaPath=None, drugPath=None, rnaDim=463, drugDim=256):
        # Define encoded drug input
        drugInput = Input(drugDim)
        rnaInput = Input(rnaDim)
                                             
        if drugPath == None:
            if rnaPath == None:         
                pairEmbed = Concatenate()([drugInput, rnaInput])
            else: 
                rnaEmbed = loadEncoder(rnaPath)(rnaInput)
                pairEmbed = Concatenate()([drugInput, rnaEmbed])
        else:
            drugEmbed = loadEncoder(drugPath, which='drug')(drugInput)
            if rnaPath == None:         
                pairEmbed = Concatenate()([drugEmbed, rnaInput])
            else: 
                rnaEmbed = loadEncoder(rnaPath)(rnaInput)
                pairEmbed = Concatenate()([drugEmbed, rnaEmbed])

        return Model(inputs=[drugInput, rnaInput], outputs=pairEmbed)

# %% [markdown]
# ## Define paths

# %% [markdown]
# ## Cell line encoder

# %%
rnaPath = '/fs/scratch/PCON0041/PatrickLawrence/cancer-drug-response/fewShot/cellLines/siameseV1/models/'

rnaRFModel = 'CellLineFewShot_Layers2_Hidden64_DO0-1_AFrelu_LR0-001_DR0-99_DS1000'
rnaRFPath = os.path.join(rnaPath, rnaRFModel)

rnaLMModel = 'CellLineFewShot_Layers2_Hidden64_DO0-1_AFsigmoid_LR0-001_DR0-99_DS1000'
rnaLMPath = os.path.join(rnaPath, rnaLMModel)

# %% [markdown]
# ## Drug encoder

# %%
# drugPath = '../../models/drugEncoders/'
drugPath = '/fs/scratch/PCON0041/PatrickLawrence/cancer-drug-response/fewShot/drugs/siameseV1/models/'
drugModel = 'DrugFewShot_Layers1_Hidden64_DO0-1_AFrelu_LR0-001_DR0-99_DS1000'
drugPath = os.path.join(drugPath, drugModel)

# %% [markdown]
# # Load Data

# %% [markdown]
# ## RNA

# %%
testRNA = pd.read_csv('../../data/processed/RNA_test_cancergenes.csv', index_col=0)
newRNA = pd.read_csv('../../data/processed/RNA_newcancer_cancergenes.csv', index_col=0)
preRNA = pd.read_csv('../../data/processed/cellLineEncoderPretrainData.csv', index_col=0)
RNA = pd.concat([testRNA, preRNA, newRNA])
RNA.head()
# Out:
#                  XIAP     CDKN2B      ITGB1      TRAF1      GSTM4       LRP5  \
# ACH-000961  13.154465   8.849100  15.549766   6.920184  12.072700  14.011049
# ACH-000984  12.658436  11.099468  16.368337  10.291742  16.100270  13.418132
# ACH-000978  12.391499   9.313873  14.526513   8.183218  10.895111  12.847516
# ACH-000222  14.216933  13.075022  16.941942   9.317074   9.706432  14.477196
# ACH-000164  13.991268   2.579163  17.134937   9.554390  11.698739  14.880114
#
#                  IL3       HEYL     CXCL12        FN1  ...      CALM1  \
# ACH-000961  0.130963  10.485365   7.216564  15.074025  ...  14.184124
# ACH-000984  0.130963   1.764265   6.714064  13.988510  ...  12.864645
# ACH-000978  0.130963  11.515809  10.011866  12.451502  ...  13.081577
# ACH-000222  0.130963   1.764265   4.714064  10.887437  ...  12.979026
# ACH-000164  0.130963   8.914012   6.588533  11.203131  ...  12.769463
#
#                 MGST3       ARAF      NFKB1     ZBTB17     FGF23       FZD5  \
# ACH-000961  11.098191  11.818052  11.481821  10.725326  0.569748  12.588184
# ACH-000984  12.050875  11.611258  12.007825  10.958988  1.569748   9.581694
# ACH-000978  12.571796  10.471045  10.505967  10.594366  3.377103  10.755789
# ACH-000222  12.599238  10.817039  11.842455   8.791468  1.569748  11.702942
# ACH-000164  11.896701  12.273183  12.263763  10.776197  0.569748   9.966419
#
#                  RAC3      GSTA1      LAMB2
# ACH-000961  10.000158   6.114922  15.500269
# ACH-000984   6.629056   4.529960  13.717964
# ACH-000978   8.836714  16.416312  15.371843
# ACH-000222   6.244975   2.944997  14.530380
# ACH-000164   9.899531   2.944997  13.806081
#
# [5 rows x 463 columns]

# %%
RNA.shape
# Out:
# (983, 463)

# %% [markdown]
# ## Drugs

# %%
drugInfo = pd.read_csv('../../data/processed/drugCellLinePairsData.csv')
drugInfo = drugInfo.loc[:, ['name', 'indication']].drop_duplicates(keep='first')
drugInfo = drugInfo[~drugInfo.indication.isna()].set_index('name')
print(drugInfo.shape)
# Out:
# (369, 1)

# %%
drugInfo
# Out:
#                                                            indication
# name
# floxuridine                                         colorectal cancer
# valrubicin                                             bladder cancer
# belinostat                          peripheral T-cell lymphoma (PTCL)
# romidepsin                           cutaneous T-cell lymphoma (CTCL)
# dihydroartemisinin                                            malaria
# ...                                                               ...
# tofogliflozin                    diabetes mellitus, diabetes mellitus
# vindesine           breast cancer, non-small cell lung cancer (NSC...
# vinblastine         Hodgkin's lymphoma, true histiocytic lymphoma ...
# vinflunine                                             bladder cancer
# ibrutinib           chronic lymphocytic leukemia (CLL), mantle cel...
#
# [369 rows x 1 columns]

# %%
drugs = pd.read_csv('../../data/processed/drug_fingerprints.csv', index_col=0)
drugs = drugs[drugs.index.isin(list(drugInfo.index))]
print(drugs.shape)
# Out:
# (369, 256)

# %% [markdown]
# ## Pairs

# %%
pairs = [*product(RNA.index.values, drugs.index.values)]

# %%
pairDF = pd.DataFrame({'cellLine': [p[0] for p in pairs],
                       'drug': [p[1] for p in pairs]})
pairDF.sort_values(by=['cellLine', 'drug'], inplace=True)
print(pairDF.shape)
pairDF.head()
# Out:
# (362727, 2)
#           cellLine            drug
# 183943  ACH-000001  5-fluorouracil
# 183990  ACH-000001           SN-38
# 184034  ACH-000001     abemaciclib
# 183828  ACH-000001  acetophenazine
# 184106  ACH-000001        acipimox

# %% [markdown]
# ## Add cancer type

# %%
cellInfo = pd.read_csv('../../data/processed/cellLineInfo.csv', index_col=0)
cellInfo = cellInfo.loc[list(pairDF.cellLine.unique()), ['primary_disease']]
cellInfo.rename(columns={'primary_disease': 'cancerType'}, inplace=True)
cellInfo
# Out:
#                          cancerType
# DepMap_ID
# ACH-000001           Ovarian Cancer
# ACH-000002                 Leukemia
# ACH-000003  Colon/Colorectal Cancer
# ACH-000004                 Leukemia
# ACH-000005                 Leukemia
# ...                             ...
# ACH-002680             Brain Cancer
# ACH-002687               Eye Cancer
# ACH-002693                  Sarcoma
# ACH-002710                  Sarcoma
# ACH-002834              Bone Cancer
#
# [983 rows x 1 columns]

# %%
getCT = lambda x: cellInfo.loc[x, 'cancerType']
pairDF.insert(1, 'cancerType', pairDF.cellLine.apply(getCT))

# %% [markdown]
# ## Add drug indication

# %%
getIndication = lambda x: drugInfo.loc[x, 'indication'].lower()
pairDF['drugIndication'] = pairDF.drug.apply(getIndication)

# %% [markdown]
# ## Data

# %%
data = [drugs.loc[list(pairDF.drug.values), :].to_numpy(), 
        RNA.loc[list(pairDF.cellLine.values), :].to_numpy()]

# %% [markdown]
# # Process data

# %%
models = {}

# %% [markdown]
# ## RF

# %%
models['rf'] = joblib.load(f'../../models/fsCDR/RF/EmbedDrug-EmbedCell-Concat-RF-CVfold1.joblib')

# %% [markdown]
# ## DeepDSC

# %%
models['dsc'] = load_model(f'../../models/baselines/DeepDSC/DeepDSC_fold2')
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# # Get test preds

# %% [markdown]
# we want it to be sorted by cell line then drug going in so that we can re-sort after finding rank

# %%
predDFs = {}
for name, model in models.items():
    if name in ['rf']:
        if name == 'rf':
            cp = rnaRFPath
            dp = drugPath
            
        encoder = getModel(cp, dp)
        preds = [p[1] for p in model.predict_proba(encoder(data))]    
        
    else:
        if name == 'dsc':
            td = [data[1], data[0]]
        preds = model.predict(td).reshape(-1)
        
    pairDF[f'{name}Pred'] = preds
    pairDF[f'{name}CellRank'] = [0 for i in range(len(pairDF))]
    for cellLine, sub in pairDF.groupby(by='cellLine'):
        indicies = list(sub.index)
        sub.sort_values(by=f'{name}Pred', ascending=False, inplace=True)
        sub[f'{name}CellRank'] = [i+1 for i in range(len(sub))]
        
        sub.sort_values(by=['cellLine', 'drug'], inplace=True)
        pairDF.loc[indicies, f'{name}CellRank'] = sub[f'{name}CellRank'].values

# %%
pairDF.head()
# Out:
#           cellLine      cancerType            drug  \
# 183943  ACH-000001  Ovarian Cancer  5-fluorouracil
# 183990  ACH-000001  Ovarian Cancer           SN-38
# 184034  ACH-000001  Ovarian Cancer     abemaciclib
# 183828  ACH-000001  Ovarian Cancer  acetophenazine
# 184106  ACH-000001  Ovarian Cancer        acipimox
#
#                                            drugIndication    rfPred  \
# 183943  colorectal cancer, breast cancer, pancreatic c...  0.001863
# 183990                                  colorectal cancer  0.395247
# 184034                                      breast cancer  0.003214
# 183828                                          psychosis  0.041572
# 184106                                     hyperlipidemia  0.016433
#
#         rfCellRank   dscPred  dscCellRank
# 183943         305  0.106888          252
# 183990           8  0.151473           18
# 184034         288  0.117888          140
# 183828          63  0.118217          135
# 184106         148  0.093828          365

# %% [markdown]
# # Define valid indications for cancer types

# %%
indications = []
for d in drugInfo.index:
    indication = getIndication(d).lower().split(", ")
    indications.extend(indication)

indications = set(indications)
print(len(indications))
# Out:
# 295

# %%
indications
# Out:
# {'abdominal pain',
#  'abstinence from alcohol',
#  'acne vulgaris (av)',
#  'acquired immunodeficiency syndrome (aids)',
#  'actinic keratosis (ak)',
#  'acute abdominal visceral spasm',
#  'acute lymphoblastic leukemia (all)',
#  'acute myeloid leukemia (aml)',
#  'acute promyelocytic leukemia (apl)',
#  'aggressive systemic mastocytosis (asm)',
#  'allergic rhinitis',
#  'amyotrophic lateral sclerosis (als)',
#  'anacidity diagnostic',
#  'anaphylactic shock',
#  'anemia',
#  'anesthetic',
#  'angina pectoris',
#  'angioedema',
#  'ankylosing spondylitis',
#  'anxiety',
#  'arteriosclerosis',
#  'ascariasis',
#  'asthma',
#  'atrial fibrillation (af)',
#  'backache',
#  'bacterial septicemia',
#  'bacterial vaginosis',
#  'basal cell carcinoma (bcc)',
#  'bile stimulation',
#  'bipolar disorder',
#  'blackhead disease',
#  'bladder cancer',
#  'bovine respiratory disease (brd)',
#  'breast cancer',
#  'bronchitis',
#  'bronchogenic carcinoma',
#  'bronchospasm',
#  'brucellosis',
#  "buerger's disease",
#  "burkitt's lymphoma",
#  'bursitis',
#  'cardiac arrest',
#  'cardiac arrythmia',
#  'cardiomyopathy',
#  'cervical cancer',
#  'chancroid',
#  'chapped lips',
#  'chest congestion',
#  'cholera',
#  'chronic eosinophilic leukemia (cel)',
#  'chronic kidney disease (ckd)',
#  'chronic lymphocytic leukemia (cll)',
#  'chronic myeloid leukemia (cml)',
#  'chronic myelomonocytic leukemia (cmmol)',
#  'chronic obstructive pulmonary disease (copd)',
#  'coccidiosis',
#  'colitis',
#  'colorectal cancer',
#  'common cold',
#  'congenital heart defects',
#  'congestive heart failure',
#  'conjunctivitis',
#  'constipation',
#  'contact dermatitis',
#  'contraceptive',
#  'contrast agent',
#  'coronary artery disease (cad)',
#  'coronary heart disease',
#  'corticosteroid-responsive dermatoses',
#  'cosmetic',
#  "crohn's disease",
#  'cutaneous t-cell lymphoma (ctcl)',
#  'cyclitis',
#  'cystic fibrosis',
#  'cystic hydatid disease',
#  'cystinuria',
#  'cytomegalovirus retinitis',
#  'dandruff',
#  'depression',
#  'dermatofibrosarcoma protuberans (dfsp)',
#  'dermatographism',
#  'diabetes mellitus',
#  'diagnostic agent',
#  'diarrhea',
#  'duodenal ulcer disease',
#  'dysentry',
#  'dyskinesia',
#  'edema',
#  'emphysema',
#  'endogenous uveitis',
#  'endometriosis',
#  'enteritis',
#  'enterocolitis',
#  'equine protozoal myeloencephalitis (epm)',
#  'eye inflammation',
#  'fescue toxicosis',
#  'fever',
#  'first-aid antiseptic',
#  'flea control',
#  'fungal infection',
#  'gastric adenocarcinoma',
#  'gastric hypersecretion diagnostic',
#  'gastroesophageal reflux disease (gerd)',
#  'gastrointestinal parasites',
#  'gastrointestinal roundworms',
#  'gastrointestinal stromal tumors (gist)',
#  'general anaesthetic',
#  'genital warts',
#  'gestational choriocarcinoma',
#  'giardiasis',
#  'gingivitis',
#  'glaucoma',
#  'gonorrhea',
#  'gout',
#  'gram-negative bacterial infections',
#  'gram-positive bacterial infections',
#  'gynecologic infections',
#  'hairy cell leukemia',
#  'head and neck squamous cell carcinoma (hnscc)',
#  'headache',
#  'heart attack',
#  'heartburn',
#  'hemorrhagic cystitis',
#  'hepatic cirrhosis',
#  'hepatitis b',
#  'hepatitis c',
#  'hepatocellular carcinoma (hcc)',
#  'hip dysplasia',
#  "hodgkin's lymphoma",
#  'hookworm',
#  'human immunodeficiency virus (hiv-1)',
#  'hydatidiform mole',
#  'hyperaldosteronism',
#  'hypercalcemia',
#  'hypercholesterolemia',
#  'hypereosinophilic syndrome (hes)',
#  'hyperglycemia',
#  'hyperlipidemia',
#  'hyperparathyroidism',
#  'hypertension',
#  'hyperthyroidism',
#  'hypertriglyceridemia',
#  'hypocalcemia',
#  'hypokalemia',
#  'hyponatremia',
#  'hypoparathyroidism',
#  'hypotension',
#  'ichthyosis vulgaris',
#  'infertility',
#  'inflammatory bowel disease',
#  'insomnia',
#  'interstitial cystitis (ic)',
#  'intra-abdominal infections',
#  'intraocular pressure',
#  'iritis',
#  'iron overload',
#  'irritability',
#  'irritable bowel syndrome',
#  'joint inflammation',
#  'joint pain',
#  'kaposi sarcoma',
#  'leishmaniasis',
#  'leprosy',
#  'lungworms',
#  'lymphangioleiomyomatosis',
#  'malaria',
#  'mantle cell lymphoma (mcl)',
#  'mastitis',
#  'medullary thyroid cancer (mtc)',
#  'melanoma',
#  'meningitis',
#  'menopause',
#  'mesothelioma',
#  'migraine headache',
#  'motion sickness',
#  'mouth inflammation',
#  'multiple myeloma',
#  'multiple sclerosis',
#  'muscle pain',
#  'mycosis',
#  'myelodysplastic diseases (mds)',
#  'myelofibrosis',
#  'myeloproliferative neoplasms',
#  'myocardial infarction',
#  'nasal congestion',
#  'nausea',
#  'navicular syndrome',
#  'nephrotic syndrome',
#  'neuroblastoma',
#  'neuroendocrine tumors of pancreatic origin (pnet)',
#  'non-hodgkin lymphoma (nhl)',
#  'non-small cell lung cancer (nsclc)',
#  'ocular hypertension',
#  'onychomycosis',
#  'organ rejection',
#  'osteoarthritis',
#  'osteoporosis',
#  'ovarian cancer',
#  'pain relief',
#  'pancreatic cancer',
#  'panic disorders',
#  'parathyroid carcinoma',
#  'parenchymal neurocysticercosis',
#  "parkinson's disease",
#  'pelvic inflammatory disease',
#  'peptic ulcer disease (pud)',
#  'periodontitis',
#  'peripheral t-cell lymphoma (ptcl)',
#  'pharyngitis',
#  'pinworm',
#  'pneumonia',
#  'polycythemia vera',
#  'primary peritoneal cancer (ppc)',
#  'prostate cancer',
#  'prostatitis',
#  'protozoan infection',
#  'psittacosis',
#  'psoriasis',
#  'psoriatic arthritis',
#  'psychosis',
#  'pulmonary arterial hypertension (pah)',
#  'pulmonary embolism (pe)',
#  'punctate keratitis',
#  "raynaud's disease",
#  'renal angiomyolipoma',
#  'renal cell carcinoma (rcc)',
#  'renal homotransplantation',
#  'respiratory depression',
#  'respiratory tract infections',
#  'retinoblastoma',
#  'reverse sedative',
#  'rheumatoid arthritis',
#  'rosacea',
#  'schizophrenia',
#  'scleroderma',
#  'seasonal affective disorder',
#  'seborrheic dermatitis',
#  'seizures',
#  'senile dementia',
#  'shingles',
#  'skin depigmentation',
#  'skin infections',
#  'skin protectant',
#  'small cell lung cancer',
#  'small lymphocytic lymphoma (sll)',
#  'soft tissue sarcoma (sts)',
#  'spinocerebellar ataxia',
#  'status epilepticus',
#  'stroke',
#  'strongyles',
#  'subependymal giant cell astrocytoma (sega)',
#  'sunscreen lotion',
#  'tapeworm',
#  'testicular carcinoma',
#  'thalassemia',
#  'throat inflammation',
#  'thrombocythemia',
#  'thrombocytopenia',
#  'thyroid cancer',
#  'thyroiditis',
#  'tinea corporis',
#  'tinea cruris',
#  'tinea pedis',
#  'tonsillitis',
#  'toothache',
#  'trachoma',
#  'transfusional hemosiderosis',
#  'tremors',
#  'true histiocytic lymphoma (thl)',
#  'tuberculosis',
#  'tuberous sclerosis complex (tsc)',
#  'tularemia',
#  'ulcerative colitis',
#  'urethritis',
#  'urinary incontinence',
#  'urinary tract infections',
#  'urticaria',
#  'vaginal atrophy',
#  'varicella-zoster virus (vzv)',
#  'varicose veins',
#  'vascular spasm',
#  'vasomotor rhinitis',
#  'ventricular arrhythmias',
#  'ventricular tachycardia (vt)',
#  'virus herpes simplex (hsv)',
#  'vitamin d deficiency',
#  'vomiting',
#  'vulvovaginal candidiasis',
#  "waldenstrom's macroglobulinemia (wm)",
#  'whipworm',
#  "wilm's tumor",
#  "wilson's disease",
#  'wolff-parkinson-white syndrome (wpw)',
#  'xerosis cutis',
#  'zollinger-ellison syndrome'}

# %%
cTypeInd = {}
cTypeInd['Ovarian Cancer'] = ['ovarian cancer']

cTypeInd['Leukemia'] = ['leukemia', 'acute myeloid leukemia (aml)', 
                        'chronic eosinophilic leukemia (cel)',
                        'acute lymphoblastic leukemia (all)',
                        'chronic myelomonocytic leukemia (cmmol)',
                        'chronic lymphocytic leukemia (cll)',
                        'chronic myeloid leukemia (cml)',
                        'hairy cell leukemia',
                        'acute promyelocytic leukemia (apl)']

cTypeInd['Colon/Colorectal Cancer'] = ['colorectal cancer']

cTypeInd['Lung Cancer'] = ['small cell lung cancer', 
                           'mantle cell lymphoma (mcl)',
                           'non-small cell lung cancer (nsclc)']

cTypeInd['Kidney Cancer'] = ["wilm's tumor",
                             'renal cell carcinoma (rcc)']

cTypeInd['Breast Cancer'] = ['breast cancer']

cTypeInd['Myeloma'] = ['myeloma', 'multiple myeloma']

cTypeInd['Pancreatic Cancer'] = ['neuroendocrine tumors of pancreatic origin (pnet)',
                                 'pancreatic cancer']

cTypeInd['Lymphoma'] = ["burkitt's lymphoma", 
                        'small lymphocytic lymphoma (sll)',
                        "hodgkin's lymphoma",
                        'true histiocytic lymphoma (thl)',
                        'cutaneous t-cell lymphoma (ctcl)',
                        'non-hodgkin lymphoma (nhl)',
                        'peripheral t-cell lymphoma (ptcl)']

cTypeInd['Sarcoma'] = ['soft tissue sarcoma (sts)', 'kaposi sarcoma']

cTypeInd['Thyroid Cancer'] = ['thyroid cancer',
                              'parathyroid carcinoma',
                              'medullary thyroid cancer (mtc)']

cTypeInd['Neuroblastoma'] = ['neuroblastoma']

cTypeInd['Gastric Cancer'] = ['gastric adenocarcinoma']

cTypeInd['Prostate Cancer'] = ['prostate cancer']

cTypeInd['Bladder Cancer'] = ['bladder cancer']

cTypeInd['Endometrial/Uterine Cancer'] = ['gestational choriocarcinoma',
                                          'endometrial', 'uterine', 'uterus']

cTypeInd['Head and Neck Cancer'] = ['head and neck squamous cell carcinoma (hnscc)']

cTypeInd['Skin Cancer'] = ['melanoma']

cTypeInd['Liver Cancer'] = ['hepatocellular carcinoma (hcc)']

cTypeInd['Cervical Cancer'] = ['cervical cancer']

# %%
def checkIndication(x, y):
    overlap = set(y).intersection(set(x.lower().split(', ')))
    if len(overlap) >= 1:
        return True
    else:
        return False

# %% [markdown]
# # Get approved drug for each cancer

# %%
for ct, subdf in pairDF.groupby(by='cancerType'):
    if ct not in list(cTypeInd.keys()):
        continue
    print("\n" + ct + ":")
    check = lambda x: checkIndication(x, cTypeInd[ct])
    for i in subdf[subdf.drugIndication.apply(check)].drug.unique():
        print(i)
# Out:
# Bladder Cancer:
# doxorubicin
# valrubicin
# vinflunine
#
# Breast Cancer:
# 5-fluorouracil
# abemaciclib
# carmofur
# cyclophosphamide
# docetaxel
# doxorubicin
# epirubicin
# everolimus
# formestane
# gemcitabine
# ixabepilone
# lapatinib
# paclitaxel
# palbociclib
# ribociclib
# toremifene
# vindesine
#
# Cervical Cancer:
# topotecan
#
# Colon/Colorectal Cancer:
# 5-fluorouracil
# SN-38
# carmofur
# doxifluridine
# floxuridine
# irinotecan
# oxaliplatin
# regorafenib
# tipiracil
#
# Endometrial/Uterine Cancer:
# methotrexate
#
# Gastric Cancer:
# 5-fluorouracil
# docetaxel
# mitomycin-c
#
# Head and Neck Cancer:
# docetaxel
# hydroxyurea
#
# Kidney Cancer:
# axitinib
# doxorubicin
# everolimus
# pazopanib
# sorafenib
# sunitinib
# temsirolimus
#
# Leukemia:
# amsacrine
# azacitidine
# bendamustine
# bosutinib
# busulfan
# chlorambucil
# cladribine
# clofarabine
# cyclophosphamide
# dasatinib
# daunorubicin
# decitabine
# doxorubicin
# fludarabine
# fludarabine-phosphate
# homoharringtonine
# hydroxyurea
# ibrutinib
# idarubicin
# imatinib
# mechlorethamine
# mercaptopurine
# methotrexate
# midostaurin
# mitoxantrone
# nilotinib
# ponatinib
# tamibarotene
# teniposide
# thioguanine
# ubenimex
# venetoclax
# vincristine
#
# Liver Cancer:
# sorafenib
#
# Lung Cancer:
# afatinib
# alectinib
# bortezomib
# brigatinib
# crizotinib
# docetaxel
# erlotinib
# etoposide
# etoposide-phosphate
# gefitinib
# gemcitabine
# ibrutinib
# icotinib
# lenalidomide
# osimertinib
# paclitaxel
# topotecan
# vindesine
# vinorelbine
#
# Lymphoma:
# belinostat
# bendamustine
# bexarotene
# chlorambucil
# cyclophosphamide
# dacarbazine
# doxorubicin
# mechlorethamine
# pralatrexate
# romidepsin
# vinblastine
# vorinostat
#
# Myeloma:
# bortezomib
# carfilzomib
# cyclophosphamide
# doxorubicin
# ixazomib
# ixazomib-citrate
# lenalidomide
# melphalan
# panobinostat
#
# Neuroblastoma:
# cyclophosphamide
#
# Ovarian Cancer:
# altretamine
# carboplatin
# cyclophosphamide
# doxorubicin
# gemcitabine
# olaparib
# paclitaxel
#
# Pancreatic Cancer:
# 5-fluorouracil
# erlotinib
# everolimus
# gemcitabine
# mitomycin-c
# streptozotocin
# sunitinib
#
# Prostate Cancer:
# cabazitaxel
# cyproterone-acetate
# docetaxel
# estramustine
# mitoxantrone
#
# Sarcoma:
# pazopanib
# vinblastine
#
# Skin Cancer:
# cobimetinib
# dabrafenib
# dacarbazine
# trametinib
# vemurafenib
# vindesine
#
# Thyroid Cancer:
# cabozantinib
# cinacalcet
# lenvatinib
# sorafenib
# vandetanib

# %% [markdown]
# ## Look at gastric cancer for FS-CDR (RF) for repurposing

# %%
gastric = pairDF[pairDF.cancerType == 'Gastric Cancer']
gastric.shape
# Out:
# (14391, 8)

# %%
gastric.head()
# Out:
#           cellLine      cancerType            drug  \
# 229330  ACH-000110  Gastric Cancer  5-fluorouracil
# 229377  ACH-000110  Gastric Cancer           SN-38
# 229421  ACH-000110  Gastric Cancer     abemaciclib
# 229215  ACH-000110  Gastric Cancer  acetophenazine
# 229493  ACH-000110  Gastric Cancer        acipimox
#
#                                            drugIndication    rfPred  \
# 229330  colorectal cancer, breast cancer, pancreatic c...  0.005435
# 229377                                  colorectal cancer  0.348161
# 229421                                      breast cancer  0.007412
# 229215                                          psychosis  0.041489
# 229493                                     hyperlipidemia  0.017761
#
#         rfCellRank   dscPred  dscCellRank
# 229330         284  0.082454          251
# 229377          12  0.117813           18
# 229421         252  0.091294          135
# 229215          79  0.091557          131
# 229493         166  0.071672          367

# %%
check = lambda x: checkIndication(x, cTypeInd['Gastric Cancer'])
gastric[gastric.drugIndication.apply(check)].groupby('drug').rfCellRank.mean()
# Out:
# drug
# 5-fluorouracil    278.410256
# docetaxel          25.538462
# mitomycin-c       173.358974
# Name: rfCellRank, dtype: float64

# %%
gastric[gastric.drugIndication.apply(check)].groupby('drug').dscCellRank.mean()
# Out:
# drug
# 5-fluorouracil    251.794872
# docetaxel           2.128205
# mitomycin-c       180.512821
# Name: dscCellRank, dtype: float64

# %%
cdr = pd.read_csv('../../data/processed/drugCellLinePairsData.csv')
cdr = cdr[cdr.DepMap_ID.isin(list(RNA.index))]
cdr.head()
# Out:
#      DepMap_ID           cancer_type         name                      moa  \
# 0   ACH-000320     Pancreatic Cancer  floxuridine  DNA synthesis inhibitor
# 9   ACH-000846  Head and Neck Cancer  floxuridine  DNA synthesis inhibitor
# 10  ACH-000804         Neuroblastoma  floxuridine  DNA synthesis inhibitor
# 16  ACH-000305     Esophageal Cancer  floxuridine  DNA synthesis inhibitor
# 18  ACH-000046         Kidney Cancer  floxuridine  DNA synthesis inhibitor
#
#    target         indication     phase        r2      ic50       auc  \
# 0    TYMS  colorectal cancer  Launched  0.972544  0.007879  0.336463
# 9    TYMS  colorectal cancer  Launched  0.883318  0.052711  0.492464
# 10   TYMS  colorectal cancer  Launched  0.972829  0.025269  0.421177
# 16   TYMS  colorectal cancer  Launched  0.786261  0.190516  0.693634
# 18   TYMS  colorectal cancer  Launched  0.797691  0.037893  0.441029
#
#     lower_limit  effectiveCont  effective
# 0      0.105140       6.692422          0
# 9      0.101684       4.808385          0
# 10     0.073301       5.808496          0
# 16     0.333560       2.625589          0
# 18     0.032024       6.168264          0

# %%
cdr[cdr.name == '5-fluorouracil']
# Out:
#         DepMap_ID           cancer_type            name  \
# 26816  ACH-000174        Thyroid Cancer  5-fluorouracil
# 26817  ACH-000836  Head and Neck Cancer  5-fluorouracil
# 26820  ACH-000510           Lung Cancer  5-fluorouracil
#
#                                   moa      target  \
# 26816  thymidylate synthase inhibitor  DPYD, TYMS
# 26817  thymidylate synthase inhibitor  DPYD, TYMS
# 26820  thymidylate synthase inhibitor  DPYD, TYMS
#
#                                               indication     phase        r2  \
# 26816  colorectal cancer, breast cancer, pancreatic c...  Launched  0.762251
# 26817  colorectal cancer, breast cancer, pancreatic c...  Launched  0.803679
# 26820  colorectal cancer, breast cancer, pancreatic c...  Launched  0.779528
#
#            ic50       auc  lower_limit  effectiveCont  effective
# 26816  1.703437  0.871191     0.352683       1.028369          0
# 26817  1.385561  0.861655     0.355879       1.119514          0
# 26820  2.316117  0.885603     0.351690       0.901359          0

# %%
cdr[(cdr.cancer_type == 'Gastric Cancer') & (cdr.name.isin(['5-fluorouracil', 'docetaxel', 'mitomycin-c']))]
# Out:
#         DepMap_ID     cancer_type         name  \
# 4783   ACH-000736  Gastric Cancer    docetaxel
# 4802   ACH-000948  Gastric Cancer    docetaxel
# 4819   ACH-000919  Gastric Cancer    docetaxel
# 4838   ACH-000880  Gastric Cancer    docetaxel
# 4839   ACH-000847  Gastric Cancer    docetaxel
# 4872   ACH-000351  Gastric Cancer    docetaxel
# 4885   ACH-000255  Gastric Cancer    docetaxel
# 4897   ACH-000678  Gastric Cancer    docetaxel
# 4934   ACH-000344  Gastric Cancer    docetaxel
# 27805  ACH-000948  Gastric Cancer  mitomycin-c
# 27809  ACH-000911  Gastric Cancer  mitomycin-c
# 27817  ACH-000919  Gastric Cancer  mitomycin-c
# 27829  ACH-000847  Gastric Cancer  mitomycin-c
# 27857  ACH-000674  Gastric Cancer  mitomycin-c
# 27866  ACH-000255  Gastric Cancer  mitomycin-c
# 27904  ACH-000344  Gastric Cancer  mitomycin-c
# 27911  ACH-000356  Gastric Cancer  mitomycin-c
# 62562  ACH-000356  Gastric Cancer    docetaxel
# 64615  ACH-000674  Gastric Cancer    docetaxel
# 65402  ACH-000764  Gastric Cancer    docetaxel
# 66854  ACH-000911  Gastric Cancer    docetaxel
#
#                                                  moa  \
# 4783                tubulin polymerization inhibitor
# 4802                tubulin polymerization inhibitor
# 4819                tubulin polymerization inhibitor
# 4838                tubulin polymerization inhibitor
# 4839                tubulin polymerization inhibitor
# 4872                tubulin polymerization inhibitor
# 4885                tubulin polymerization inhibitor
# 4897                tubulin polymerization inhibitor
# 4934                tubulin polymerization inhibitor
# 27805  DNA alkylating agent, DNA synthesis inhibitor
# 27809  DNA alkylating agent, DNA synthesis inhibitor
# 27817  DNA alkylating agent, DNA synthesis inhibitor
# 27829  DNA alkylating agent, DNA synthesis inhibitor
# 27857  DNA alkylating agent, DNA synthesis inhibitor
# 27866  DNA alkylating agent, DNA synthesis inhibitor
# 27904  DNA alkylating agent, DNA synthesis inhibitor
# 27911  DNA alkylating agent, DNA synthesis inhibitor
# 62562               tubulin polymerization inhibitor
# 64615               tubulin polymerization inhibitor
# 65402               tubulin polymerization inhibitor
# 66854               tubulin polymerization inhibitor
#
#                                            target  \
# 4783   BCL2, MAP2, MAP4, MAPT, NR1I2, TUBB, TUBB1
# 4802   BCL2, MAP2, MAP4, MAPT, NR1I2, TUBB, TUBB1
# 4819   BCL2, MAP2, MAP4, MAPT, NR1I2, TUBB, TUBB1
# 4838   BCL2, MAP2, MAP4, MAPT, NR1I2, TUBB, TUBB1
# 4839   BCL2, MAP2, MAP4, MAPT, NR1I2, TUBB, TUBB1
# 4872   BCL2, MAP2, MAP4, MAPT, NR1I2, TUBB, TUBB1
# 4885   BCL2, MAP2, MAP4, MAPT, NR1I2, TUBB, TUBB1
# 4897   BCL2, MAP2, MAP4, MAPT, NR1I2, TUBB, TUBB1
# 4934   BCL2, MAP2, MAP4, MAPT, NR1I2, TUBB, TUBB1
# 27805                                         NaN
# 27809                                         NaN
# 27817                                         NaN
# 27829                                         NaN
# 27857                                         NaN
# 27866                                         NaN
# 27904                                         NaN
# 27911                                         NaN
# 62562  BCL2, MAP2, MAP4, MAPT, NR1I2, TUBB, TUBB1
# 64615  BCL2, MAP2, MAP4, MAPT, NR1I2, TUBB, TUBB1
# 65402  BCL2, MAP2, MAP4, MAPT, NR1I2, TUBB, TUBB1
# 66854  BCL2, MAP2, MAP4, MAPT, NR1I2, TUBB, TUBB1
#
#                                               indication     phase        r2  \
# 4783   breast cancer, non-small cell lung cancer (NSC...  Launched  0.977671
# 4802   breast cancer, non-small cell lung cancer (NSC...  Launched  0.817384
# 4819   breast cancer, non-small cell lung cancer (NSC...  Launched  0.748284
# 4838   breast cancer, non-small cell lung cancer (NSC...  Launched  0.842545
# 4839   breast cancer, non-small cell lung cancer (NSC...  Launched  0.867757
# 4872   breast cancer, non-small cell lung cancer (NSC...  Launched  0.846306
# 4885   breast cancer, non-small cell lung cancer (NSC...  Launched  0.922466
# 4897   breast cancer, non-small cell lung cancer (NSC...  Launched  0.777161
# 4934   breast cancer, non-small cell lung cancer (NSC...  Launched  0.810193
# 27805          pancreatic cancer, gastric adenocarcinoma  Launched  0.734920
# 27809          pancreatic cancer, gastric adenocarcinoma  Launched  0.718332
# 27817          pancreatic cancer, gastric adenocarcinoma  Launched  0.726763
# 27829          pancreatic cancer, gastric adenocarcinoma  Launched  0.830113
# 27857          pancreatic cancer, gastric adenocarcinoma  Launched  0.855500
# 27866          pancreatic cancer, gastric adenocarcinoma  Launched  0.761831
# 27904          pancreatic cancer, gastric adenocarcinoma  Launched  0.778541
# 27911          pancreatic cancer, gastric adenocarcinoma  Launched  0.790410
# 62562  breast cancer, non-small cell lung cancer (NSC...  Launched  0.810655
# 64615  breast cancer, non-small cell lung cancer (NSC...  Launched  0.771752
# 65402  breast cancer, non-small cell lung cancer (NSC...  Launched  0.949641
# 66854  breast cancer, non-small cell lung cancer (NSC...  Launched  0.740565
#
#            ic50       auc  lower_limit  effectiveCont  effective
# 4783   0.038857  0.439954     0.024630       6.393319          0
# 4802   0.029509  0.412153     0.024279       6.670703          0
# 4819   0.037117  0.451819     0.055834       5.672975          0
# 4838   0.026288  0.450473     0.116318       5.371945          0
# 4839   0.008449  0.297080     0.039226       7.467776          1
# 4872   0.034948  0.441346     0.042524       5.980146          0
# 4885   0.016160  0.348987     0.018364       7.523763          1
# 4897   0.032964  0.486224     0.154576       4.912457          0
# 4934   0.008861  0.394221     0.175086       6.158350          0
# 27805  0.094456  0.521706     0.006483       6.881884          0
# 27809  0.145153  0.583589     0.047529       4.568535          0
# 27817  0.476435  0.686001     0.001825       6.883558          0
# 27829  0.083335  0.520531     0.032942       5.406359          0
# 27857  0.240848  0.617385     0.005073       6.349549          0
# 27866  0.426082  0.679774     0.016219       4.782720          0
# 27904  0.114378  0.640264     0.242133       3.336012          0
# 27911  0.303442  0.653906     0.047664       3.972784          0
# 62562  0.006977  0.577701     0.170512       6.308781          0
# 64615  0.017043  0.683234     0.187223       5.315914          0
# 65402  0.003101  0.481914     0.075580       7.816828          1
# 66854  0.001288  0.477578     0.218460       7.861506          1

# %% [markdown]
# # Create output table

# %%
cols=['Cancer type', 'Cell line', 'Drug count', 'Mean rank', 'Max rank', 'Top drug', 'Mean rank', 'Max rank', 'Top drug']
results = pd.DataFrame(columns=cols)

# %%
i = 0
for ct, indications in cTypeInd.items():
    df = pairDF.copy()[pairDF.cancerType == ct]
    check = lambda x: checkIndication(x, indications)
    for cellLine, subdf in df.groupby(by='cellLine'):
        row = [ct, cellLine]
        subdf = subdf[subdf.drugIndication.apply(check)]
        row.append(len(subdf))
        
        for m in ['dsc', 'rf']:
            row.append(round(subdf[f'{m}CellRank'].mean(), 2))
            row.append(int(subdf[f'{m}CellRank'].min()))
            row.append(subdf.sort_values(by=f'{m}CellRank').drug.values[0])
            
        results.loc[i, :] = row
        i += 1

# %%
r2 = results.sort_values(by=['Cancer type', 'Cell line'])
r2.head()
# Out:
#         Cancer type   Cell line Drug count Mean rank Max rank     Top drug  \
# 651  Bladder Cancer  ACH-000127          3     22.33        6  doxorubicin
# 652  Bladder Cancer  ACH-000486          3     22.33        6  doxorubicin
# 653  Bladder Cancer  ACH-000522          3     22.33        6  doxorubicin
# 654  Bladder Cancer  ACH-000547          3     22.33        6  doxorubicin
# 655  Bladder Cancer  ACH-000834          3      22.0        5  doxorubicin
#
#     Mean rank Max rank    Top drug
# 651     89.33        5  valrubicin
# 652     70.33        7  valrubicin
# 653      75.0       13  valrubicin
# 654     49.33       21  valrubicin
# 655      59.0       15  valrubicin

# %%
r2['Cell line'].nunique()
# Out:
# 805

# %%
r2.to_csv('SupplementalTable9.csv', index=False)

# %% [markdown]
# # Get average variance in ranking

# %%
dscTopDrugs = r2.iloc[:, -4].unique()
cdrTopDrugs = r2.iloc[:, -1].unique()

# %%
len(dscTopDrugs)
# Out:
# 13

# %%
dscRankVars = []
for d in dscTopDrugs:
    subdf = pairDF[pairDF.drug == d]
    dscRankVars.append(subdf.dscCellRank.var())
    
print(round(np.mean(dscRankVars), 4))
# Out:
# 2.9479

# %%
cdrRankVars = []
for d in cdrTopDrugs:
    subdf = pairDF[pairDF.drug == d]
    cdrRankVars.append(subdf.rfCellRank.var())
    
print(round(np.mean(cdrRankVars), 4))
# Out:
# 601.5828

# %% [markdown]
# # Get cancer type average & pvals

# %%
cols2=['Cancer type', 'Cell line count', 'Drug count', 
       'DeepDSC', 'FS-CDR', 'p-value', 
       'DeepDSC', 'FS-CSR', 'p-value', 
       'DeepDSC', 'FS-CDR']
results2 = pd.DataFrame(columns=cols2)

# %%
i = 0
pcntsDSC = []
pcntsCDR = []
for ct, subdf in results.groupby(by='Cancer type'):
    row = [ct, subdf.shape[0], subdf['Drug count'].values[0]]
    dscMean = subdf.iloc[:, 3].values
    fsMean = subdf.iloc[:, 6].values
    meanP = ttest(dscMean, fsMean).pvalue
    row.extend([round(dscMean.mean(),2), round(fsMean.mean(),2), round(meanP,4)])
    
    dscMax = subdf.iloc[:, 4].values
    fsMax = subdf.iloc[:, 7].values
    maxP = ttest(dscMax, fsMax).pvalue
    row.extend([round(dscMax.mean(), 2), round(fsMax.mean(), 2), round(maxP,4)])
    
    topDSC = subdf.iloc[:, -4].value_counts()
    topCDR = subdf.iloc[:, -1].value_counts()
    pcntDSC = round(100*(topDSC[0]/len(subdf)), 2)
    pcntCDR = round(100*(topCDR[0]/len(subdf)), 2)
    row.extend([f'{topDSC.index[0]} ({pcntDSC})', 
                f'{topCDR.index[0]} ({pcntCDR})'])
    if row[2] > 1:
        pcntsDSC.append(pcntDSC)
        pcntsCDR.append(pcntCDR)
    
    results2.loc[i, :] = row
    i += 1

# %%
np.mean(pcntsDSC)
# Out:
# 94.96125

# %%
np.mean(pcntsCDR)
# Out:
# 92.16375000000001

# %%
results2.shape
# Out:
# (20, 11)

# %%
results2
# Out:
#                    Cancer type Cell line count Drug count DeepDSC  FS-CDR  \
# 0               Bladder Cancer              17          3   22.19   98.92
# 1                Breast Cancer              43         17  133.14  163.68
# 2              Cervical Cancer              18          1    10.0  104.94
# 3      Colon/Colorectal Cancer              50          9   183.5  238.18
# 4   Endometrial/Uterine Cancer              22          1  222.27  332.27
# 5               Gastric Cancer              39          3  144.81   159.1
# 6         Head and Neck Cancer              37          2  168.86   33.27
# 7                Kidney Cancer              33          7   84.71  204.76
# 8                     Leukemia             104         33  190.98  169.65
# 9                 Liver Cancer               9          1  118.33  290.11
# 10                 Lung Cancer             118         19  134.55  169.89
# 11                    Lymphoma              83         12  176.66  103.43
# 12                     Myeloma              30          9  143.19   73.22
# 13               Neuroblastoma              29          1  271.28    67.1
# 14              Ovarian Cancer              38          7  176.88   78.73
# 15           Pancreatic Cancer              24          7  193.88  226.23
# 16             Prostate Cancer              10          5   77.78   35.66
# 17                     Sarcoma              35          2   101.1   140.2
# 18                 Skin Cancer              51          6  235.68  174.33
# 19              Thyroid Cancer              15          5  205.01  286.19
#
#    p-value DeepDSC  FS-CSR p-value                   DeepDSC  \
# 0      0.0    5.65   20.71     0.0       doxorubicin (100.0)
# 1      0.0     2.0    2.72     0.0         docetaxel (62.79)
# 2      0.0    10.0  104.94     0.0         topotecan (100.0)
# 3      0.0   10.98    16.1     0.0        irinotecan (100.0)
# 4      0.0  222.27  332.27     0.0      methotrexate (100.0)
# 5   0.0444    2.13   25.54     0.0         docetaxel (100.0)
# 6      0.0    2.11   25.86     0.0         docetaxel (100.0)
# 7      0.0    5.64     8.7     0.0       doxorubicin (100.0)
# 8      0.0    5.62    4.47     0.0       doxorubicin (100.0)
# 9      0.0  118.33  290.11     0.0         sorafenib (100.0)
# 10     0.0     2.0    2.58     0.0         docetaxel (91.53)
# 11     0.0    5.14    3.82     0.0       doxorubicin (65.06)
# 12     0.0    5.67     6.2  0.0678       doxorubicin (100.0)
# 13     0.0  271.28    67.1     0.0  cyclophosphamide (100.0)
# 14     0.0    2.79    2.71  0.5913        paclitaxel (100.0)
# 15     0.0   21.96    2.54     0.0        everolimus (100.0)
# 16     0.0     2.4     2.8  0.2457         docetaxel (100.0)
# 17     0.0   58.97   30.86     0.0       vinblastine (100.0)
# 18     0.0  112.96   39.82     0.0         vindesine (100.0)
# 19     0.0   89.53  204.73     0.0        lenvatinib (100.0)
#
#                       FS-CDR
# 0         valrubicin (64.71)
# 1        gemcitabine (100.0)
# 2          topotecan (100.0)
# 3              SN-38 (100.0)
# 4       methotrexate (100.0)
# 5          docetaxel (100.0)
# 6          docetaxel (86.49)
# 7       temsirolimus (84.85)
# 8        vincristine (89.42)
# 9          sorafenib (100.0)
# 10       gemcitabine (99.15)
# 11        romidepsin (100.0)
# 12   ixazomib-citrate (90.0)
# 13  cyclophosphamide (100.0)
# 14       gemcitabine (100.0)
# 15       gemcitabine (100.0)
# 16       cabazitaxel (100.0)
# 17       vinblastine (100.0)
# 18        dabrafenib (100.0)
# 19         cinacalcet (60.0)

# %%
results2[results2['Cancer type'].isin(['Bladder Cancer',
                                       'Head and Neck Cancer',
                                       'Gastric Cancer',
                                       'Prostate Cancer'])].sort_values(by='Drug count')
# Out:
#              Cancer type Cell line count Drug count DeepDSC FS-CDR p-value  \
# 6   Head and Neck Cancer              37          2  168.86  33.27     0.0
# 0         Bladder Cancer              17          3   22.19  98.92     0.0
# 5         Gastric Cancer              39          3  144.81  159.1  0.0444
# 16       Prostate Cancer              10          5   77.78  35.66     0.0
#
#    DeepDSC FS-CSR p-value              DeepDSC               FS-CDR
# 6     2.11  25.86     0.0    docetaxel (100.0)    docetaxel (86.49)
# 0     5.65  20.71     0.0  doxorubicin (100.0)   valrubicin (64.71)
# 5     2.13  25.54     0.0    docetaxel (100.0)    docetaxel (100.0)
# 16     2.4    2.8  0.2457    docetaxel (100.0)  cabazitaxel (100.0)

# %%
37+17+39+10
# Out:
# 103

# %%
len(set(i.split(" ")[0] for i in results2.iloc[:, -1])) / 20
# Out:
# 0.8

# %%
set(i.split(" ")[0] for i in results2.iloc[:, -2])
# Out:
# {'cyclophosphamide',
#  'docetaxel',
#  'doxorubicin',
#  'everolimus',
#  'irinotecan',
#  'lenvatinib',
#  'methotrexate',
#  'paclitaxel',
#  'sorafenib',
#  'topotecan',
#  'vinblastine',
#  'vindesine'}

# %%
np.sum([i.split(" ")[0] in ['docetaxel', 'doxorubicin'] for i in results2.iloc[:, -2]])
# Out:
# 10

# %% [markdown]
# # Save predDF for repurposing case study

# %%
repDF = pairDF.iloc[:, :6].rename(columns={'rfPred': 'pred', 'rfCellRank': 'cellRank'})
repDF[repDF.cancerType.isin(['Bladder Cancer',
                             'Head and Neck Cancer',
                             'Gastric Cancer',
                             'Prostate Cancer'])]
# Out:
#           cellLine      cancerType            drug  \
# 183943  ACH-000001  Ovarian Cancer  5-fluorouracil
# 183990  ACH-000001  Ovarian Cancer           SN-38
# 184034  ACH-000001  Ovarian Cancer     abemaciclib
# 183828  ACH-000001  Ovarian Cancer  acetophenazine
# 184106  ACH-000001  Ovarian Cancer        acipimox
# ...            ...             ...             ...
# 98736   ACH-002834     Bone Cancer      vismodegib
# 98877   ACH-002834     Bone Cancer      vorinostat
# 98769   ACH-002834     Bone Cancer        zaleplon
# 98834   ACH-002834     Bone Cancer     ziprasidone
# 98816   ACH-002834     Bone Cancer    zolmitriptan
#
#                                            drugIndication      pred  cellRank
# 183943  colorectal cancer, breast cancer, pancreatic c...  0.001863       305
# 183990                                  colorectal cancer  0.395247         8
# 184034                                      breast cancer  0.003214       288
# 183828                                          psychosis  0.041572        63
# 184106                                     hyperlipidemia  0.016433       148
# ...                                                   ...       ...       ...
# 98736                          basal cell carcinoma (bcc)  0.025566       124
# 98877                    cutaneous t-cell lymphoma (ctcl)  0.019711       156
# 98769                                            insomnia  0.024570       128
# 98834                     schizophrenia, bipolar disorder  0.013722       187
# 98816                                   migraine headache  0.038703        81
#
# [362727 rows x 6 columns]
