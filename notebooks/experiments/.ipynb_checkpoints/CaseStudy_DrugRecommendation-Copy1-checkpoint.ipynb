# %% [markdown]
# # Import Packages

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from itertools import product
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# # Define functions

# %%
def sim_btwn_grps(rep, groupA, groupB):
    sim = cosine_similarity(rep.iloc[:, 1:])
    sim = pd.DataFrame(sim, index=rep.index.values, columns=rep.index.values)
    
    cancers = set(rep.cancerType.unique().tolist())
    groupC = cancers - set(groupA)
    groupC = list(groupC - set(groupB))
    
    A = rep[(rep.cancerType.isin(groupA))].index.tolist()
    B = rep[(rep.cancerType.isin(groupB))].index.tolist()
    C = rep[(rep.cancerType.isin(groupC))].index.tolist()

    A2B = []
    for a, b in product(A, B):
        A2B.append(1 - sim.loc[a,b])
        
    A2C = []
    for a, c in product(A, C):
        A2C.append(1 - sim.loc[a, c])
    
    return A2B, A2C

# %% [markdown]
# # Load + process data

# %% [markdown]
# ## RNA

# %%
newCancerCellLines = pd.read_csv('../data/cell_lines/RNA_newcancer_allgenes.csv', index_col=0).index.tolist()
cancerGenes = pd.read_csv('../data/cell_lines/RNA_newcancer_cancergenes.csv', index_col=0).columns.tolist()

allRNA = pd.read_csv('../data/cell_lines/RNA_autoencoder_pretrain.csv', index_col=0)
allRNA = pd.concat([allRNA, pd.read_csv('../data/cell_lines/RNA_autoencoder_validation.csv', index_col=0)])
allRNA = allRNA[allRNA.index.str.startswith('ACH')]

# %% [markdown]
# ## Cell line info

# %%
cellLineInfo = pd.read_csv('../data/cell_lines/CCLE_INFO_22Q2.csv', index_col=0)
cellLineCancerType = cellLineInfo.loc[:, 'primary_disease']
cellLineCancerType.head()
# Out:
# DepMap_ID
# ACH-000016    Kidney Cancer
# ACH-000032         Leukemia
# ACH-000033      Lung Cancer
# ACH-000043    Non-Cancerous
# ACH-000049    Non-Cancerous
# Name: primary_disease, dtype: object

# %% [markdown]
# ## New cancer type cell lines

# %%
cellLines = pd.read_csv('../data/cell_lines/RNA_newcancer_cancergenes.csv', index_col=0).index.tolist()

cellLines = pd.DataFrame({'cellLine':cellLines})
cellLines['cancerType'] = cellLines.cellLine.apply(cellLineCancerType.get)
cellLines.set_index('cellLine', inplace=True)

# exclude Unknown b/c cancer type non known and Gallbladder b/c only 1 sample
cellLines = cellLines[~cellLines.cancerType.isin(['Unknown', 'Gallbladder Cancer'])]
cellLines.cancerType.value_counts()
# Out:
# Bone Cancer         12
# Thyroid Cancer      10
# Sarcoma              8
# Bile Duct Cancer     6
# Neuroblastoma        5
# Rhabdoid             4
# Prostate Cancer      3
# Name: cancerType, dtype: int64

# %% [markdown]
# ## Drug combinations

# %%
cdrRaw = pd.read_csv('../data/raw/CCLE_PRISM_IC50.csv', index_col='name')
cdrRaw.head()
# Out:
# <ipython-input-6-c2b5be4d2976>:1: DtypeWarning: Columns (14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   cdrRaw = pd.read_csv('../data/raw/CCLE_PRISM_IC50.csv', index_col='name')
#                           broad_id   depmap_id           ccle_name screen_id  \
# name
# cytarabine  BRD-K71847383-001-12-5  ACH-000879  MFE296_ENDOMETRIUM    HTS002
# cytarabine  BRD-K71847383-001-12-5  ACH-000320       PSN1_PANCREAS    HTS002
# cytarabine  BRD-K71847383-001-12-5  ACH-001145         OC316_OVARY    HTS002
# cytarabine  BRD-K71847383-001-12-5  ACH-000873  KYSE270_OESOPHAGUS    HTS002
# cytarabine  BRD-K71847383-001-12-5  ACH-000855  KYSE150_OESOPHAGUS    HTS002
#
#             upper_limit  lower_limit     slope        r2       auc  \
# name
# cytarabine            1     2.122352 -0.022826 -0.026964  1.677789
# cytarabine            1     1.325174 -0.237504 -0.147274  1.240300
# cytarabine            1     2.089350 -0.302937  0.193893  1.472333
# cytarabine            1     1.311820 -0.209393 -0.005460  1.207160
# cytarabine            1     1.369799 -0.277530  0.132818  1.229332
#
#                     ec50  ic50                                 moa  \
# name
# cytarabine  8.415093e+06   NaN  ribonucleotide reductase inhibitor
# cytarabine  9.643742e+00   NaN  ribonucleotide reductase inhibitor
# cytarabine  2.776687e-02   NaN  ribonucleotide reductase inhibitor
# cytarabine  2.654701e+00   NaN  ribonucleotide reductase inhibitor
# cytarabine  5.889041e-01   NaN  ribonucleotide reductase inhibitor
#
#                               target            disease.area  \
# name
# cytarabine  POLA1, POLB, POLD1, POLE  hematologic malignancy
# cytarabine  POLA1, POLB, POLD1, POLE  hematologic malignancy
# cytarabine  POLA1, POLB, POLD1, POLE  hematologic malignancy
# cytarabine  POLA1, POLB, POLD1, POLE  hematologic malignancy
# cytarabine  POLA1, POLB, POLD1, POLE  hematologic malignancy
#
#                                                    indication  \
# name
# cytarabine  acute lymphoblastic leukemia (ALL), chronic ly...
# cytarabine  acute lymphoblastic leukemia (ALL), chronic ly...
# cytarabine  acute lymphoblastic leukemia (ALL), chronic ly...
# cytarabine  acute lymphoblastic leukemia (ALL), chronic ly...
# cytarabine  acute lymphoblastic leukemia (ALL), chronic ly...
#
#                                                        smiles     phase  \
# name
# cytarabine  Nc1ccn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)c(=O)...  Launched
# cytarabine  Nc1ccn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)c(=O)...  Launched
# cytarabine  Nc1ccn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)c(=O)...  Launched
# cytarabine  Nc1ccn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)c(=O)...  Launched
# cytarabine  Nc1ccn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)c(=O)...  Launched
#
#             passed_str_profiling    row_name
# name
# cytarabine                  True  ACH-000879
# cytarabine                  True  ACH-000320
# cytarabine                  True  ACH-001145
# cytarabine                  True  ACH-000873
# cytarabine                  True  ACH-000855

# %% [markdown]
# ## Convert drug combinations to drug info

# %% [markdown]
# **Index: Drug name**
#
# **Columns: MOA, (gene) target, disease area, indication, (latest clinical) phase**

# %%
columns = ['moa', 'target', 'disease.area', 'indication', 'phase']
drugInfo = cdrRaw.loc[:, columns]
drugInfo.drop_duplicates(inplace=True)
drugInfo.head()
# Out:
#                                                 moa  \
# name
# cytarabine       ribonucleotide reductase inhibitor
# epinastine            histamine receptor antagonist
# floxuridine                 DNA synthesis inhibitor
# valrubicin   DNA inhibitor, topoisomerase inhibitor
# adapalene                 retinoid receptor agonist
#
#                                               target            disease.area  \
# name
# cytarabine                  POLA1, POLB, POLD1, POLE  hematologic malignancy
# epinastine   ADRA1A, ADRA2A, HRH1, HRH2, HTR2A, HTR7           ophthalmology
# floxuridine                                     TYMS                oncology
# valrubicin                                     TOP2A                oncology
# adapalene         RARA, RARB, RARG, RXRA, RXRB, RXRG             dermatology
#
#                                                     indication     phase
# name
# cytarabine   acute lymphoblastic leukemia (ALL), chronic ly...  Launched
# epinastine                                      conjunctivitis  Launched
# floxuridine                                  colorectal cancer  Launched
# valrubicin                                      bladder cancer  Launched
# adapalene                                   acne vulgaris (AV)  Launched

# %% [markdown]
# ## Split drug info into cancer and non-cancer drugs

# %% [markdown]
# ### Cancer drugs

# %%
cancerDrugs = drugInfo[drugInfo['disease.area'].str.contains('malignancy') | drugInfo['disease.area'].str.contains('oncology')]
cancerDrugs.head()
# Out:
#                                                                    moa  \
# name
# cytarabine                          ribonucleotide reductase inhibitor
# floxuridine                                    DNA synthesis inhibitor
# valrubicin                      DNA inhibitor, topoisomerase inhibitor
# fulvestrant                               estrogen receptor antagonist
# estramustine-phosphate  DNA synthesis inhibitor, microtubule inhibitor
#
#                                           target            disease.area  \
# name
# cytarabine              POLA1, POLB, POLD1, POLE  hematologic malignancy
# floxuridine                                 TYMS                oncology
# valrubicin                                 TOP2A                oncology
# fulvestrant                    ESR1, ESR2, GPER1                oncology
# estramustine-phosphate   ESR1, ESR2, MAP1A, MAP2                oncology
#
#                                                                indication  \
# name
# cytarabine              acute lymphoblastic leukemia (ALL), chronic ly...
# floxuridine                                             colorectal cancer
# valrubicin                                                 bladder cancer
# fulvestrant                                                 breast cancer
# estramustine-phosphate                                    prostate cancer
#
#                            phase
# name
# cytarabine              Launched
# floxuridine             Launched
# valrubicin              Launched
# fulvestrant             Launched
# estramustine-phosphate  Launched

# %%
cancerDrugs.phase.value_counts()
# Out:
# Launched    130
# Name: phase, dtype: int64

# %% [markdown]
# Launched means that the drug has been FDA approved

# %% [markdown]
# ### Non-cancer drugs

# %%
nonCancerDrugs = [('oncology' not in str(x)) & ('malignancy' not in str(x)) for x in drugInfo['disease.area']]
nonCancerDrugs = drugInfo[nonCancerDrugs]
nonCancerDrugs.head()
# Out:
#                                               moa  \
# name
# epinastine          histamine receptor antagonist
# adapalene               retinoid receptor agonist
# colforsin-daproate     adenylyl cyclase activator
# sulfamethazine                    PABA antagonist
# niridazole          phosphofructokinase inhibitor
#
#                                                      target  \
# name
# epinastine          ADRA1A, ADRA2A, HRH1, HRH2, HTR2A, HTR7
# adapalene                RARA, RARB, RARG, RXRA, RXRB, RXRG
# colforsin-daproate                                      NaN
# sulfamethazine                                          NaN
# niridazole                                              NaN
#
#                           disease.area            indication     phase
# name
# epinastine               ophthalmology        conjunctivitis  Launched
# adapalene                  dermatology    acne vulgaris (AV)  Launched
# colforsin-daproate                 NaN                   NaN  Launched
# sulfamethazine        gastroenterology  enteritis, enteritis  Launched
# niridazole          infectious disease       schistosomiasis  Launched

# %%
nonCancerDrugs.phase.value_counts()
# Out:
# Launched           397
# Preclinical        346
# Phase 2            177
# Phase 1            110
# Phase 3            100
# Phase 1/Phase 2     23
# Withdrawn           17
# Phase 2/Phase 3     10
# Name: phase, dtype: int64

# %%
cancerDrugsList = cancerDrugs.index.tolist()
nonCancerDrugsList = nonCancerDrugs.index.tolist()

# %%
print(f"Number of cancer drugs: {len(cancerDrugsList)}")
print(f"Number of non-cancer drugs: {len(nonCancerDrugsList)}")
# Out:
# Number of cancer drugs: 130
# Number of non-cancer drugs: 1180

# %% [markdown]
# ## Pred dataframe

# %%
base_path = '/fs/scratch/PCON0041/PatrickLawrence/cancer-drug-response/mcRBM/full_models/newcancer_preds/'
fname = 'CDR-smcRBM_preRBM2_Layers1_Hidden8_DO3_AFrelu_LR001_DR96_DS5_L1001_preds.csv'
full_path = os.path.join(base_path, fname)

preds = pd.read_csv(full_path, index_col=0)
preds.head()
# Out:
#     cell_line     cancer_type        drug  true      pred
# 0  ACH-000359     Bone Cancer  cytarabine     0  0.489242
# 1  ACH-000804   Neuroblastoma  cytarabine     0  0.494004
# 2  ACH-000391     Bone Cancer  cytarabine     0  0.483010
# 3  ACH-000364     Bone Cancer  cytarabine     0  0.483253
# 4  ACH-001321  Thyroid Cancer  cytarabine     0  0.495825

# %% [markdown]
# ### Bianarize preds using threshold

# %%
predThreshold = 0.4806
def binarize(n, threshold):
    if n < threshold:
        return 0
    else:
        return 1
    
toBinary = lambda x: binarize(x, predThreshold)
preds['predBool'] = preds.pred.apply(toBinary)
preds
# Out:
#         cell_line     cancer_type         drug  true      pred  predBool
# 0      ACH-000359     Bone Cancer   cytarabine     0  0.489242         1
# 1      ACH-000804   Neuroblastoma   cytarabine     0  0.494004         1
# 2      ACH-000391     Bone Cancer   cytarabine     0  0.483010         1
# 3      ACH-000364     Bone Cancer   cytarabine     0  0.483253         1
# 4      ACH-001321  Thyroid Cancer   cytarabine     0  0.495825         1
# ...           ...             ...          ...   ...       ...       ...
# 63030  ACH-001321  Thyroid Cancer   vandetanib     0  0.564938         1
# 63031  ACH-001321  Thyroid Cancer  vemurafenib     0  0.569870         1
# 63032  ACH-001321  Thyroid Cancer   venetoclax     0  0.609534         1
# 63033  ACH-001321  Thyroid Cancer   volasertib     1  0.630792         1
# 63034  ACH-001321  Thyroid Cancer   vorinostat     1  0.512204         1
#
# [63035 rows x 6 columns]

# %% [markdown]
# # Case Study

# %% [markdown]
# ## Procedure:

# %% [markdown]
#     1) Iterate through each cancer type not seen during training
#         a) Get top 20 drugs (by pred float) for each cell line that are:
#             i) predicted true (predBool == 1)
#             ii) effective combinations by drug screen (true == 1)
#             iii) not indicated to treat the current cancer type
#         b) Check if any of the drugs are recommended by majority of cell lines of current cancer type
#         b) Check if any of the commonly recommended drugs are indicated to treat other cancers
#             i) evaluate distance between cell lines of the current cancer and indicated cancer.
#                Plausible candidate if the distance between these groups are significantly closer than others
#         c) Check if any of commonly recommended drugs are not indicated for cancer.
#             i) Plausible candidate if moa or gene targets shared between disease

# %% [markdown]
# ## Get commonly recommened drugs

# %%
commonRecs = {}
for cancerType, subdf in preds.groupby(by='cancer_type'):
    if cancerType in ['Unknown', "Gallbladder Cancer"]:
        continue
    commonRecs[cancerType] = {}
    commonRecs[cancerType]['nCellLines'] = len(subdf.cell_line.unique())
    subdf = subdf[(subdf.predBool == 1) & (subdf.true == 1)]
    subdf.sort_values(by='pred', inplace=True)
    for cellLine, subsubdf in subdf.groupby(by='cell_line'):
        subsubdf.sort_values(by='pred')
        topk = 0
        for i in range(len(subsubdf)):
            drugName = subsubdf.iloc[i, :].drug
            if drugName not in drugInfo.index.tolist():
                continue
            cancer = cancerType.split(' ')[0].lower()
            if cancer not in str(drugInfo.loc[drugName, 'indication']):
                if drugName in list(commonRecs[cancerType].keys()):
                    commonRecs[cancerType][drugName]["count"] += 1
                    commonRecs[cancerType][drugName]["preds"].append(subsubdf.iloc[i, :].pred)
                    commonRecs[cancerType][drugName]["cellLines"].append(cellLine)
                else:
                    commonRecs[cancerType][drugName] = {}
                    commonRecs[cancerType][drugName]["count"] = 1
                    commonRecs[cancerType][drugName]["preds"] = [subsubdf.iloc[i, :].pred]
                    commonRecs[cancerType][drugName]["cellLines"] = [cellLine]
            topk += 1
            if topk >= 20:
                break
# Out:
# <ipython-input-68-35f4a2e3bd3d>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subdf.sort_values(by='pred', inplace=True)
# <ipython-input-68-35f4a2e3bd3d>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subdf.sort_values(by='pred', inplace=True)
# <ipython-input-68-35f4a2e3bd3d>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subdf.sort_values(by='pred', inplace=True)
# <ipython-input-68-35f4a2e3bd3d>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subdf.sort_values(by='pred', inplace=True)
# <ipython-input-68-35f4a2e3bd3d>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subdf.sort_values(by='pred', inplace=True)
# <ipython-input-68-35f4a2e3bd3d>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subdf.sort_values(by='pred', inplace=True)
# <ipython-input-68-35f4a2e3bd3d>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subdf.sort_values(by='pred', inplace=True)

# %%
for cancer in commonRecs.keys():
    nCL = commonRecs[cancer]['nCellLines']
    print(f"Cancer: {cancer}; nCellLines: {nCL}")
# Out:
# Cancer: Bile Duct Cancer; nCellLines: 6
# Cancer: Bone Cancer; nCellLines: 12
# Cancer: Neuroblastoma; nCellLines: 5
# Cancer: Prostate Cancer; nCellLines: 3
# Cancer: Rhabdoid; nCellLines: 4
# Cancer: Sarcoma; nCellLines: 8
# Cancer: Thyroid Cancer; nCellLines: 10

# %%
results = pd.DataFrame(columns=['Cancer Type', 'Drug Candidate', 'PredScore', '%Rec', 'CLs',
                                'MOA', 'Target(s)', 'Phase', 'FDA indication'])
i = 0
for cancer in commonRecs.keys():
    nCL = commonRecs[cancer]['nCellLines']
    for drug in list(commonRecs[cancer].keys())[1:]:
        prctRec = 100 * (commonRecs[cancer][drug]['count'] / nCL)
        CLs = commonRecs[cancer][drug]['cellLines']
        avg_pred = np.mean(commonRecs[cancer][drug]['preds'])
        moa = drugInfo.loc[drug, 'moa']
        target = drugInfo.loc[drug, 'target']
        phase = drugInfo.loc[drug, 'phase']
        if phase == 'Launched':
            phase = 'Approved'
        indication = drugInfo.loc[drug, 'indication']
        
        results.loc[i, :] = [cancer, drug, avg_pred, prctRec, CLs, moa, target, phase, indication]
        i += 1

# %%
common = results[results['%Rec'] >= 50.]
commonSorted = common.sort_values(by=['Cancer Type', '%Rec', 'PredScore'], ascending=[True, False, False])

# %%
commonSorted['Cancer Type'].unique()
# Out:
# array(['Bile Duct Cancer', 'Bone Cancer', 'Neuroblastoma',
#        'Prostate Cancer', 'Rhabdoid', 'Sarcoma', 'Thyroid Cancer'],
#       dtype=object)

# %%
commonSorted[commonSorted['Cancer Type'] == 'Bile Duct Cancer']
# Out:
#          Cancer Type      Drug Candidate PredScore       %Rec  \
# 33  Bile Duct Cancer         Ro-106-9920  0.485374  66.666667
# 31  Bile Duct Cancer    tyrphostin-AG-99  0.484903  66.666667
# 42  Bile Duct Cancer          NSC-632839  0.483116  66.666667
# 25  Bile Duct Cancer           alexidine  0.482564  66.666667
# 13  Bile Duct Cancer           ryuvidine  0.487055       50.0
# 35  Bile Duct Cancer     cetylpyridinium   0.48701       50.0
# 38  Bile Duct Cancer         zardaverine  0.486857       50.0
# 10  Bile Duct Cancer         metaraminol  0.486803       50.0
# 37  Bile Duct Cancer          ciclopirox  0.486758       50.0
# 36  Bile Duct Cancer          mexiletine  0.486692       50.0
# 43  Bile Duct Cancer           CCG-50014  0.485912       50.0
# 27  Bile Duct Cancer  combretastatin-A-4  0.485139       50.0
# 30  Bile Duct Cancer            NSC-3852  0.485111       50.0
# 29  Bile Duct Cancer         gemcitabine  0.484962       50.0
# 28  Bile Duct Cancer       chlorhexidine  0.484535       50.0
#
#                                                  CLs  \
# 33  [ACH-000209, ACH-000268, ACH-000461, ACH-000808]
# 31  [ACH-000209, ACH-000268, ACH-000461, ACH-000808]
# 42  [ACH-000268, ACH-000461, ACH-000808, ACH-000976]
# 25  [ACH-000209, ACH-000268, ACH-000461, ACH-000808]
# 13              [ACH-000182, ACH-000268, ACH-000976]
# 35              [ACH-000209, ACH-000268, ACH-000976]
# 38              [ACH-000209, ACH-000268, ACH-000461]
# 10              [ACH-000182, ACH-000268, ACH-000976]
# 37              [ACH-000209, ACH-000268, ACH-000808]
# 36              [ACH-000209, ACH-000268, ACH-000808]
# 43              [ACH-000268, ACH-000461, ACH-000976]
# 27              [ACH-000209, ACH-000808, ACH-000976]
# 30              [ACH-000209, ACH-000461, ACH-000808]
# 29              [ACH-000209, ACH-000268, ACH-000808]
# 28              [ACH-000209, ACH-000268, ACH-000808]
#
#                                            MOA                Target(s)  \
# 33                      NFkB pathway inhibitor                      NaN
# 31                   tyrosine kinase inhibitor                     EGFR
# 42       ubiquitin specific protease inhibitor  SENP2, USP1, USP2, USP7
# 25    phosphatidylglycerophosphatase inhibitor                   PTPMT1
# 13  histone lysine methyltransferase inhibitor               CDK2, CDK4
# 35                                         NaN                      NaN
# 38                 phosphodiesterase inhibitor                    PDE4D
# 10                 adrenergic receptor agonist                   ADRA1A
# 37                membrane integrity inhibitor                   ATP1A1
# 36                      sodium channel blocker        AHR, SCN4A, SCN5A
# 43               G protein signaling inhibitor               RGS4, RGS8
# 27            tubulin polymerization inhibitor                      NaN
# 30                              HDAC inhibitor                    HDAC1
# 29          ribonucleotide reductase inhibitor  CMPK1, RRM1, RRM2, TYMS
# 28                membrane integrity inhibitor                      NaN
#
#           Phase                                     FDA indication
# 33  Preclinical                                                NaN
# 31  Preclinical                                                NaN
# 42  Preclinical                                                NaN
# 25  Preclinical                                                NaN
# 13  Preclinical                                                NaN
# 35     Approved                     gingivitis, mouth inflammation
# 38      Phase 2                                                NaN
# 10     Approved                                        hypotension
# 37     Approved                                      onychomycosis
# 36     Approved  ventricular arrhythmias, ventricular tachycard...
# 43  Preclinical                                                NaN
# 27      Phase 2                                                NaN
# 30  Preclinical                                                NaN
# 29     Approved  ovarian cancer, breast cancer, non-small cell ...
# 28     Approved              cosmetic, skin infections, gingivitis

# %%
with pd.option_context('display.max_colwidth', None):
  display(commonSorted[commonSorted['Cancer Type'] == 'Bone Cancer'])
# Out:
#     Cancer Type Drug Candidate PredScore  %Rec  \
# 89  Bone Cancer     mexiletine  0.483848  50.0
# 80  Bone Cancer      melphalan  0.483103  50.0
# 78  Bone Cancer    gemcitabine  0.483099  50.0
# 82  Bone Cancer    Ro-106-9920  0.482824  50.0
#
#                                                                          CLs  \
# 89  [ACH-000052, ACH-000082, ACH-000210, ACH-000279, ACH-000359, ACH-000613]
# 80  [ACH-000052, ACH-000082, ACH-000087, ACH-000210, ACH-000359, ACH-000748]
# 78  [ACH-000052, ACH-000082, ACH-000087, ACH-000210, ACH-000359, ACH-000748]
# 82  [ACH-000052, ACH-000087, ACH-000210, ACH-000279, ACH-000359, ACH-000748]
#
#                                     MOA                Target(s)        Phase  \
# 89               sodium channel blocker        AHR, SCN4A, SCN5A     Approved
# 80  DNA alkylating agent, DNA inhibitor                      NaN     Approved
# 78   ribonucleotide reductase inhibitor  CMPK1, RRM1, RRM2, TYMS     Approved
# 82               NFkB pathway inhibitor                      NaN  Preclinical
#
#                                                                           FDA indication
# 89                                 ventricular arrhythmias, ventricular tachycardia (VT)
# 80                                                                      multiple myeloma
# 78  ovarian cancer, breast cancer, non-small cell lung cancer (NSCLC), pancreatic cancer
# 82                                                                                   NaN

# %%
commonSorted[commonSorted['Cancer Type'] == 'Neuroblastoma']
# Out:
#        Cancer Type Drug Candidate PredScore  %Rec  \
# 200  Neuroblastoma     NSC-319726  0.484434  60.0
# 186  Neuroblastoma      indisulam  0.482896  60.0
# 181  Neuroblastoma    BAY-11-7085  0.482349  60.0
#
#                                       CLs                     MOA  \
# 200  [ACH-000099, ACH-000259, ACH-000260]           p53 activator
# 186  [ACH-000099, ACH-000259, ACH-000260]           CDK inhibitor
# 181  [ACH-000099, ACH-000259, ACH-000260]  NFkB pathway inhibitor
#
#                                Target(s)        Phase FDA indication
# 200                                  NaN  Preclinical            NaN
# 186  CA1, CA12, CA14, CA2, CA6, CA7, CA9      Phase 2            NaN
# 181                               NFKBIA  Preclinical            NaN

# %%
commonSorted[commonSorted['Cancer Type'] == 'Prostate Cancer']
# Out:
#          Cancer Type     Drug Candidate PredScore       %Rec  \
# 281  Prostate Cancer      trovafloxacin  0.483216  66.666667
# 271  Prostate Cancer         fenoprofen  0.482891  66.666667
# 272  Prostate Cancer           triapine  0.482854  66.666667
# 279  Prostate Cancer              NH125  0.482454  66.666667
# 277  Prostate Cancer          SB-200646  0.482255  66.666667
# 268  Prostate Cancer        dexrazoxane  0.482127  66.666667
# 278  Prostate Cancer         iodipamide  0.482014  66.666667
# 275  Prostate Cancer  IKK-2-inhibitor-V  0.481941  66.666667
# 274  Prostate Cancer            RN-1734  0.481769  66.666667
# 260  Prostate Cancer          indisulam  0.481398  66.666667
#
#                           CLs  \
# 281  [ACH-000956, ACH-000977]
# 271  [ACH-000090, ACH-000977]
# 272  [ACH-000090, ACH-000977]
# 279  [ACH-000956, ACH-000977]
# 277  [ACH-000956, ACH-000977]
# 268  [ACH-000090, ACH-000977]
# 278  [ACH-000956, ACH-000977]
# 275  [ACH-000956, ACH-000977]
# 274  [ACH-000956, ACH-000977]
# 260  [ACH-000090, ACH-000956]
#
#                                                    MOA  \
# 281                     bacterial DNA gyrase inhibitor
# 271                            prostaglandin inhibitor
# 272                 ribonucleotide reductase inhibitor
# 279  eukaryotic translation elongation factor 2 inh...
# 277                      serotonin receptor antagonist
# 268           chelating agent, topoisomerase inhibitor
# 278                                  radiopaque medium
# 275              IKK inhibitor, NFkB pathway inhibitor
# 274                                    TRPV antagonist
# 260                                      CDK inhibitor
#
#                                Target(s)        Phase  \
# 281                                TOP2A    Withdrawn
# 271                 PTGS1, PTGS2, SLC5A8     Approved
# 272                           RRM1, RRM2      Phase 2
# 279                                  NaN  Preclinical
# 277                         HTR2B, HTR2C  Preclinical
# 268                         TOP2A, TOP2B     Approved
# 278                                  ALB     Approved
# 275                                IKBKB      Phase 1
# 274                                TRPV4  Preclinical
# 260  CA1, CA12, CA14, CA2, CA6, CA7, CA9      Phase 2
#
#                            FDA indication
# 281                                   NaN
# 271  rheumatoid arthritis, osteoarthritis
# 272                                   NaN
# 279                                   NaN
# 277                                   NaN
# 268                        cardiomyopathy
# 278                        contrast agent
# 275                                   NaN
# 274                                   NaN
# 260                                   NaN

# %%
commonSorted[commonSorted['Cancer Type'] == 'Rhabdoid']
# Out:
#     Cancer Type                         Drug Candidate PredScore  %Rec  \
# 321    Rhabdoid                            BAY-11-7085  0.484254  75.0
# 317    Rhabdoid                          cyclocytidine  0.483499  75.0
# 314    Rhabdoid                                 SU3327  0.483097  75.0
# 310    Rhabdoid                            thioguanine  0.482259  75.0
# 313    Rhabdoid                            zardaverine  0.482191  75.0
# 322    Rhabdoid                             ketoprofen  0.484647  50.0
# 331    Rhabdoid                               triapine  0.484176  50.0
# 343    Rhabdoid                            atipamezole  0.484144  50.0
# 309    Rhabdoid                             thiomersal  0.483595  50.0
# 311    Rhabdoid                            florfenicol   0.48329  50.0
# 312    Rhabdoid                                   PP-2  0.483177  50.0
# 315    Rhabdoid                             NSC-319726   0.48311  50.0
# 326    Rhabdoid                               riluzole  0.482416  50.0
# 305    Rhabdoid                          pyrimethamine  0.481684  50.0
# 323    Rhabdoid                        cetylpyridinium  0.481506  50.0
# 308    Rhabdoid                             decitabine    0.4815  50.0
# 307    Rhabdoid  MNS-(3,4-Methylenedioxy-nitrostyrene)  0.481482  50.0
# 306    Rhabdoid                             ciclopirox  0.481396  50.0
# 304    Rhabdoid                             mexiletine  0.481063  50.0
#
#                                       CLs  \
# 321  [ACH-000096, ACH-000172, ACH-001128]
# 317  [ACH-000096, ACH-000172, ACH-001128]
# 314  [ACH-000096, ACH-000172, ACH-001128]
# 310  [ACH-000096, ACH-000172, ACH-001128]
# 313  [ACH-000096, ACH-000172, ACH-001128]
# 322              [ACH-000096, ACH-001128]
# 331              [ACH-000172, ACH-000201]
# 343              [ACH-000201, ACH-001128]
# 309              [ACH-000096, ACH-001128]
# 311              [ACH-000096, ACH-000172]
# 312              [ACH-000096, ACH-000172]
# 315              [ACH-000096, ACH-000201]
# 326              [ACH-000172, ACH-001128]
# 305              [ACH-000096, ACH-001128]
# 323              [ACH-000172, ACH-001128]
# 308              [ACH-000096, ACH-000172]
# 307              [ACH-000096, ACH-000172]
# 306              [ACH-000096, ACH-000172]
# 304              [ACH-000096, ACH-000172]
#
#                                                   MOA  \
# 321                            NFkB pathway inhibitor
# 317  DNA synthesis inhibitor, RNA synthesis inhibitor
# 314                                     JNK inhibitor
# 310                                 purine antagonist
# 313                       phosphodiesterase inhibitor
# 322                          cyclooxygenase inhibitor
# 331                ribonucleotide reductase inhibitor
# 343                    adrenergic receptor antagonist
# 309                                  other antibiotic
# 311                       protein synthesis inhibitor
# 312                                     src inhibitor
# 315                                     p53 activator
# 326                               glutamate inhibitor
# 305                 dihydrofolate reductase inhibitor
# 323                                               NaN
# 308                   DNA methyltransferase inhibitor
# 307                      src inhibitor, syk inhibitor
# 306                      membrane integrity inhibitor
# 304                            sodium channel blocker
#
#                                              Target(s)        Phase  \
# 321                                             NFKBIA  Preclinical
# 317                                                NaN  Preclinical
# 314                                              MAPK8  Preclinical
# 310                                     IMPDH1, IMPDH2     Approved
# 313                                              PDE4D      Phase 2
# 322                        CXCR1, PTGS1, PTGS2, SLC5A8     Approved
# 331                                         RRM1, RRM2      Phase 2
# 343                                                NaN     Approved
# 309                                              OXCT1     Approved
# 311                                                NaN     Approved
# 312                         ABL1, LCK, LYN, RIPK2, SRC  Preclinical
# 315                                                NaN  Preclinical
# 326  KCNK10, KCNK2, KCNK4, KCNN4, SCN10A, SCN11A, S...     Approved
# 305                                      DHFR, SLC47A1     Approved
# 323                                                NaN     Approved
# 308                                      DNMT1, DNMT3A     Approved
# 307                                           SRC, SYK  Preclinical
# 306                                             ATP1A1     Approved
# 304                                  AHR, SCN4A, SCN5A     Approved
#
#                                         FDA indication
# 321                                                NaN
# 317                                                NaN
# 314                                                NaN
# 310                       acute myeloid leukemia (AML)
# 313                                                NaN
# 322               rheumatoid arthritis, osteoarthritis
# 331                                                NaN
# 343                                   reverse sedative
# 309                                                NaN
# 311                   bovine respiratory disease (BRD)
# 312                                                NaN
# 315                                                NaN
# 326                amyotrophic lateral sclerosis (ALS)
# 305                                            malaria
# 323                     gingivitis, mouth inflammation
# 308  myelodysplastic diseases (MDS), anemia, chroni...
# 307                                                NaN
# 306                                      onychomycosis
# 304  ventricular arrhythmias, ventricular tachycard...

# %%
with pd.option_context('display.max_colwidth', None):
  display(commonSorted[commonSorted['Cancer Type'] == 'Sarcoma'])
# Out:
#     Cancer Type          Drug Candidate PredScore  %Rec  \
# 371     Sarcoma             Ro-106-9920  0.484812  87.5
# 370     Sarcoma        tyrphostin-AG-99  0.484424  87.5
# 383     Sarcoma                NSC-3852   0.48326  75.0
# 382     Sarcoma             BAY-11-7082  0.482987  75.0
# 377     Sarcoma             zardaverine  0.486891  62.5
# 394     Sarcoma               melphalan  0.483632  62.5
# 388     Sarcoma         cetylpyridinium  0.483243  62.5
# 384     Sarcoma      combretastatin-A-4  0.481865  62.5
# 367     Sarcoma          broxyquinoline  0.484086  50.0
# 393     Sarcoma                  DCEBIO  0.484046  50.0
# 369     Sarcoma           chlorhexidine  0.483881  50.0
# 389     Sarcoma              mexiletine  0.483086  50.0
# 387     Sarcoma  phenylmercuric-acetate  0.482753  50.0
# 386     Sarcoma                 BVT-948  0.482544  50.0
#
#                                                                                       CLs  \
# 371  [ACH-000037, ACH-000054, ACH-000169, ACH-000449, ACH-000505, ACH-000833, ACH-000939]
# 370  [ACH-000037, ACH-000054, ACH-000169, ACH-000449, ACH-000505, ACH-000833, ACH-000939]
# 383              [ACH-000054, ACH-000169, ACH-000449, ACH-000505, ACH-000833, ACH-000939]
# 382              [ACH-000054, ACH-000169, ACH-000449, ACH-000505, ACH-000833, ACH-000939]
# 377                          [ACH-000037, ACH-000054, ACH-000169, ACH-000505, ACH-000835]
# 394                          [ACH-000169, ACH-000449, ACH-000505, ACH-000833, ACH-000939]
# 388                          [ACH-000054, ACH-000169, ACH-000833, ACH-000835, ACH-000939]
# 384                          [ACH-000054, ACH-000169, ACH-000833, ACH-000835, ACH-000939]
# 367                                      [ACH-000037, ACH-000449, ACH-000505, ACH-000833]
# 393                                      [ACH-000054, ACH-000833, ACH-000835, ACH-000939]
# 369                                      [ACH-000037, ACH-000054, ACH-000169, ACH-000939]
# 389                                      [ACH-000054, ACH-000449, ACH-000835, ACH-000939]
# 387                                      [ACH-000054, ACH-000169, ACH-000833, ACH-000939]
# 386                                      [ACH-000054, ACH-000833, ACH-000835, ACH-000939]
#
#                                      MOA             Target(s)        Phase  \
# 371               NFkB pathway inhibitor                   NaN  Preclinical
# 370            tyrosine kinase inhibitor                  EGFR  Preclinical
# 383                       HDAC inhibitor                 HDAC1  Preclinical
# 382               NFkB pathway inhibitor                  RELA  Preclinical
# 377          phosphodiesterase inhibitor                 PDE4D      Phase 2
# 394  DNA alkylating agent, DNA inhibitor                   NaN     Approved
# 388                                  NaN                   NaN     Approved
# 384     tubulin polymerization inhibitor                   NaN      Phase 2
# 367                  antiprotozoal agent                   NaN      Phase 1
# 393          potassium channel activator   KCNN2, KCNN3, KCNN4  Preclinical
# 369         membrane integrity inhibitor                   NaN     Approved
# 389               sodium channel blocker     AHR, SCN4A, SCN5A     Approved
# 387                     other antifungal                   NaN  Preclinical
# 386       tyrosine phosphatase inhibitor  PTPN1, PTPN11, PTPN2  Preclinical
#
#                                             FDA indication
# 371                                                    NaN
# 370                                                    NaN
# 383                                                    NaN
# 382                                                    NaN
# 377                                                    NaN
# 394                                       multiple myeloma
# 388                         gingivitis, mouth inflammation
# 384                                                    NaN
# 367                                                    NaN
# 393                                                    NaN
# 369                  cosmetic, skin infections, gingivitis
# 389  ventricular arrhythmias, ventricular tachycardia (VT)
# 387                                                    NaN
# 386                                                    NaN

# %%
with pd.option_context('display.max_colwidth', None):
  display(commonSorted[commonSorted['Cancer Type'] == 'Thyroid Cancer'])
# Out:
#         Cancer Type Drug Candidate PredScore  %Rec  \
# 436  Thyroid Cancer      alexidine  0.482831  60.0
# 442  Thyroid Cancer    gemcitabine  0.486544  50.0
# 441  Thyroid Cancer       NSC-3852    0.4855  50.0
# 437  Thyroid Cancer  teriflunomide  0.485018  50.0
# 439  Thyroid Cancer    BAY-11-7082  0.484927  50.0
# 492  Thyroid Cancer     chloroxine  0.483954  50.0
#
#                                                                           CLs  \
# 436  [ACH-000163, ACH-000716, ACH-000897, ACH-001306, ACH-001307, ACH-001321]
# 442              [ACH-000163, ACH-000716, ACH-000897, ACH-001307, ACH-001321]
# 441              [ACH-000163, ACH-000716, ACH-000897, ACH-001307, ACH-001321]
# 437              [ACH-000163, ACH-000716, ACH-000897, ACH-001306, ACH-001321]
# 439              [ACH-000163, ACH-000716, ACH-000897, ACH-001307, ACH-001321]
# 492              [ACH-000716, ACH-000897, ACH-001306, ACH-001307, ACH-001321]
#
#                                           MOA                Target(s)  \
# 436  phosphatidylglycerophosphatase inhibitor                   PTPMT1
# 442        ribonucleotide reductase inhibitor  CMPK1, RRM1, RRM2, TYMS
# 441                            HDAC inhibitor                    HDAC1
# 437    dihydroorotate dehydrogenase inhibitor                    DHODH
# 439                    NFkB pathway inhibitor                     RELA
# 492                opioid receptor antagonist                    OPRK1
#
#            Phase  \
# 436  Preclinical
# 442     Approved
# 441  Preclinical
# 437     Approved
# 439  Preclinical
# 492     Approved
#
#                                                                            FDA indication
# 436                                                                                   NaN
# 442  ovarian cancer, breast cancer, non-small cell lung cancer (NSCLC), pancreatic cancer
# 441                                                                                   NaN
# 437                                                                    multiple sclerosis
# 439                                                                                   NaN
# 492                            diarrhea, inflammatory bowel disease, giardiasis, dandruff

# %%
commonSorted.MOA.value_counts()
# Out:
# NFkB pathway inhibitor                                  7
# ribonucleotide reductase inhibitor                      5
# membrane integrity inhibitor                            4
# sodium channel blocker                                  4
# phosphodiesterase inhibitor                             3
# HDAC inhibitor                                          3
# tubulin polymerization inhibitor                        2
# tyrosine kinase inhibitor                               2
# CDK inhibitor                                           2
# p53 activator                                           2
# DNA alkylating agent, DNA inhibitor                     2
# phosphatidylglycerophosphatase inhibitor                2
# potassium channel activator                             1
# other antifungal                                        1
# cyclooxygenase inhibitor                                1
# tyrosine phosphatase inhibitor                          1
# antiprotozoal agent                                     1
# src inhibitor, syk inhibitor                            1
# DNA methyltransferase inhibitor                         1
# dihydrofolate reductase inhibitor                       1
# glutamate inhibitor                                     1
# dihydroorotate dehydrogenase inhibitor                  1
# src inhibitor                                           1
# protein synthesis inhibitor                             1
# other antibiotic                                        1
# adrenergic receptor antagonist                          1
# radiopaque medium                                       1
# purine antagonist                                       1
# JNK inhibitor                                           1
# DNA synthesis inhibitor, RNA synthesis inhibitor        1
# TRPV antagonist                                         1
# IKK inhibitor, NFkB pathway inhibitor                   1
# chelating agent, topoisomerase inhibitor                1
# serotonin receptor antagonist                           1
# eukaryotic translation elongation factor 2 inhibitor    1
# prostaglandin inhibitor                                 1
# bacterial DNA gyrase inhibitor                          1
# G protein signaling inhibitor                           1
# adrenergic receptor agonist                             1
# histone lysine methyltransferase inhibitor              1
# ubiquitin specific protease inhibitor                   1
# opioid receptor antagonist                              1
# Name: MOA, dtype: int64

# %% [markdown]
# # Explore Results

# %% [markdown]
# ## Neuroblastoma -- also need evidence of crossing BBB

# %% [markdown]
# ### BAY-11-7082

# %%
drugInfo.loc['BAY-11-7082',:]

# %% [markdown]
#  - Evidence of crossing BBB: https://www-ncbi-nlm-nih-gov.proxy.lib.ohio-state.edu/pmc/articles/PMC5845744/ (used to kill brain eating ameoba)
#
#
#  - Evidence of NFkB pathway involvement in cancer:
#      - https://www-ncbi-nlm-nih-gov.proxy.lib.ohio-state.edu/pmc/articles/PMC2869521/
#      - https://www-nature-com.proxy.lib.ohio-state.edu/articles/sigtrans201723
#      - https://www-nature-com.proxy.lib.ohio-state.edu/articles/nri.2017.142
#      - https://molecular-cancer.biomedcentral.com/articles/10.1186/1476-4598-12-86
#
#
#  - Evidence of NFkB driven Neuroblastoma:
#      - https://www-ncbi-nlm-nih-gov.proxy.lib.ohio-state.edu/pmc/articles/PMC4280060/
#
#
#  - Evidence of RELA's (drug's target) involvment in cancer development
#      - https://pubmed-ncbi-nlm-nih-gov.proxy.lib.ohio-state.edu/31382678/
#
#  - Evidence of drug + disease pathway intersection increasing survival
#      - https://www.jbc.org/article/S0021-9258(19)49039-X/fulltext

# %% [markdown]
# #### Look at RELA expression in Neuroblastoma vs rest of cancer samples

# %%
NB_cellLines = preds[preds.cancer_type == 'Neuroblastoma'].cell_line.unique().tolist()

# %%
NB_RELA_mean = newCancerRNA.loc[NB_cellLines, 'RELA'].mean()
NB_RELA_std = newCancerRNA.loc[NB_cellLines, 'RELA'].std()

print(f"Mean differential RELA expression (STD) in Neuroblastoma cell lines: {round(NB_RELA_mean, 4)} ({round(NB_RELA_std, 4)})")

# %%
nonNB_cellLines = preds[preds.cancer_type != 'Neuroblastoma'].cell_line.unique().tolist()

nonNBExpRELA = newCancerRNA.loc[nonNB_cellLines, 'RELA'].tolist()
nonNBExpRELA.extend(trainRNA.loc[:, 'RELA'].tolist())

# %%
nonNB_RELA_mean = np.mean(nonNBExpRELA)
nonNB_RELA_std = np.std(nonNBExpRELA)

print(f"Mean differential RELA expression (STD) in non-Neuroblastoma cell lines: {round(nonNB_RELA_mean, 4)} ({round(nonNB_RELA_std, 4)})")

# %% [markdown]
# ### Indisulam

# %%
drugInfo.loc['indisulam',:]

# %% [markdown]
#  - Evidence of drugs utility for treating high risk neuroblastoma: https://www-nature-com.proxy.lib.ohio-state.edu/articles/s41467-022-28907-3

# %% [markdown]
# ### NSC-319726

# %%
drugInfo.loc['NSC-319726',:]

# %% [markdown]
#  - Evidence of utility for glioblastoma: https://pubmed-ncbi-nlm-nih-gov.proxy.lib.ohio-state.edu/29576531/
#  - Evidence of targeting p53 mutations (typically associated with mechanism of resistance to therapy): https://www-sciencedirect-com.proxy.lib.ohio-state.edu/science/article/pii/S153561082030605X?via%3Dihub

# %% [markdown]
# ## Thyroid Cancer

# %% [markdown]
# ### Alexidine

# %%
drugInfo.loc['alexidine',:]

# %% [markdown]
# MOA plays role in phosphoinositide 3-kinase pathway, which mediates actions of horomones, GFs, etc
#
#  - Evidence of PI3K pathway role in thyroid cancer development: https://www-sciencedirect-com.proxy.lib.ohio-state.edu/science/article/pii/S0022227520354559
#
#  - Evidence of cancer death promotion by inhibiting gene: https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0053803
#
#  - Genetic alterations in PI3K pathway induces especially aggressive thyroid cancers: https://www-ncbi-nlm-nih-gov.proxy.lib.ohio-state.edu/pmc/articles/PMC2935335/

# %% [markdown]
# ### Teriflunomide

# %%
drugInfo.loc['teriflunomide',:]

# %% [markdown]
# - Recent evidence that targeting DHODH has potential to be effective therapeutic (especially in combination with others):
#     - https://cancerandmetabolism.biomedcentral.com/articles/10.1186/s40170-021-00250-z
#     - https://www-sciencedirect-com.proxy.lib.ohio-state.edu/science/article/pii/S0163725818301967
#
#
# - Evidence of similar drug suppressing growth of thyroid cancers
#     - https://www-ncbi-nlm-nih-gov.proxy.lib.ohio-state.edu/pmc/articles/PMC3805832/

# %% [markdown]
# ### Chloroxine

# %%
drugInfo.loc['chloroxine',:]

# %% [markdown]
# Throid stimulating horomone (TSH) binds to the thyroid stimulating horomone receptor (TSHR), which is a G-protein coupled receptor. Evidence that downregulation of GPCRs leads to thyroid cancer pathogenesis: https://pubmed-ncbi-nlm-nih-gov.proxy.lib.ohio-state.edu/34000025/. Additionally, GPCRs mediate PI3K/ATK signalling (https://www-ncbi-nlm-nih-gov.proxy.lib.ohio-state.edu/pmc/articles/PMC5207145/), and alterations to this pathway leads to thyroid cancer pathogenesis (https://www.frontiersin.org/articles/10.3389/fendo.2015.00188/full)

# %%
NB_cellLines = preds[preds.cancer_type == 'Thyroid Cancer'].cell_line.unique().tolist()

NB_RELA_mean = newCancerRNA.loc[NB_cellLines, 'OPRK1'].mean()
NB_RELA_std = newCancerRNA.loc[NB_cellLines, 'OPRK1'].std()

print(f"Mean differential OPRK1 expression (STD) in Thyroid cancer cell lines: {round(NB_RELA_mean, 4)} ({round(NB_RELA_std, 4)})")


nonNB_cellLines = preds[preds.cancer_type != 'Thyroid Cancer'].cell_line.unique().tolist()

nonNBExpRELA = newCancerRNA.loc[nonNB_cellLines, 'OPRK1'].tolist()
nonNBExpRELA.extend(trainRNA.loc[:, 'OPRK1'].tolist())

nonNB_RELA_mean = np.mean(nonNBExpRELA)
nonNB_RELA_std = np.std(nonNBExpRELA)

print(f"Mean differential OPRK1 expression (STD) in non-Thyroid cancer cell lines: {round(nonNB_RELA_mean, 4)} ({round(nonNB_RELA_std, 4)})")

# %% [markdown]
# ### Gemcitabine

# %%
drugInfo.loc['gemcitabine',:]
# Out:
# moa                            ribonucleotide reductase inhibitor
# target                                    CMPK1, RRM1, RRM2, TYMS
# disease.area                                             oncology
# indication      ovarian cancer, breast cancer, non-small cell ...
# phase                                                    Launched
# Name: gemcitabine, dtype: object

# %%
drugInfo.loc['gemcitabine',:].indication
# Out:
# 'ovarian cancer, breast cancer, non-small cell lung cancer (NSCLC), pancreatic cancer'

# %%
[g in cancerGenes for g in ['CMPK1', 'RRM1', 'RRM2', 'TYMS']]
# Out:
# [False, False, False, False]

# %%
[g in allRNA.columns.tolist() for g in ['CMPK1', 'RRM1', 'RRM2', 'TYMS']]
# Out:
# [False, False, False, False]

# %%
rep = allRNA.copy()
rep.insert(0, 'cancerType', [cellLineCancerType.get(x) for x in allRNA.index.tolist()])

A2B, A2C = sim_btwn_grps(rep, groupA=['Thyroid Cancer'], groupB=['Ovarian Cancer', 'Breast Cancer', 
                                                                 'Pancreatic Cancer', 'Lung Cancer'])

print(f"Avg similarity between indicated cancer types and Thyroid cancer: {round(np.mean(A2B), 4)} ({round(np.std(A2B), 4)})")

print(f"Avg similarity between Thyroid cancer and non-indicated cancer types: {round(np.mean(A2C), 4)} ({round(np.std(A2C), 4)})")
# Out:
# Avg similarity between indicated cancer types and Thyroid cancer: 0.0462 (0.0141)
# Avg similarity between Thyroid cancer and non-indicated cancer types: 0.0545 (0.0213)

# %% [markdown]
# Because the expression is similar, it is likely that these cancer types have similar mechanisms of pathogenesis and progression. As such, it is possible that Gemcitabine could be reporposed to treat Thyroid cancer.
#
#  - Evidence that Gemcitabine enhances the effects of radiation in patients with medullary thyroid cancer: https://pubmed-ncbi-nlm-nih-gov.proxy.lib.ohio-state.edu/31725814/

# %% [markdown]
# ## Sarcoma

# %% [markdown]
# ### tyrphostin-AG-99

# %%
drugInfo.loc['tyrphostin-AG-99',:]
# Out:
# moa             tyrosine kinase inhibitor
# target                               EGFR
# disease.area                          NaN
# indication                            NaN
# phase                         Preclinical
# Name: tyrphostin-AG-99, dtype: object

# %% [markdown]
# - Evidence of tyrosine kinase's activation in cancer:
#     - https://molecular-cancer.biomedcentral.com/articles/10.1186/s12943-018-0782-4
# - Evidence suggesting that TKIs are effective for reducing cancer growth, however often are difficult to approve due to off-target effects: https://www-nature-com.proxy.lib.ohio-state.edu/articles/s41388-021-01841-2

# %% [markdown]
# ### Ro-106-9920

# %%
drugInfo.loc['Ro-106-9920',:]
# Out:
# moa             NFkB pathway inhibitor
# target                             NaN
# disease.area                       NaN
# indication                         NaN
# phase                      Preclinical
# Name: Ro-106-9920, dtype: object

# %% [markdown]
# Can use same evidence for NFkB pathway targeting that was used for NB + BAY-11-7082

# %% [markdown]
# ### BAY-11-7082

# %% [markdown]
# ## Bone and Brain cancers

# %% [markdown]
# Like Sarcoma and Neuroblastoma, NFkB inhibitors are highly recommened, qualitatively, this is not surprising when looking at the cancer clustering. Bone, brain, NB, and sarcoma are all relatively closely grouped, which indicates that these cancers may have similar mechanisms driving pathogenesis
