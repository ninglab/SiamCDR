# %% [markdown]
# # Import

# %%
import os, joblib
import numpy as np
import pandas as pd
from math import ceil, floor
from itertools import combinations

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
plt.rcParams['font.family'] = 'Helvetica'

import seaborn as sns

from tensorflow.keras import Sequential
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.layers import Input, Concatenate

from sklearn.manifold import TSNE
from sklearn.metrics.pairwise import cosine_similarity

from scipy.stats import ttest_ind as ttest

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %% [markdown]
# ## RNA

# %%
rna = pd.read_csv('../../data/processed/cellLineEncoderPretrainData.csv', index_col=0)

# %% [markdown]
# ## Drugs

# %%
drugs = pd.read_csv('../../data/processed/drug_fingerprints.csv', index_col=0)

# %% [markdown]
# ## MOAs

# %%
cdr = pd.read_csv('../../data/processed/drugCellLinePairsData.csv')
moas = cdr.loc[:, ['name', 'moa']].drop_duplicates(keep='first')
moas.rename(columns={'name': 'drug'}, inplace=True)
moas = moas[moas.drug.isin(list(drugs.index))].set_index('drug')
moas = moas[moas.moa.isin(list(moas.moa.value_counts()[moas.moa.value_counts() >= 10].index))]

getMOA = lambda x: moas.loc[x, :][0]
drugList = list(moas.index)

# %% [markdown]
# ## Cancer types

# %%
info = pd.read_csv('../../data/processed/cellLineInfo.csv').loc[:, ['DepMap_ID', 'primary_disease']]
info = info.rename(columns={'primary_disease': 'cancer_type', 'DepMap_ID': 'cell_line'})
info = info[info.cell_line.isin(list(rna.index))].set_index('cell_line', drop=True)
getCT = lambda x: info.loc[x, :][0]

# %% [markdown]
# # Raw RNA tsne

# %%
rawTSNE = pd.DataFrame(TSNE(n_components=2, init='random').fit_transform(rna), index=rna.index)
rawTSNE.insert(0, 'cancer_type', [getCT(cellLine) for cellLine in list(rna.index)])

# %% [markdown]
# # Define funcs

# %%
def loadEncoder(path, which='rna'):
    try:
        snn = load_model(path)
        encoder = snn.get_layer('model')
        encoder._name = f'{which}Encoder'
        return encoder
    except AttributeError:
        return None

# %% [markdown]
# # RF Embeddings

# %% [markdown]
# ## RNA

# %%
rnaPath = '/fs/scratch/PCON0041/PatrickLawrence/cancer-drug-response/fewShot/cellLines/siameseV1/models/'

rnaModel = 'CellLineFewShot_Layers2_Hidden64_DO0-1_AFrelu_LR0-001_DR0-99_DS1000'
rnaPath = os.path.join(rnaPath, rnaModel)
rnaEmbed = loadEncoder(rnaPath)

# %%
rnaEmbeddings = pd.DataFrame(rnaEmbed(rna.to_numpy()), index=rna.index)
rnaEmbeddings.insert(0, 'cancer_type', [getCT(cellLine) for cellLine in list(rnaEmbeddings.index)])
rnaEmbeddings.head()
# Out:
#                         cancer_type    0    1    2    3         4    5  \
# ACH-001289                 Rhabdoid  0.0  0.0  0.0  0.0  0.000000  0.0
# ACH-001339              Skin Cancer  0.0  0.0  0.0  0.0  0.000000  0.0
# ACH-001538         Bile Duct Cancer  0.0  0.0  0.0  0.0  0.622538  0.0
# ACH-000708  Colon/Colorectal Cancer  0.0  0.0  0.0  0.0  0.000000  0.0
# ACH-000327              Lung Cancer  0.0  0.0  0.0  0.0  0.000000  0.0
#
#                    6    7    8  ...   54        55        56   57   58   59  \
# ACH-001289  0.518141  0.0  0.0  ...  0.0  0.000000  0.000000  0.0  0.0  0.0
# ACH-001339  0.000000  0.0  0.0  ...  0.0  0.000000  0.147524  0.0  0.0  0.0
# ACH-001538  0.849156  0.0  0.0  ...  0.0  1.008909  0.234708  0.0  0.0  0.0
# ACH-000708  0.893929  0.0  0.0  ...  0.0  0.000000  0.000000  0.0  0.0  0.0
# ACH-000327  0.042873  0.0  0.0  ...  0.0  0.000000  0.000000  0.0  0.0  0.0
#
#                   60   61        62   63
# ACH-001289  0.169183  0.0  0.457829  0.0
# ACH-001339  1.013961  0.0  0.000000  0.0
# ACH-001538  0.358598  0.0  0.000000  0.0
# ACH-000708  0.000000  0.0  0.000000  0.0
# ACH-000327  0.098728  0.0  0.122655  0.0
#
# [5 rows x 65 columns]

# %%
cdrTSNErna = pd.DataFrame(TSNE(n_components=2, init='random').fit_transform(rna.iloc[:, 1:]), index=rnaEmbeddings.index)
cdrTSNErna.insert(0, 'cancer_type', rnaEmbeddings.cancer_type)

# %% [markdown]
# ## Drugs

# %%
drugPath = '/fs/scratch/PCON0041/PatrickLawrence/cancer-drug-response/fewShot/drugs/siameseV1/models/'
drugModel = 'DrugFewShot_Layers1_Hidden64_DO0-1_AFrelu_LR0-001_DR0-99_DS1000'
drugPath = os.path.join(drugPath, drugModel)
drugEmbed = loadEncoder(drugPath, which='drug')

# %%
drugSubset = drugs.loc[drugList, :]
drugEmbeddings = pd.DataFrame(drugEmbed(drugSubset.to_numpy()), index=drugSubset.index)
drugEmbeddings.insert(0, 'moa', [getMOA(drug) for drug in list(drugEmbeddings.index)])
drugEmbeddings.head()
# Out:
#                                        moa    0    1         2         3  \
# belinostat                  HDAC inhibitor  0.0  0.0  4.733480  2.116385
# romidepsin                  HDAC inhibitor  0.0  0.0  5.026449  2.037010
# puromycin      protein synthesis inhibitor  0.0  0.0  0.000000  1.656208
# cycloheximide  protein synthesis inhibitor  0.0  0.0  0.881959  1.227137
# RGFP966                     HDAC inhibitor  0.0  0.0  5.520843  1.719670
#
#                       4         5         6         7         8  ...  \
# belinostat     0.000000  1.359826  0.000000  2.276699  2.795123  ...
# romidepsin     0.000000  1.293311  0.000000  2.727001  3.474960  ...
# puromycin      3.103661  0.000000  2.341359  0.000000  4.596645  ...
# cycloheximide  2.496884  0.000000  1.917890  0.000000  5.178120  ...
# RGFP966        0.000000  0.019688  0.000000  2.469327  3.348505  ...
#
#                      54        55   56        57        58   59   60  \
# belinostat     1.109962  2.636456  0.0  0.000000  0.935001  0.0  0.0
# romidepsin     0.949178  3.398749  0.0  0.009806  0.717597  0.0  0.0
# puromycin      0.000000  0.000000  0.0  0.000000  4.124204  0.0  0.0
# cycloheximide  0.000000  0.000000  0.0  0.000000  3.429098  0.0  0.0
# RGFP966        0.000000  2.458517  0.0  0.000000  1.874853  0.0  0.0
#
#                      61        62        63
# belinostat     1.395575  2.279768  2.110241
# romidepsin     1.668294  1.469026  1.555456
# puromycin      2.730622  0.000000  0.000000
# cycloheximide  2.328746  0.000000  0.000000
# RGFP966        2.042814  0.453671  2.721272
#
# [5 rows x 65 columns]

# %%
cdrTSNEdrug = pd.DataFrame(TSNE(n_components=2, init='random').fit_transform(drugEmbeddings.iloc[:, 1:]), index=drugEmbeddings.index)
cdrTSNEdrug.insert(0, 'moa', drugEmbeddings.moa)

# %% [markdown]
# ## DeepDSC

# %% [markdown]
# ### Load model

# %%
aePath = '/fs/scratch/PCON0041/PatrickLawrence/cancer-drug-response/autoencoders/RNA-batchcorrect'
aeModel = 'Encoder_Hidden_64_32_AFlkyu_LR1e-05_DR99_DS10_GC1'
aePath = os.path.join(aePath, aeModel)

AE = load_model(aePath)
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
dscEmbeddings = pd.DataFrame(AE(rna.to_numpy()), index=rna.index)
dscEmbeddings.insert(0, 'cancer_type', [getCT(cellLine) for cellLine in list(dscEmbeddings.index)])
dscEmbeddings.head()
# Out:
#                         cancer_type          0         1         2          3  \
# ACH-001289                 Rhabdoid  21.560524 -4.600863 -5.601335  14.959680
# ACH-001339              Skin Cancer  22.892403 -4.922985 -6.977116  11.705415
# ACH-001538         Bile Duct Cancer  26.289768 -3.466034 -8.066165  15.369724
# ACH-000708  Colon/Colorectal Cancer  23.243246 -3.256840 -7.324371  12.940812
# ACH-000327              Lung Cancer  24.209332 -5.978451 -6.918748  16.259144
#
#                     4          5          6         7          8  ...  \
# ACH-001289  84.007286  39.670219 -25.901674 -1.622540 -14.493036  ...
# ACH-001339  89.637764  38.319714 -25.736265 -1.172204 -15.489100  ...
# ACH-001538  81.841827  41.446384 -26.197708 -2.637902 -13.696660  ...
# ACH-000708  81.453018  40.333603 -25.441477 -1.869221 -14.233493  ...
# ACH-000327  83.902298  38.851749 -25.293184 -1.423608 -14.456236  ...
#
#                    22        23          24         25        26         27  \
# ACH-001289  31.515160 -7.084526   99.437477  -9.614636 -2.213378  32.522522
# ACH-001339  36.401066 -7.141747  105.290337 -10.784549 -2.682678  35.794403
# ACH-001538  35.381786 -7.055945   98.223480 -10.750059 -2.936413  38.123817
# ACH-000708  34.467007 -6.987257   97.587662 -10.636830 -2.616166  36.374592
# ACH-000327  35.260906 -6.973253  100.115334 -10.110357 -2.224427  35.100475
#
#                    28         29         30        31
# ACH-001289  48.142254  31.854723  68.153740 -4.651627
# ACH-001339  52.787197  35.410877  74.957336 -5.482809
# ACH-001538  44.005596  34.194675  64.135338 -4.944628
# ACH-000708  46.771610  34.100342  63.628464 -4.908471
# ACH-000327  46.667641  32.247635  66.023582 -4.049247
#
# [5 rows x 33 columns]

# %%
dscTSNE = pd.DataFrame(TSNE(n_components=2, init='random').fit_transform(dscEmbeddings.iloc[:, 1:]), index=dscEmbeddings.index)
dscTSNE.insert(0, 'cancer_type', dscEmbeddings.cancer_type)

# %%
drugTSNE = pd.DataFrame(TSNE(n_components=2, init='random').fit_transform(drugSubset), index=drugSubset.index)
drugTSNE.insert(0, 'moa', [getMOA(drug) for drug in list(drugSubset.index)])

# %% [markdown]
# # Embedding dicts

# %%
embeddings = {'DeepDSC cell line AE': dscEmbeddings,
              'Cell line SNN': rnaEmbeddings,
              'Morgan fingerprints': drugSubset,
              'Drug SNN': drugEmbeddings}

tsnes = {'DeepDSC cell line AE': dscTSNE,
         'Cell line SNN': cdrTSNErna,
         'Morgan fingerprints': drugTSNE,
         'Drug SNN': cdrTSNEdrug}

# %% [markdown]
# # Similarities

# %%
def sim_by_type(rep, tsne, sim, cnt=5):
    intra_avgs = []
    inter_avgs = []
    common_cancers = tsne.iloc[:, 0].value_counts()[tsne.iloc[:, 0].value_counts() > cnt].index.tolist()
    for ct in common_cancers:
        intra = rep[(tsne.iloc[:, 0] == ct)].index.tolist()
        inter = rep[(tsne.iloc[:, 0] != ct)].index.tolist()

        n_intra = 0
        intra_sum = 0
        for i, j in combinations(intra, 2):
            n_intra += 1
            intra_sum += sim.loc[i, j]

        intra_avgs.append(intra_sum / n_intra)

        n_inter = 0
        inter_sum = 0
        for i, j in combinations(inter, 2):
            n_inter += 1
            inter_sum += sim.loc[i, j]

        inter_avgs.append(inter_sum / n_inter)

    return pd.DataFrame({'intra_avg_sim': intra_avgs, 'inter_avg_sim': inter_avgs}, index=common_cancers)

# %% [markdown]
# ## Raw rna sim

# %%
rawSim = cosine_similarity(rna)
rawSim = pd.DataFrame(rawSim, index=rna.index, columns=rna.index)

# %%
rawAvgSim = sim_by_type(rna, rawTSNE, rawSim, 5)
rawAvgSim['diff'] = rawAvgSim.intra_avg_sim / rawAvgSim.inter_avg_sim

# %%
rawAvgSim.head()
# Out:
#                          intra_avg_sim  inter_avg_sim      diff
# Lung Cancer                   0.952152       0.934062  1.019367
# Leukemia                      0.949659       0.938720  1.011653
# Lymphoma                      0.945193       0.939264  1.006312
# Brain Cancer                  0.959541       0.934911  1.026344
# Colon/Colorectal Cancer       0.966308       0.934634  1.033889

# %% [markdown]
# ## Model embedding sims

# %%
sims = {}
for e, rep in embeddings.items():
    sim = cosine_similarity(rep.iloc[:, 1:])
    sims[e] = pd.DataFrame(sim, index=rep.index, columns=rep.index)

# %%
avgSims = {}
for e, rep in embeddings.items():
    if ('drug' in e.lower()) | ('fingerprint' in e.lower()):
        cnt = 10
    else:
        cnt = 5
    df = sim_by_type(rep, tsnes[e], sims[e], cnt)
    df['diff'] = df.intra_avg_sim / df.inter_avg_sim
    avgSims[e] = df

# %%
pairs = [('DeepDSC cell line AE', 'Cell line SNN'),
         ('Morgan fingerprints', 'Drug SNN')]

# %%
for (p1, p2) in pairs:
    s1 = avgSims[p1]; s2 = avgSims[p2]
    d1 = s1['diff'].mean(); d2 = s2['diff'].mean()
    pval = ttest(s1['diff'], s2['diff']).pvalue
    sim1 = s1.intra_avg_sim.mean(); sim2 = s2.intra_avg_sim.mean()
    
    print(f'{p1} avg intra-group sim: {sim1}')
    print(f'{p1} avg inter-group sep: {d1}\n')
    print(f'{p2} avg intra-group sim: {sim2}')
    print(f'{p2} avg inter-group sep: {d2}\n')
    
    print(f"Percent improvement in intra-group similarity of {p2} over {p1}: {round(((sim2-sim1)/sim1)*100,2)}%")
    print(f"Percent improvement in intra-group vs inter-group difference of {p2} over {p1}: {round(((d2-d1)/d1)*100,2)}%",\
          f"(p-value: {pval})\n")
# Out:
# DeepDSC cell line AE avg intra-group sim: 0.9993848488648149
# DeepDSC cell line AE avg inter-group sep: 1.0002830101917621
#
# Cell line SNN avg intra-group sim: 0.9109291947558863
# Cell line SNN avg inter-group sep: 1.7708200443306887
#
# Percent improvement in intra-group similarity of Cell line SNN over DeepDSC cell line AE: -8.85%
# Percent improvement in intra-group vs inter-group difference of Cell line SNN over DeepDSC cell line AE: 77.03% (p-value: 2.789486708122086e-29)
#
# Morgan fingerprints avg intra-group sim: 0.40533333845122504
# Morgan fingerprints avg inter-group sep: 1.1927522629742386
#
# Drug SNN avg intra-group sim: 0.7681113135314075
# Drug SNN avg inter-group sep: 1.9182157806086917
#
# Percent improvement in intra-group similarity of Drug SNN over Morgan fingerprints: 89.5%
# Percent improvement in intra-group vs inter-group difference of Drug SNN over Morgan fingerprints: 60.82% (p-value: 3.168137281033167e-06)

# %% [markdown]
# ## Raw

# %%
rawD = rawAvgSim['diff']
rawS = rawAvgSim.intra_avg_sim
print(f"Raw intra-group sim: {rawS.mean()}")
print(f"Raw inter-group sep: {rawD.mean()}")
# Out:
# Raw intra-group sim: 0.958385469152183
# Raw inter-group sep: 1.0244591088473225

# %%
def getPChng(sim):
    s = avgSims[sim]
    sD = s['diff']
    sS = s.intra_avg_sim
    
    intraChng = 100 * ((sS.mean() - rawS.mean()) / rawS.mean())
    intraP = ttest(sS, rawS).pvalue
    interChng = 100 * ((sD.mean() - rawD.mean()) / rawD.mean())
    interP = ttest(sD, rawD).pvalue
    
    print(f"%Change (Intra-Sim): {round(intraChng, 2)} (p={intraP})")
    print(f"%Change (Intra-Sep): {round(interChng, 2)} (p={interP})")

# %% [markdown]
# ## DSC vs. Raw

# %%
getPChng('DeepDSC cell line AE')
# Out:
# %Change (Intra-Sim): 4.28 (p=3.4372298038723836e-34)
# %Change (Intra-Sep): -2.36 (p=1.0790272976144347e-20)

# %% [markdown]
# ## FS-CDR vs. Raw

# %%
getPChng('Cell line SNN')
# Out:
# %Change (Intra-Sim): -4.95 (p=0.008690202603435561)
# %Change (Intra-Sep): 72.85 (p=1.3382676087897975e-28)

# %% [markdown]
# # Save t-SNE's

# %%
joblib.dump(tsnes, './tsneDFs.joblib')
# Out:
# ['./tsneDFs.joblib']

# %% [markdown]
# # Create tsne plots

# %%
tsnes = joblib.load('./tsneDFs.joblib')

# %%
def getPalette(opts):
    shapeOpts = ['X', 's', '^', 'p']
#     shapeOpts = ['+', 'x', '3', '$\dagger$']
    while len(shapeOpts) < len(opts):
        shapeOpts.extend(shapeOpts)
    colorOpts = sns.color_palette('husl', n_colors=len(opts))
    optDict = {}
    for i, opt in enumerate(opts):
        try:
            optDict[opt] = (shapeOpts[i], colorOpts[i])
        except ZeroDivisionError:
            optDict[opt] = (shapeOpts[0], colorOpts[0])
        
    return optDict

# %%
cl = 'Cell line SNN'
cTypesPlotSubset = list(tsnes[cl].cancer_type.value_counts()[tsnes[cl].cancer_type.value_counts() >= 15].index)

# %%
# define stylistic settings
sns.set_theme()
sns.set_context("paper")
sns.set(font_scale = 2.25)
rc = {'axes.facecolor': 'white',
      'axes.grid': True,
      'grid.color': '0.8',
      'font.family': 'sans-serif',
      'font.sans-serif': 'Helvetica',
      'axes.unicode_minus': False}
plt.rcParams.update(rc)

# create blank figure
fig, ax = plt.subplots(2, 2, sharex='none', sharey='none', 
                       figsize=(35,20), constrained_layout=True)

# iterate through each tsne embedding
for i, (name, vals) in enumerate(tsnes.items()):
    vals = vals.copy().rename(columns={0:'ft1', 1:'ft2'}) # rename tsne cols
    
    # Define ax specific conditions
    if i < 2: 
        r = 0; c = i; col = 'cancer_type'; alpha=0.5; size=180; facecolor='white'
        vals = vals[vals[col].isin(cTypesPlotSubset)]       
    else: 
        r = 1; c = i - 2; col = 'moa'; alpha=0.75; size=220; facecolor='lightgrey'
        
    # Define colors
    colors = []       
    opts = getPalette(list(vals[col].unique()))
    for g in vals[col]:
        try: 
            h = opts[g][1]
        except KeyError:
            h = 'lightgray'
        colors.append(h)
    vals['color'] = colors
        
    # Get subplot
    subplt = ax[r][c]
    
    # plot each group with marker / color combo
    for ct, subvals in vals.groupby(by=col):
        subplt.scatter(y=subvals.ft2, x=subvals.ft1, 
                       edgecolor=subvals.color, facecolor=facecolor, marker=opts[ct][0], 
                       s=size, linewidth=2.5, alpha=alpha, label=ct)
        
#     if i == 3:
#         keyDrugs = ['brefeldin-a', 'CUDC-907', 'YM-201636', 'BNC105']
#         subsub = vals[vals.index.isin(keyDrugs)]
#         subplt.scatter(y=subsub.ft2, x=subsub.ft1, 
#                        edgecolor=subvals.color, facecolor='red', marker=opts[ct][0], 
#                        s=size, linewidth=2.5, alpha=alpha, label=ct)
    
    # Remove single cell line outlier for FS-RF
    if i == 1:
        subplt.set_ylim(-50, 50)
        subplt.set_xlim(-37, 40)
    
    # define which gets legend
    if i in [1,3]:
        if '_' in col:
            legTitle = 'Cell line ' + " ".join(col.split('_'))
            a1 = 1.825; a2 = 0.71; nc = 2
        else:
            legTitle = 'Drug mechanism of action'
            a1 = 1.525; a2 = 0.5; nc = 1
        subplt.legend(title=legTitle, title_fontsize=30,
                      loc=7, bbox_to_anchor=(a1, a2), 
                      markerscale=2, ncol=nc, columnspacing=0.65)
    # Format subplots
#     subplt.set_xticks([])
#     subplt.set_yticks([])
    for border in ['top', 'bottom', 'left', 'right']:
        subplt.spines[border].set_visible(True)
        subplt.spines[border].set_color("0.4")
        subplt.spines[border].set_linewidth(1)
        
ax[0][0].text(-66.5, 24.25, 'a', color='black', weight='bold', fontsize=40)
ax[0][0].text(-2, 28.5, 'DeepDSC', color='black', fontsize=30, horizontalalignment='center')
ax[0][0].text(-66.5, -3, 'Cell line embeddings', color='black', fontsize=30, 
              rotation='vertical', verticalalignment='center')

ax[0][1].text(-40, 45, 'b', color='black', weight='bold', fontsize=40)
ax[0][1].text(1.5, 52, 'FS-CDR', color='black', fontsize=30, horizontalalignment='center')

ax[1][0].text(-24, 22.3, 'e', color='black', weight='bold', fontsize=40)
ax[1][0].text(-24.1, 0, 'Drug embeddings', color='black', fontsize=30, 
              rotation='vertical', verticalalignment='center')

ax[1][1].text(-25, 10, 'f', color='black', weight='bold', fontsize=40)

# plt.savefig("./figure4.pdf", dpi=1200, bbox_inches="tight")
plt.show()

# %%
# Load data
col='cancer_type' 
vals = tsnes['Cell line SNN'].copy().rename(columns={0:'ft1', 1:'ft2'})
vals = vals[vals[col].isin(cTypesPlotSubset)]

# Define colors
colors = []       
opts = getPalette(list(vals[col].unique()))
for g in vals[col]:
    try: 
        h = opts[g][1]
    except KeyError:
        h = 'lightgray'
    colors.append(h)
vals['color'] = colors

# Basic params
alpha=0.5
size=180

# %%
fig, ax = plt.subplots(1, 1, figsize=(5,4))

for ct, subvals in vals.groupby(by=col):
    ax.scatter(y=subvals.ft2, x=subvals.ft1, 
                edgecolor=subvals.color, facecolor='white', marker=opts[ct][0], 
                s=size, linewidth=2.5, alpha=alpha, label=ct)
    
ax.set_xlim(-35.7,-25.5)
ax.set_xticks([])
ax.set_ylim(-7.5, 0.3)
ax.set_yticks([])

for border in ['top', 'bottom', 'left', 'right']:
    ax.spines[border].set_visible(True)
    ax.spines[border].set_color("#377eb8")
    ax.spines[border].set_linewidth(1.5)
    
ax.text(-36.3, -0.1, 'c', color='black', weight='bold', fontsize=20)
ax.text(-32.35, -7.3, 'Cluster 2', fontsize=20, color="#377eb8")

plt.savefig("./figure4_cluster2.pdf", dpi=1200, bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(5,4))

vals = vals[~((vals.ft1 < -8) & (vals.ft2 > -22))]

for ct, subvals in vals.groupby(by=col):
    ax.scatter(y=subvals.ft2, x=subvals.ft1, 
                edgecolor=subvals.color, facecolor='white', marker=opts[ct][0], 
                s=size, linewidth=2.5, alpha=alpha, label=ct)
    
ax.set_xlim(-11, 1)
ax.set_xticks([])
ax.set_ylim(-33.5, -15)
ax.set_yticks([])

for border in ['top', 'bottom', 'left', 'right']:
    ax.spines[border].set_visible(True)
    ax.spines[border].set_color("#4daf4a")
    ax.spines[border].set_linewidth(1.5)
    
ax.text(-11.7, -16.3, 'd', color='black', weight='bold', fontsize=20)
ax.text(-6.85, -33, 'Cluster 3', fontsize=20, color="#4daf4a")

plt.savefig("./figure4_cluster3.pdf", dpi=1200, bbox_inches="tight")
plt.show()

# %%
t = tsnes['Drug SNN']

# %%
t.moa.unique()
# Out:
# array(['HDAC inhibitor', 'protein synthesis inhibitor', 'PI3K inhibitor',
#        'topoisomerase inhibitor', 'histamine receptor antagonist',
#        'mTOR inhibitor', 'tubulin polymerization inhibitor',
#        'HSP inhibitor', 'EGFR inhibitor',
#        'adrenergic receptor antagonist', 'cyclooxygenase inhibitor',
#        'glucocorticoid receptor agonist', 'MEK inhibitor',
#        'CDK inhibitor', 'adrenergic receptor agonist',
#        'Aurora kinase inhibitor'], dtype=object)

# %% [markdown]
# ## Examine classification of NAs

# %%
tsneDrugs = list(t.index)
moas = ['PI3K inhibitor', 'mTOR inhibitor', 'EGFR inhibitor', 
        'CDK inhibitor', 'glucocorticoid receptor agonist',
        'Aurora kinase inhibitor', 'tubulin polymerization inhibitor',
        'HDAC inhibitor']
cdrSegMOA = cdr[cdr.name.isin(tsneDrugs) & (cdr.moa.isin(moas))].loc[:, ['name', 'moa', 'target', 'indication']].drop_duplicates(keep='first')
cdrSegMOA
# Out:
#              name                               moa  \
# 347    belinostat                    HDAC inhibitor
# 387    romidepsin                    HDAC inhibitor
# 1101      RGFP966                    HDAC inhibitor
# 1662       PI-828                    PI3K inhibitor
# 3017        PP242                    mTOR inhibitor
# ...           ...                               ...
# 58123  poziotinib                    EGFR inhibitor
# 58511   tucatinib                    EGFR inhibitor
# 58512   vindesine  tubulin polymerization inhibitor
# 60060   PI3K-IN-2                    PI3K inhibitor
# 60337   verubulin  tubulin polymerization inhibitor
#
#                                                   target  \
# 347    HDAC1, HDAC10, HDAC11, HDAC2, HDAC3, HDAC4, HD...
# 387    HDAC1, HDAC2, HDAC3, HDAC4, HDAC5, HDAC6, HDAC...
# 1101                                               HDAC3
# 1662                                                 NaN
# 3017                                          MTOR, PASK
# ...                                                  ...
# 58123                                 EGFR, ERBB2, ERBB4
# 58511                                              ERBB2
# 58512                                        TUBB, TUBB1
# 60060                                                NaN
# 60337                                               TUBB
#
#                                               indication
# 347                    peripheral T-cell lymphoma (PTCL)
# 387                     cutaneous T-cell lymphoma (CTCL)
# 1101                                                 NaN
# 1662                                                 NaN
# 3017                                                 NaN
# ...                                                  ...
# 58123                                                NaN
# 58511                                                NaN
# 58512  breast cancer, non-small cell lung cancer (NSC...
# 60060                                                NaN
# 60337                                                NaN
#
# [157 rows x 4 columns]

# %%
cdrSegMOA[cdrSegMOA.target.isna()]
# Out:
#                      name                               moa target indication
# 1662               PI-828                    PI3K inhibitor    NaN        NaN
# 11392           indibulin  tubulin polymerization inhibitor    NaN        NaN
# 30476          plinabulin  tubulin polymerization inhibitor    NaN        NaN
# 34680           YM-201636                    PI3K inhibitor    NaN        NaN
# 36011  combretastatin-A-4  tubulin polymerization inhibitor    NaN        NaN
# 38922         pilaralisib                    PI3K inhibitor    NaN        NaN
# 40668           TG-100713                    PI3K inhibitor    NaN        NaN
# 41561               M-344                    HDAC inhibitor    NaN        NaN
# 45831             R306465                    HDAC inhibitor    NaN        NaN
# 47585          taltobulin  tubulin polymerization inhibitor    NaN        NaN
# 54653              BNC105  tubulin polymerization inhibitor    NaN        NaN
# 60060           PI3K-IN-2                    PI3K inhibitor    NaN        NaN

# %%
# compare PI3K center
t[(t.moa == 'PI3K inhibitor') & (~t.index.isin(['PI-828', 'YM-201636', 'pilaralisib', 'PI3K-IN-2', 'TG-100713', 'CUDC-907']))].mean()
# Out:
# 0   -19.547571
# 1    -4.192241
# dtype: float32

# %%
t[(t.moa == 'PI3K inhibitor') & (t.index.isin(['PI-828', 'YM-201636', 'pilaralisib', 'PI3K-IN-2', 'TG-100713']))]
# Out:
#                         moa          0         1
# PI-828       PI3K inhibitor   4.013199 -1.770302
# YM-201636    PI3K inhibitor -20.727577 -3.413701
# pilaralisib  PI3K inhibitor   0.916255  4.096707
# TG-100713    PI3K inhibitor   4.161310 -1.967589
# PI3K-IN-2    PI3K inhibitor  -0.378229  4.394473

# %%
# compare PI3K center
t[(t.moa == 'tubulin polymerization inhibitor') & (~t.index.isin(['indibulin', 'plinabulin', 'taltobulin', 'BNC105', 'nocodazole', 'combretastatin-A-4']))].mean()
# Out:
# 0    4.001436
# 1   -8.989261
# dtype: float32

# %%
t[(t.moa == 'tubulin polymerization inhibitor') & (t.index.isin(['indibulin', 'plinabulin', 'taltobulin', 'BNC105']))]
# Out:
#                                          moa         0         1
# indibulin   tubulin polymerization inhibitor  0.055814  2.801407
# plinabulin  tubulin polymerization inhibitor  4.024914 -2.589196
# taltobulin  tubulin polymerization inhibitor  4.919209 -0.992286
# BNC105      tubulin polymerization inhibitor  4.939353 -8.897046

# %% [markdown]
# ## Examine protein synthesis w/ tubulin polymerization inhibitors

# %%
subset = t[((t[0] < 5) & (t[0] > 0)) & (t[1] < -5)]

# %%
drugSubset = list(subset.index)
subset.sort_values(by='moa').head(10)
# Out:
#                                                     moa         0         1
# brefeldin-a                 protein synthesis inhibitor  3.436090 -6.196681
# clindamycin-phosphate       protein synthesis inhibitor  3.688029 -6.929410
# methacycline                protein synthesis inhibitor  3.578050 -6.752577
# parbendazole           tubulin polymerization inhibitor  4.226462 -9.370715
# BNC105                 tubulin polymerization inhibitor  4.939353 -8.897046
# CYT-997                tubulin polymerization inhibitor  3.960062 -8.720332
# flubendazole           tubulin polymerization inhibitor  3.812800 -9.265142
# dolastatin-10          tubulin polymerization inhibitor  4.031003 -8.949802
# vincristine            tubulin polymerization inhibitor  3.972488 -8.595027
# oxibendazole           tubulin polymerization inhibitor  4.362323 -9.438025

# %%
cdrSub = cdr[cdr.name.isin(drugSubset)].loc[:, ['name', 'moa', 'target', 'indication', 'phase']].drop_duplicates(keep='first')
cdrSub = cdrSub.sort_values(by='moa')
cdrSub
# Out:
#                         name                               moa  \
# 53476            brefeldin-a       protein synthesis inhibitor
# 38812  clindamycin-phosphate       protein synthesis inhibitor
# 29011           methacycline       protein synthesis inhibitor
# 3343            parbendazole  tubulin polymerization inhibitor
# 54653                 BNC105  tubulin polymerization inhibitor
# 53320                CYT-997  tubulin polymerization inhibitor
# 38628           flubendazole  tubulin polymerization inhibitor
# 37680          dolastatin-10  tubulin polymerization inhibitor
# 36536            vincristine  tubulin polymerization inhibitor
# 33726           oxibendazole  tubulin polymerization inhibitor
# 27489            albendazole  tubulin polymerization inhibitor
# 15895            mebendazole  tubulin polymerization inhibitor
# 13889           fenbendazole  tubulin polymerization inhibitor
# 11100                ABT-751  tubulin polymerization inhibitor
# 5755              paclitaxel  tubulin polymerization inhibitor
# 5529             vinorelbine  tubulin polymerization inhibitor
# 4753               docetaxel  tubulin polymerization inhibitor
# 58512              vindesine  tubulin polymerization inhibitor
# 60337              verubulin  tubulin polymerization inhibitor
#
#                                                   target  \
# 53476                                        ARF1, CYTH2
# 38812                                                NaN
# 29011                                                NaN
# 3343                                                TUBB
# 54653                                                NaN
# 53320                                               TUBB
# 38628                                               TUBB
# 37680                                               TUBB
# 36536                                       TUBA4A, TUBB
# 33726                                       TUBB, TUBB4B
# 27489                               TUBA1A, TUBB, TUBB4B
# 15895                               TUBA1A, TUBB, TUBB4B
# 13889                                               TUBB
# 11100                                               TUBB
# 5755    BCL2, MAP2, MAP4, MAPT, NR1I2, TLR4, TUBB, TUBB1
# 5529   TUBA1A, TUBA1B, TUBA1C, TUBA3C, TUBA3D, TUBA3E...
# 4753          BCL2, MAP2, MAP4, MAPT, NR1I2, TUBB, TUBB1
# 58512                                        TUBB, TUBB1
# 60337                                               TUBB
#
#                                               indication        phase
# 53476                                                NaN  Preclinical
# 38812                                bacterial vaginosis     Launched
# 29011                                         bronchitis     Launched
# 3343                                                 NaN  Preclinical
# 54653                                                NaN      Phase 2
# 53320                                                NaN      Phase 2
# 38628                         gastrointestinal parasites     Launched
# 37680                                                NaN      Phase 2
# 36536                 acute lymphoblastic leukemia (ALL)     Launched
# 33726                                         strongyles     Launched
# 27489  cystic hydatid disease, parenchymal neurocysti...     Launched
# 15895            pinworm, whipworm, hookworm, ascariasis     Launched
# 13889  gastrointestinal parasites, gastrointestinal r...     Launched
# 11100                                                NaN      Phase 2
# 5755   ovarian cancer, breast cancer, non-small cell ...     Launched
# 5529                  non-small cell lung cancer (NSCLC)     Launched
# 4753   breast cancer, non-small cell lung cancer (NSC...     Launched
# 58512  breast cancer, non-small cell lung cancer (NSC...     Launched
# 60337                                                NaN      Phase 2

# %%
cdrSub[(cdrSub.name == 'vinorelbine')].target
# Out:
# 5529    TUBA1A, TUBA1B, TUBA1C, TUBA3C, TUBA3D, TUBA3E...
# Name: target, dtype: object

# %%
cdrSub.iloc[-4, 2]
# Out:
# 'TUBA1A, TUBA1B, TUBA1C, TUBA3C, TUBA3D, TUBA3E, TUBA4A, TUBB, TUBB1, TUBB2A, TUBB2B, TUBB3, TUBB4A, TUBB4B, TUBB6, TUBB8'

# %%
cdr[cdr.name == 'brefeldin-a'].sort_values(by='effectiveCont', ascending=False).head(15)
# Out:
#         DepMap_ID           cancer_type         name  \
# 53498  ACH-000620          Liver Cancer  brefeldin-a
# 53627  ACH-000553           Lung Cancer  brefeldin-a
# 53488  ACH-000856         Breast Cancer  brefeldin-a
# 53557  ACH-000086           Lung Cancer  brefeldin-a
# 53561  ACH-000566        Bladder Cancer  brefeldin-a
# 53558  ACH-000762  Head and Neck Cancer  brefeldin-a
# 53526  ACH-000292           Lung Cancer  brefeldin-a
# 53544  ACH-001318          Liver Cancer  brefeldin-a
# 53605  ACH-000962        Ovarian Cancer  brefeldin-a
# 53592  ACH-000966        Ovarian Cancer  brefeldin-a
# 53505  ACH-000456        Thyroid Cancer  brefeldin-a
# 53554  ACH-000549  Head and Neck Cancer  brefeldin-a
# 53585  ACH-000968           Skin Cancer  brefeldin-a
# 53528  ACH-000569           Lung Cancer  brefeldin-a
# 53510  ACH-000948        Gastric Cancer  brefeldin-a
#
#                                moa       target indication        phase  \
# 53498  protein synthesis inhibitor  ARF1, CYTH2        NaN  Preclinical
# 53627  protein synthesis inhibitor  ARF1, CYTH2        NaN  Preclinical
# 53488  protein synthesis inhibitor  ARF1, CYTH2        NaN  Preclinical
# 53557  protein synthesis inhibitor  ARF1, CYTH2        NaN  Preclinical
# 53561  protein synthesis inhibitor  ARF1, CYTH2        NaN  Preclinical
# 53558  protein synthesis inhibitor  ARF1, CYTH2        NaN  Preclinical
# 53526  protein synthesis inhibitor  ARF1, CYTH2        NaN  Preclinical
# 53544  protein synthesis inhibitor  ARF1, CYTH2        NaN  Preclinical
# 53605  protein synthesis inhibitor  ARF1, CYTH2        NaN  Preclinical
# 53592  protein synthesis inhibitor  ARF1, CYTH2        NaN  Preclinical
# 53505  protein synthesis inhibitor  ARF1, CYTH2        NaN  Preclinical
# 53554  protein synthesis inhibitor  ARF1, CYTH2        NaN  Preclinical
# 53585  protein synthesis inhibitor  ARF1, CYTH2        NaN  Preclinical
# 53528  protein synthesis inhibitor  ARF1, CYTH2        NaN  Preclinical
# 53510  protein synthesis inhibitor  ARF1, CYTH2        NaN  Preclinical
#
#              r2      ic50       auc  lower_limit  effectiveCont  effective
# 53498  0.829014  0.107756  0.533150     0.000030      12.128464          1
# 53627  0.753344  0.388010  0.665182     0.000069      10.291199          1
# 53488  0.822509  0.116874  0.541594     0.000206      10.134817          1
# 53557  0.717198  0.092082  0.517085     0.000375       9.745299          1
# 53561  0.753681  0.116564  0.541390     0.000367       9.561590          1
# 53558  0.716949  0.119303  0.544119     0.001163       8.389957          1
# 53526  0.855217  0.067332  0.485809     0.002957       7.963516          1
# 53544  0.804342  0.106741  0.533806     0.003639       7.348255          1
# 53605  0.747717  0.155008  0.571788     0.002895       7.259921          0
# 53592  0.799249  0.257205  0.623502     0.002066       7.194829          0
# 53505  0.760688  0.123680  0.549147     0.004150       7.090829          0
# 53554  0.706360  0.112679  0.539872     0.004785       7.029191          0
# 53585  0.850144  0.053327  0.465160     0.009831       6.987659          0
# 53528  0.755318  0.140432  0.562070     0.004345       6.937716          0
# 53510  0.711937  0.076450  0.501251     0.007492       6.926697          0

# %% [markdown]
# ## Examine PSI with adrenergic cluster

# %%
subset2 = t[((t[0] > 2) & (t[0] < 4)) & ((t[1] > -2) & (t[1] < 0))]

# %%
subset2.sort_values(by='moa')
# Out:
#                                              moa         0         1
# suxibuzone              cyclooxygenase inhibitor  3.955663 -1.321134
# sulfasalazine           cyclooxygenase inhibitor  3.595912 -0.481123
# aspirin                 cyclooxygenase inhibitor  3.281117 -0.190366
# phenazone               cyclooxygenase inhibitor  2.908724 -0.613803
# naproxen                cyclooxygenase inhibitor  2.827822 -0.660513
# ketoprofen              cyclooxygenase inhibitor  2.887695 -0.700749
# amfenac                 cyclooxygenase inhibitor  2.997747 -0.728369
# meloxicam               cyclooxygenase inhibitor  2.906686 -0.655599
# FK-3311                 cyclooxygenase inhibitor  2.824632 -0.588283
# tedizolid-phosphate  protein synthesis inhibitor  3.795045 -0.249517

# %%
drugSubset2 = list(subset2.index)
cdrSub2 = cdr[cdr.name.isin(drugSubset2)].loc[:, ['name', 'moa', 'target', 'indication', 'phase']].drop_duplicates(keep='first')
cdrSub2 = cdrSub2.sort_values(by='moa', ascending=False)
cdrSub2
# Out:
#                       name                          moa  \
# 58178  tedizolid-phosphate  protein synthesis inhibitor
# 5514            suxibuzone     cyclooxygenase inhibitor
# 14192        sulfasalazine     cyclooxygenase inhibitor
# 14207              aspirin     cyclooxygenase inhibitor
# 14273            phenazone     cyclooxygenase inhibitor
# 14704             naproxen     cyclooxygenase inhibitor
# 27364           ketoprofen     cyclooxygenase inhibitor
# 32155              amfenac     cyclooxygenase inhibitor
# 33213            meloxicam     cyclooxygenase inhibitor
# 49348              FK-3311     cyclooxygenase inhibitor
#
#                                                   target  \
# 58178                                                NaN
# 5514                                                 NaN
# 14192  ACAT1, ALOX5, CHUK, IKBKB, PLA2G1B, PPARG, PTG...
# 14207  AKR1C1, ASIC3, EDNRA, HSPA5, IKBKB, NFKB1, NFK...
# 14273                                       PTGS1, PTGS2
# 14704                                       PTGS1, PTGS2
# 27364                        CXCR1, PTGS1, PTGS2, SLC5A8
# 32155                                       PTGS1, PTGS2
# 33213                                       PTGS1, PTGS2
# 49348                                              PTGS2
#
#                                               indication     phase
# 58178                                    skin infections  Launched
# 5514                             joint pain, muscle pain  Launched
# 14192                                 ulcerative colitis  Launched
# 14207            headache, fever, toothache, muscle pain  Launched
# 14273                                        pain relief  Launched
# 14704  pain relief, rheumatoid arthritis, headache, t...  Launched
# 27364               rheumatoid arthritis, osteoarthritis  Launched
# 32155                                        pain relief  Launched
# 33213               osteoarthritis, rheumatoid arthritis  Launched
# 49348                                                NaN   Phase 2

# %%
for c in cdrSub2.target:
    print(c+'\n')
# Out:
# RPS2
#
# ADRB1, ADRB2
#
# ADRB1
#
# ADRA1A, ADRA1B, ADRA1D, ADRA2A, ADRA2B, ADRA2C, ADRB1, ADRB2, ADRB3, GJA1, HIF1A, KCNH2, NDUFC2, NPPB, SELE, VCAM1, VEGFA
#
# ADRB1, ADRB2, ADRB3
#
# ADRB1, ADRB2, HTR1A, HTR1B, HTR2A, HTR2B
#
# ADRA2A
#
# ADRB2
#
# ADRB2
#
# ADRB2
#
# ADRB1, ADRB2, ADRB3, NGF, TNF
#
# ADRA1A, ADRA1B, ADRA1D, ADRA2A, ADRA2B, ADRA2C, ADRB1, ADRB2, ADRB3, PAH, SLC18A1, SLC18A2
#
# ADRA2A, ADRA2B, ADRA2C, DDC

# %%
cdrNoNA = cdr[~cdr.target.isna()]
slc = cdrNoNA[cdrNoNA.target.str.startswith('RPS')].loc[:, ['name', 'moa', 'target']].drop_duplicates(keep='first')
slcDrugs = list(slc.name)
slc
# Out:
#            name                          moa  \
# 10045   emetine  protein synthesis inhibitor
# 44722  BI-D1870  ribosomal protein inhibitor
#
#                                    target
# 10045                                RPS2
# 44722  RPS6KA1, RPS6KA2, RPS6KA3, RPS6KA6

# %%
slcFPS = drugs[drugs.index.isin(slcDrugs)]
slcEmbeddings = pd.DataFrame(drugEmbed(slcFPS.to_numpy()), index=slcFPS.index)
slcEmbeddings
# Out:
#                    0         1         2         3         4         5   \
# anguidine         0.0  0.000000  3.675644  1.931502  0.000000  0.000000
# streptozotocin    0.0  0.000000  5.306341  0.019228  1.763042  2.099860
# BTS-54505         0.0  0.000000  0.000000  3.008378  0.000000  2.216108
# bitopertin        0.0  1.828844  0.000000  3.182946  0.000000  2.569113
# torasemide        0.0  0.000000  3.588966  2.865899  0.000000  0.057030
# chlorogenic-acid  0.0  0.928520  1.273102  0.000000  0.000000  0.000000
# tetrandrine       0.0  0.000000  0.000000  4.417787  0.000000  1.684587
# vanoxerine        0.0  0.000000  0.000000  3.356236  0.000000  2.212327
# cariporide        0.0  0.000000  0.000000  0.000000  0.000000  0.000000
#
#                         6         7         8         9   ...        54   55  \
# anguidine         0.000000  2.263573  4.592370  0.000000  ...  0.000000  0.0
# streptozotocin    3.657456  0.000000  1.688770  0.000000  ...  0.000000  0.0
# BTS-54505         2.610644  0.295862  6.608119  0.000000  ...  0.000000  0.0
# bitopertin        0.000000  0.283705  6.777803  0.000000  ...  0.710360  0.0
# torasemide        0.000000  0.000000  6.297584  0.848389  ...  0.000000  0.0
# chlorogenic-acid  1.676323  0.000000  0.000000  0.000000  ...  0.000000  0.0
# tetrandrine       2.983632  0.000000  7.067230  0.000000  ...  0.000000  0.0
# vanoxerine        1.191479  0.000000  7.451711  0.000000  ...  0.000000  0.0
# cariporide        2.755565  0.170080  0.000000  0.000000  ...  8.557508  0.0
#
#                         56        57        58   59      60        61  \
# anguidine         2.096403  0.002313  2.178377  0.0  0.0000  2.443798
# streptozotocin    0.000000  0.000000  0.000000  0.0  0.0000  4.477334
# BTS-54505         1.642903  0.000000  0.254814  0.0  0.0000  1.751037
# bitopertin        6.344385  0.211802  0.000000  0.0  1.0173  0.000000
# torasemide        0.000000  0.000000  3.127850  0.0  0.0000  2.458280
# chlorogenic-acid  3.797884  0.000000  0.000000  0.0  0.0000  5.366400
# tetrandrine       0.041703  0.000000  0.000000  0.0  0.0000  1.309418
# vanoxerine        1.774545  0.000000  0.000000  0.0  0.0000  1.769114
# cariporide        1.517143  0.000000  1.177204  0.0  0.0000  3.054856
#
#                         62        63
# anguidine         0.000000  0.000000
# streptozotocin    0.000000  2.083950
# BTS-54505         0.000000  0.715751
# bitopertin        4.958534  2.209433
# torasemide        0.000000  2.456618
# chlorogenic-acid  0.000000  0.000000
# tetrandrine       0.000000  0.000000
# vanoxerine        0.000000  0.000000
# cariporide        6.731888  0.000000
#
# [9 rows x 64 columns]

# %%
tsneSub = t[t.index.isin(slcDrugs)]
plt.scatter(x = tsneSub[0], y = tsneSub[1])
plt.show()

# %%
for c in cdrSub2.target:
    print(c)
# Out:
# SLC5A1
# HDAC1, HDAC10, HDAC11, HDAC2, HDAC3, HDAC4, HDAC5, HDAC6, HDAC7, HDAC8, HDAC9
# HDAC1, HDAC2, HDAC3, HDAC4, HDAC5, HDAC6, HDAC7, HDAC8, HDAC9
# HDAC1, HDAC10, HDAC11, HDAC2, HDAC3, HDAC5, HDAC6, HDAC8, HDAC9
# HDAC1, HDAC2, HDAC3, HDAC6
# HDAC1
# HDAC1
# HDAC1, HDAC2, HDAC3, HDAC4, HDAC5, HDAC6, HDAC7, HDAC8, HDAC9
# HDAC1, HDAC2, HDAC3, HDAC4, HDAC5, HDAC6, HDAC7, HDAC8, HDAC9
# HDAC1, HDAC6
# HDAC1, HDAC10, HDAC2, HDAC3, HDAC4, HDAC5, HDAC6, HDAC7, HDAC8, HDAC9
# HDAC1
# HDAC1, HDAC2, HDAC3, HDAC6, HDAC8
# HDAC1, HDAC2, HDAC3, HDAC4, HDAC5, HDAC6, HDAC7, HDAC8, HDAC9
# HDAC1, HDAC2, HDAC3, HDAC4, HDAC6, HDAC7, HDAC8, HDAC9
# HDAC1, HDAC10, HDAC3, HDAC4, HDAC5, HDAC9
# HDAC1, HDAC2, HDAC3, HDAC9
# HDAC1, HDAC10, HDAC11, HDAC2, HDAC3, HDAC4, HDAC5, HDAC6, HDAC7, HDAC8, HDAC9, MDM2
# HDAC1, HDAC11, HDAC2, HDAC3
# HDAC1, HDAC3, HDAC6, HDAC8
# HDAC1
# HDAC3
# HDAC10, HDAC3

# %%
cdr[cdr.name == 'anguidine'].sort_values(by='effectiveCont', ascending=False).head(20)
# Out:
#        DepMap_ID                 cancer_type       name  \
# 9712  ACH-000524              Ovarian Cancer  anguidine
# 9673  ACH-000848                Liver Cancer  anguidine
# 9731  ACH-000048              Ovarian Cancer  anguidine
# 9783  ACH-000796              Ovarian Cancer  anguidine
# 9719  ACH-000164           Pancreatic Cancer  anguidine
# 9840  ACH-000717           Esophageal Cancer  anguidine
# 9761  ACH-000959     Colon/Colorectal Cancer  anguidine
# 9769  ACH-000493                Liver Cancer  anguidine
# 9740  ACH-000375               Kidney Cancer  anguidine
# 9686  ACH-000569                 Lung Cancer  anguidine
# 9729  ACH-000471                Liver Cancer  anguidine
# 9701  ACH-000847              Gastric Cancer  anguidine
# 9709  ACH-000096                    Rhabdoid  anguidine
# 9838  ACH-000123              Ovarian Cancer  anguidine
# 9742  ACH-000965  Endometrial/Uterine Cancer  anguidine
# 9748  ACH-000909  Endometrial/Uterine Cancer  anguidine
# 9670  ACH-000996  Endometrial/Uterine Cancer  anguidine
# 9754  ACH-000885              Ovarian Cancer  anguidine
# 9775  ACH-000750                 Skin Cancer  anguidine
# 9635  ACH-000682        Head and Neck Cancer  anguidine
#
#                               moa  target indication    phase        r2  \
# 9712  protein synthesis inhibitor  SLC5A1        NaN  Phase 2  0.822143
# 9673  protein synthesis inhibitor  SLC5A1        NaN  Phase 2  0.822809
# 9731  protein synthesis inhibitor  SLC5A1        NaN  Phase 2  0.857652
# 9783  protein synthesis inhibitor  SLC5A1        NaN  Phase 2  0.793021
# 9719  protein synthesis inhibitor  SLC5A1        NaN  Phase 2  0.813543
# 9840  protein synthesis inhibitor  SLC5A1        NaN  Phase 2  0.763218
# 9761  protein synthesis inhibitor  SLC5A1        NaN  Phase 2  0.939163
# 9769  protein synthesis inhibitor  SLC5A1        NaN  Phase 2  0.814936
# 9740  protein synthesis inhibitor  SLC5A1        NaN  Phase 2  0.776177
# 9686  protein synthesis inhibitor  SLC5A1        NaN  Phase 2  0.821402
# 9729  protein synthesis inhibitor  SLC5A1        NaN  Phase 2  0.777294
# 9701  protein synthesis inhibitor  SLC5A1        NaN  Phase 2  0.851310
# 9709  protein synthesis inhibitor  SLC5A1        NaN  Phase 2  0.776411
# 9838  protein synthesis inhibitor  SLC5A1        NaN  Phase 2  0.842424
# 9742  protein synthesis inhibitor  SLC5A1        NaN  Phase 2  0.707410
# 9748  protein synthesis inhibitor  SLC5A1        NaN  Phase 2  0.874230
# 9670  protein synthesis inhibitor  SLC5A1        NaN  Phase 2  0.837735
# 9754  protein synthesis inhibitor  SLC5A1        NaN  Phase 2  0.821827
# 9775  protein synthesis inhibitor  SLC5A1        NaN  Phase 2  0.758774
# 9635  protein synthesis inhibitor  SLC5A1        NaN  Phase 2  0.759237
#
#           ic50       auc  lower_limit  effectiveCont  effective
# 9712  0.081065  0.566237     0.000100      11.165144          1
# 9673  0.065958  0.545166     0.000543       9.659062          1
# 9731  0.012841  0.380413     0.006158       8.800618          1
# 9783  0.062976  0.540583     0.001432       8.733297          1
# 9719  0.078043  0.562593     0.001848       8.283641          1
# 9840  0.095583  0.583532     0.002278       7.894202          1
# 9761  0.016139  0.408393     0.016629       7.607162          1
# 9769  0.161572  0.637864     0.002279       7.442492          1
# 9740  0.017997  0.419771     0.017684       7.441047          1
# 9686  0.090119  0.578428     0.004180       7.341905          1
# 9729  0.076996  0.562278     0.004870       7.331510          1
# 9701  0.020535  0.433101     0.017735       7.309393          1
# 9709  0.016652  0.414688     0.021975       7.308940          1
# 9838  0.021424  0.438326     0.019169       7.193092          0
# 9742  0.029590  0.469153     0.015321       7.097135          0
# 9748  0.018836  0.429220     0.024371       7.089139          0
# 9670  0.024188  0.452039     0.019270       7.069736          0
# 9754  0.037883  0.493163     0.012565       7.054315          0
# 9775  0.027539  0.464221     0.018250       6.996672          0
# 9635  0.071138  0.556166     0.008311       6.873746          0
