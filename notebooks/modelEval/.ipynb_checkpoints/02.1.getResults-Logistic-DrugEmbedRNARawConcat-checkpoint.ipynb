# %% [markdown]
# # Load packages

# %%
import os
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
from scripts.evalModel import evalLogisticModels, getPredDist

# %% [markdown]
# # Data

# %% [markdown]
# ## Load cell lines

# %%
trainRNA = pd.read_csv('../../data/processed/RNA_train_cancergenes.csv', index_col=0)
trainCellLines = list(trainRNA.index)

testRNA = pd.read_csv('../../data/processed/RNA_test_cancergenes.csv', index_col=0)
testCellLines = list(testRNA.index)

newRNA = pd.read_csv('../../data/processed/RNA_newcancer_cancergenes.csv', index_col=0)
newCellLines = list(newRNA.index)

# %% [markdown]
# ## CDR

# %%
cdr = pd.read_csv('../../data/processed/drugCellLinePairsData.csv', index_col='DepMap_ID')
trainCDR = cdr.loc[trainCellLines, :].reset_index()
testCDR = cdr.loc[testCellLines, :].reset_index()
newCDR = cdr.loc[newCellLines, :].reset_index()

# %%
testTemp = testCDR.loc[:, ['DepMap_ID', 'cancer_type', 'name', 'effective']].rename(columns={'DepMap_ID':'cell_line',
                                                                                             'name': 'drug',
                                                                                             'effective': 'true'})

newTemp = newCDR.loc[:, ['DepMap_ID', 'cancer_type', 'name', 'effective']].rename(columns={'DepMap_ID':'cell_line',
                                                                                          'name': 'drug',
                                                                                          'effective': 'true'})

# %% [markdown]
# # Load drugs

# %%
drugs = pd.read_csv('../../data/processed/drug_fingerprints.csv', index_col=0)

# %%
trainDrugs = drugs.loc[list(trainCDR.name.values), :].to_numpy()
testDrugs = drugs.loc[list(testCDR.name.values), :].to_numpy()
newDrugs = drugs.loc[list(newCDR.name.values), :].to_numpy()

trainRNA = trainRNA.loc[list(trainCDR.DepMap_ID.values), :].to_numpy()
testRNA = testRNA.loc[list(testCDR.DepMap_ID.values), :].to_numpy()
newRNA = newRNA.loc[list(newCDR.DepMap_ID.values), :].to_numpy()

# %%
trainData = [trainDrugs, trainRNA]
trainEff = trainCDR.effective.to_numpy()
testData = [testDrugs, testRNA]
newData = [newDrugs, newRNA]

# %%
del cdr, drugs, trainDrugs, testDrugs, newDrugs, trainRNA, testRNA, newRNA

# %% [markdown]
# # Model performance

# %%
drugEncoderPath = '/fs/scratch/PCON0041/PatrickLawrence/cancer-drug-response/fewShot/drugs/siameseV1/'
modelDir = os.path.join(drugEncoderPath, 'models')

# %%
thresh = 0.55
bestModel = ''
for m in os.listdir(modelDir):
    evalLog = evalLogisticModels(trainData.copy(), trainEff, testData.copy(), newData.copy(),
                                 fusionPath=None, drugPath=os.path.join(modelDir, m), rnaPath=None)

    if evalLog.drugEncoder == None:
        continue
        
    currentThresh = evalLog.evaluate(testDF=testTemp.copy(), newDF=newTemp.copy(), 
                                    modelName=m, at=1, thresh=thresh, returnThresh=True)
    if currentThresh > thresh:
        thresh = currentThresh
        bestModel = m
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [11], in <cell line: 3>()
#       2 bestModel = ''
#       3 for m in os.listdir(modelDir):
# ----> 4     evalLog = evalLogisticModels(trainData.copy(), trainEff, testData.copy(), newData.copy(),
#       5                                  fusionPath=None, drugPath=os.path.join(modelDir, m), rnaPath=None)
#       7     if evalLog.drugEncoder == None:
#       8         continue
#
# File ~/cancer-drug-response/fs-cdr/notebooks/modelEval/scripts/evalModel.py:250, in evalLogisticModels.__init__(self, train, trainEff, test, new, alt, fusionPath, drugPath, rnaPath)
#     247     self.rnaEncoder = None
#     249 self.fusionEncoder = self.getEncoder(fusionPath)
# --> 250 self.train = self.fusionEncoder(train).numpy()
#     251 self.test = self.fusionEncoder(test).numpy()
#     252 if new != None:
#
# File ~/.conda/envs/tf-gpu/lib/python3.8/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.conda/envs/tf-gpu/lib/python3.8/site-packages/keras/engine/base_layer.py:1096, in Layer.__call__(self, *args, **kwargs)
#    1092   inputs = self._maybe_cast_inputs(inputs, input_list)
#    1094 with autocast_variable.enable_auto_cast_variables(
#    1095     self._compute_dtype_object):
# -> 1096   outputs = call_fn(inputs, *args, **kwargs)
#    1098 if self._activity_regularizer:
#    1099   self._handle_activity_regularization(inputs, outputs)
#
# File ~/.conda/envs/tf-gpu/lib/python3.8/site-packages/keras/utils/traceback_utils.py:92, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      90 bound_signature = None
#      91 try:
# ---> 92   return fn(*args, **kwargs)
#      93 except Exception as e:  # pylint: disable=broad-except
#      94   if hasattr(e, '_keras_call_info_injected'):
#      95     # Only inject info for the innermost failing call
#
# File ~/.conda/envs/tf-gpu/lib/python3.8/site-packages/keras/engine/functional.py:451, in Functional.call(self, inputs, training, mask)
#     432 @doc_controls.do_not_doc_inheritable
#     433 def call(self, inputs, training=None, mask=None):
#     434   """Calls the model on new inputs.
#     435
#     436   In this case `call` just reapplies
#    (...)
#     449       a list of tensors if there are more than one outputs.
#     450   """
# --> 451   return self._run_internal_graph(
#     452       inputs, training=training, mask=mask)
#
# File ~/.conda/envs/tf-gpu/lib/python3.8/site-packages/keras/engine/functional.py:571, in Functional._run_internal_graph(self, inputs, training, mask)
#     569 tensor_usage_count = self._tensor_usage_count
#     570 for x, y in zip(self.inputs, inputs):
# --> 571   y = self._conform_to_reference_input(y, ref_input=x)
#     572   x_id = str(id(x))
#     573   tensor_dict[x_id] = [y] * tensor_usage_count[x_id]
#
# File ~/.conda/envs/tf-gpu/lib/python3.8/site-packages/keras/engine/functional.py:671, in Functional._conform_to_reference_input(self, tensor, ref_input)
#     665       logging.warning(
#     666           'Model was constructed with shape {} for input {}, but it was '
#     667           'called on an input with incompatible shape {}.'.format(
#     668               ref_input.shape, ref_input, tensor.shape))
#     670   # Dtype casting.
# --> 671   tensor = tf.cast(tensor, dtype=ref_input.dtype)
#     672 elif tf_utils.is_extension_type(tensor):
#     673   # Dtype casting (If the extension type has a non-variant dtype and
#     674   # supports being cast).  Only cast if necessary (since some extension
#     675   # types may not implement tf.cast).
#     676   tensor_dtype = getattr(tensor, 'dtype', None)
#
# File ~/.conda/envs/tf-gpu/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.conda/envs/tf-gpu/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/.conda/envs/tf-gpu/lib/python3.8/site-packages/tensorflow/python/ops/math_ops.py:1002, in cast(x, dtype, name)
#    1000   x = ops.convert_to_tensor(x, name="x")
#    1001   if x.dtype.base_dtype != base_type:
# -> 1002     x = gen_math_ops.cast(x, base_type, name=name)
#    1003 if x.dtype.is_complex and base_type.is_floating:
#    1004   logging.warn("Casting complex to real discards imaginary part.")
#
# File ~/.conda/envs/tf-gpu/lib/python3.8/site-packages/tensorflow/python/ops/gen_math_ops.py:1997, in cast(x, DstT, Truncate, name)
#    1995 if tld.is_eager:
#    1996   try:
# -> 1997     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    1998       _ctx, "Cast", name, x, "DstT", DstT, "Truncate", Truncate)
#    1999     return _result
#    2000   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
thresh = 0.5
bestModel = ''
for m in os.listdir(modelDir):
    evalLog = evalLogisticModels(trainData.copy(), trainEff, testData.copy(), newData.copy(),
                                 fusionPath=None, drugPath=os.path.join(modelDir, m), rnaPath=None)

    if evalLog.drugEncoder == None:
        continue
        
    currentThresh = evalLog.evaluate(testDF=testTemp.copy(), newDF=newTemp.copy(), 
                                    modelName=m, at=5, thresh=thresh, returnThresh=True)
    if currentThresh > thresh:
        thresh = currentThresh
        bestModel = m
# Out:
# Model: DrugFewShot_Layers2_Hidden64_DO0-1_AFrelu_LR0-01_DR0-99_DS1000
# 	Precision@1: 0.5882
# 	Precision@2: 0.6176
# 	Precision@3: 0.6078
# 	Precision@4: 0.6029
# 	Precision@5: 0.5647
# 	Precision@10: 0.5231

# %%
bestModel1 = 'DrugFewShot_Layers2_Hidden16_DO0-1_AFrelu_LR0-01_DR0-99_DS1000'

# %%
drugPath = os.path.join(modelDir, bestModel1)
evalLog = evalLogisticModels(trainData.copy(), trainEff, testData.copy(), newData.copy(),
                                fusionPath=None, drugPath=drugPath, rnaPath=None)

# %%
testDF, newDF, testWrong, newWrong, testCounts, newCounts = evalLog.evaluate(testDF=testTemp.copy(), 
                                                                             newDF=newTemp.copy(),
                                                                             thresh=0.2,
                                                                             at=1)
# Out:
# Average Cell Line precision @ k on test set
# 	Precision@1: 0.7451
# 	Precision@2: 0.6471
# 	Precision@3: 0.5621
# 	Precision@4: 0.4902
# 	Precision@5: 0.4588
# 	Precision@10: 0.3667
#
# Average Cell Line precision @ k on newcancer set
# 	Precision@1: 0.7385
# 	Precision@2: 0.6615
# 	Precision@3: 0.6
# 	Precision@4: 0.5231
# 	Precision@5: 0.4954
# 	Precision@10: 0.4294
#
#
# Test set:
# No true effective drugs identified in top 3 for ACH-000305 (top drug: YM-155)
# No true effective drugs identified in top 3 for ACH-000329 (top drug: YM-155)
# No true effective drugs identified in top 3 for ACH-000368 (top drug: TAS-103)
# No true effective drugs identified in top 3 for ACH-000510 (top drug: YM-155)
# No true effective drugs identified in top 3 for ACH-000650 (top drug: YM-155)
#
# 	# of cell lines without effective drug among top-3 recs: 5
# 	# of unique drugs among top-3 predictions: 18
#
# New cancer set
# No true effective drugs identified in top 3 for ACH-000171 (top drug: YM-155)
# No true effective drugs identified in top 3 for ACH-000189 (top drug: rubitecan)
# No true effective drugs identified in top 3 for ACH-000209 (top drug: rubitecan)
# No true effective drugs identified in top 3 for ACH-000268 (top drug: rubitecan)
# No true effective drugs identified in top 3 for ACH-000433 (top drug: YM-155)
# No true effective drugs identified in top 3 for ACH-000484 (top drug: YM-155)
# No true effective drugs identified in top 3 for ACH-000516 (top drug: genz-644282)
# No true effective drugs identified in top 3 for ACH-000649 (top drug: YM-155)
# No true effective drugs identified in top 3 for ACH-000976 (top drug: rubitecan)
# No true effective drugs identified in top 3 for ACH-001321 (top drug: genz-644282)
#
# 	# of cell lines without effective drug among top-3 recs: 10
# 	# of unique drugs among top-3 predictions: 21

# %%
testDist = getPredDist(testDF)
# Out:
# Avg varaince of predictions for each drug: 0.0014

# %%
newDist = getPredDist(newDF)
# Out:
# Avg varaince of predictions for each drug: 0.0025

# %%
testCounts
# Out:
#                          1   2   3  total
# YM-155                  38   3   0     41
# rubitecan                4  22   3     29
# genz-644282              3  15  19     37
# bitopertin               3   0   0      3
# camptothecin             2   2   2      6
# TAS-103                  1   2  13     16
# nemorubicin              1   0   0      1
# topotecan                0   2   6      8
# emetine                  0   1   2      3
# echinomycin              0   1   1      2
# 10-hydroxycamptothecin   0   1   1      2
# bruceantin               0   1   0      1
# epothilone-d             0   1   0      1
# exatecan-mesylate        0   1   0      1
# beta-lapachone           0   0   2      2
# VE-822                   0   0   1      1
# brivaracetam             0   0   1      1
# RS-504393                0   0   1      1

# %%
testDF[testDF.cell_line == 'ACH-000305'].head(10)
# Out:
#        cell_line        cancer_type                    drug  true      pred
# 1622  ACH-000305  Esophageal Cancer                  YM-155     0  0.516130
# 1541  ACH-000305  Esophageal Cancer             genz-644282     0  0.394091
# 1707  ACH-000305  Esophageal Cancer                 TAS-103     0  0.388987
# 1676  ACH-000305  Esophageal Cancer  10-hydroxycamptothecin     1  0.374119
# 1557  ACH-000305  Esophageal Cancer                 emetine     0  0.353927
# 1724  ACH-000305  Esophageal Cancer          beta-lapachone     0  0.341567
# 1712  ACH-000305  Esophageal Cancer             nemorubicin     0  0.319647
# 1632  ACH-000305  Esophageal Cancer              bruceantin     0  0.305143
# 1582  ACH-000305  Esophageal Cancer              epirubicin     0  0.284290
# 1614  ACH-000305  Esophageal Cancer               voreloxin     0  0.283325

# %%
testDF[testDF.cell_line == 'ACH-000368'].head(10)
# Out:
#        cell_line   cancer_type          drug  true      pred
# 3391  ACH-000368  Brain Cancer       TAS-103     0  0.517309
# 3404  ACH-000368  Brain Cancer     topotecan     0  0.512401
# 3353  ACH-000368  Brain Cancer       emetine     0  0.479764
# 3393  ACH-000368  Brain Cancer   nemorubicin     1  0.441628
# 3343  ACH-000368  Brain Cancer   doxorubicin     1  0.400725
# 3356  ACH-000368  Brain Cancer  daunorubicin     1  0.384589
# 3390  ACH-000368  Brain Cancer   echinomycin     1  0.377547
# 3345  ACH-000368  Brain Cancer    teniposide     0  0.355464
# 3397  ACH-000368  Brain Cancer  brivaracetam     0  0.348722
# 3368  ACH-000368  Brain Cancer   mitomycin-c     0  0.339354

# %%
newDF[newDF.cell_line == 'ACH-000268']
# Out:
#        cell_line       cancer_type                drug  true      pred
# 9844  ACH-000268  Bile Duct Cancer           rubitecan     0  0.505358
# 9834  ACH-000268  Bile Duct Cancer        epothilone-d     0  0.290892
# 9846  ACH-000268  Bile Duct Cancer           verubulin     0  0.286760
# 9847  ACH-000268  Bile Duct Cancer              VE-822     0  0.221877
# 9833  ACH-000268  Bile Duct Cancer            GDC-0980     0  0.221771
# 9839  ACH-000268  Bile Duct Cancer              BGT226     0  0.221261
# 9838  ACH-000268  Bile Duct Cancer          GSK2126458     0  0.218839
# 9841  ACH-000268  Bile Duct Cancer           LY3023414     1  0.218290
# 9848  ACH-000268  Bile Duct Cancer        panobinostat     0  0.193249
# 9836  ACH-000268  Bile Duct Cancer              SB-939     0  0.191913
# 9835  ACH-000268  Bile Duct Cancer          delanzomib     0  0.173576
# 9840  ACH-000268  Bile Duct Cancer           CGS-15943     0  0.140625
# 9845  ACH-000268  Bile Duct Cancer           PI3K-IN-2     0  0.131945
# 9832  ACH-000268  Bile Duct Cancer        sangivamycin     0  0.125918
# 9850  ACH-000268  Bile Duct Cancer  bardoxolone-methyl     0  0.113504
# 9843  ACH-000268  Bile Duct Cancer           LY2606368     0  0.100716
# 9837  ACH-000268  Bile Duct Cancer           alvocidib     0  0.094550
# 9842  ACH-000268  Bile Duct Cancer         napabucasin     0  0.067763
# 9849  ACH-000268  Bile Duct Cancer           LY2603618     0  0.059413

# %% [markdown]
# ## Cancer precision

# %%
cancerTest, cancerNew = evalLog.getCancerPerformance(testDF.copy(), newDF.copy())

# %%
cancerTest
# Out:
#                                   p1        p2        p3        p4        p5
# Endometrial/Uterine Cancer  1.000000  0.833333  0.777778  0.666667  0.600000
# Bladder Cancer              1.000000  0.833333  0.777778  0.666667  0.533333
# Breast Cancer               1.000000  0.666667  0.444444  0.333333  0.333333
# Liver Cancer                1.000000  0.500000  0.500000  0.500000  0.500000
# Lung Cancer                 0.923077  0.692308  0.615385  0.500000  0.476923
# Ovarian Cancer              0.750000  0.750000  0.666667  0.500000  0.550000
# Esophageal Cancer           0.666667  0.666667  0.555556  0.500000  0.400000
# Skin Cancer                 0.600000  0.600000  0.466667  0.500000  0.400000
# Colon/Colorectal Cancer     0.500000  0.625000  0.666667  0.625000  0.650000
# Pancreatic Cancer           0.500000  0.625000  0.500000  0.437500  0.400000
# Brain Cancer                0.500000  0.375000  0.250000  0.250000  0.300000
# Head and Neck Cancer        0.333333  0.500000  0.444444  0.416667  0.333333

# %%
round(cancerTest.mean(), 4)
# Out:
# p1    0.7311
# p2    0.6389
# p3    0.5554
# p4    0.4913
# p5    0.4564
# dtype: float64

# %%
cancerNew
# Out:
#                           p1        p2        p3        p4        p5
# Rhabdoid            1.000000  0.875000  0.666667  0.687500  0.650000
# Neuroblastoma       1.000000  0.666667  0.666667  0.500000  0.466667
# Gastric Cancer      0.928571  0.785714  0.714286  0.589286  0.585714
# Bone Cancer         0.777778  0.666667  0.629630  0.583333  0.577778
# Thyroid Cancer      0.750000  0.750000  0.750000  0.593750  0.525000
# Sarcoma             0.666667  0.750000  0.611111  0.583333  0.566667
# Kidney Cancer       0.615385  0.500000  0.435897  0.365385  0.338462
# Prostate Cancer     0.500000  0.750000  0.666667  0.500000  0.500000
# Bile Duct Cancer    0.400000  0.300000  0.333333  0.400000  0.320000
# Gallbladder Cancer  0.000000  0.500000  0.333333  0.250000  0.200000

# %%
round(cancerNew.mean(), 4)
# Out:
# p1    0.6638
# p2    0.6544
# p3    0.5808
# p4    0.5053
# p5    0.4730
# dtype: float64

# %% [markdown]
# # Check pred range by drug

# %%
testPredRange = {'drug': [], 'predCount': [], 'predRange': []}

for drug, subdf in testDF.groupby(by='drug'):
    testPredRange['drug'].append(drug)
    testPredRange['predCount'].append(len(subdf))
    minPred = subdf.pred.min()
    maxPred = subdf.pred.max()
    testPredRange['predRange'].append(maxPred-minPred)
    
testPredRange = pd.DataFrame(testPredRange).sort_values(by='predRange', ascending=False)
testPredRange.reset_index(drop=True, inplace=True)
testPredRange[testPredRange.predCount > 1].head(10)
# Out:
#                      drug  predCount  predRange
# 0                  YM-155         41   0.445689
# 1               rubitecan         31   0.421916
# 2             genz-644282         41   0.414715
# 3                 TAS-103         29   0.411773
# 4  10-hydroxycamptothecin         38   0.402858
# 5                 emetine         34   0.389928
# 6               topotecan         32   0.388482
# 7             nemorubicin         32   0.365816
# 8          beta-lapachone         36   0.358876
# 9            camptothecin          6   0.352469

# %%
testPredRange.sort_values(by='predCount', ascending=False).head(10)
# Out:
#              drug  predCount  predRange
# 231     alvocidib         46   0.098036
# 365    bortezomib         44   0.061509
# 573     selinexor         43   0.024193
# 117        FK-866         42   0.162204
# 332   napabucasin         42   0.071022
# 11    echinomycin         41   0.321616
# 71      LY3023414         41   0.214623
# 297    ganetespib         41   0.079222
# 26   epothilone-b         41   0.277473
# 0          YM-155         41   0.445689

# %%
testPredRange[testPredRange.predCount>1].predRange.mean()
# Out:
# 0.09124295879455577

# %%
newPredRange = {'drug': [], 'predCount': [], 'predRange': []}

for drug, subdf in newDF.groupby(by='drug'):
    newPredRange['drug'].append(drug)
    newPredRange['predCount'].append(len(subdf))
    minPred = subdf.pred.min()
    maxPred = subdf.pred.max()
    newPredRange['predRange'].append(maxPred-minPred)
    
newPredRange = pd.DataFrame(newPredRange).sort_values(by='predRange', ascending=False)
newPredRange.reset_index(drop=True, inplace=True)
newPredRange[newPredRange.predCount > 1].head(10)
# Out:
#                      drug  predCount  predRange
# 0                  YM-155         45   0.565515
# 1               rubitecan         49   0.525881
# 2             genz-644282         57   0.518892
# 3                 TAS-103         34   0.487045
# 4               topotecan         45   0.480699
# 5  10-hydroxycamptothecin         48   0.477824
# 6              irinotecan         28   0.476655
# 7             nemorubicin         44   0.469080
# 8          beta-lapachone         39   0.457231
# 9              epirubicin         36   0.439311

# %%
newPredRange.sort_values(by='predCount', ascending=False).head(10)
# Out:
#             drug  predCount  predRange
# 316   ganetespib         60   0.112290
# 12   echinomycin         58   0.421159
# 367   bortezomib         57   0.090874
# 2    genz-644282         57   0.518892
# 56     verubulin         52   0.305564
# 95         XL888         52   0.265461
# 68     LY3023414         51   0.295303
# 234    alvocidib         51   0.142375
# 290   NVP-AUY922         51   0.119909
# 28    paclitaxel         50   0.352208

# %%
newPredRange[newPredRange.predCount>1].predRange.mean()
# Out:
# 0.12425895235275122
