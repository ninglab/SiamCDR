# %% [markdown]
# # Load packages

# %%
import os
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
from scripts.evalModel import evalFullModel, getPredDist

# %% [markdown]
# # Define

# %%
modelPath = '../../models/SiamCDR/DNN/____'
datasets = ['test', 'newcancer']

# %% [markdown]
# # $\mathrm{SiamCDR_{DNN}}$ Performance

# %%
modelEval = evalFullModel(modelPath, modelType='SiamCDR')

# %%
bestModel1 = modelEval.iterateModels(datasets[0], at=1, thresh=0.98)
# Out:
# Model: Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS50_preds.csv
# 	Precision@1: 0.9804
# 	Precision@2: 0.9118
# 	Precision@3: 0.902
# 	Precision@4: 0.8775
# 	Precision@5: 0.8471
# 	Precision@10: 0.8359
#
# Model: Unfused-FewShotCDRRawDrugEmbedCell_NL64_32_DO0-1_AFrelu_LR0-01_DR0-99_DS50_preds.csv
# 	Precision@1: 0.9804
# 	Precision@2: 0.9118
# 	Precision@3: 0.8954
# 	Precision@4: 0.8775
# 	Precision@5: 0.8431
# 	Precision@10: 0.8462
#
# Model: Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_preds.csv
# 	Precision@1: 0.9804
# 	Precision@2: 0.9412
# 	Precision@3: 0.8954
# 	Precision@4: 0.8529
# 	Precision@5: 0.8235
# 	Precision@10: 0.8436
#
# Model: Unfused-FewShotCDRRawDrugEmbedCell_NL64_32_16_DO0-1_AFrelu_LR0-001_DR0-99_DS500_preds.csv
# 	Precision@1: 0.9804
# 	Precision@2: 0.9118
# 	Precision@3: 0.902
# 	Precision@4: 0.8775
# 	Precision@5: 0.8471
# 	Precision@10: 0.8308
#
# Model: Unfused-FewShotCDRRawDrugEmbedCell_NL16_16_DO0-1_AFrelu_LR0-01_DR0-99_DS50_preds.csv
# 	Precision@1: 0.9804
# 	Precision@2: 0.9314
# 	Precision@3: 0.902
# 	Precision@4: 0.8676
# 	Precision@5: 0.8314
# 	Precision@10: 0.8333
#
# Model: Unfused-FewShotCDRRawDrugEmbedCell_NL32_32_32_DO0-1_AFrelu_LR0-01_DR0-99_DS50_preds.csv
# 	Precision@1: 0.9804
# 	Precision@2: 0.9118
# 	Precision@3: 0.902
# 	Precision@4: 0.8873
# 	Precision@5: 0.8314
# 	Precision@10: 0.8308
#
# Model: Unfused-FewShotCDRRawDrugEmbedCell_NL64_32_8_DO0-1_AFrelu_LR0-01_DR0-99_DS50_preds.csv
# 	Precision@1: 0.9804
# 	Precision@2: 0.9118
# 	Precision@3: 0.9085
# 	Precision@4: 0.8873
# 	Precision@5: 0.8392
# 	Precision@10: 0.8282
#
# Model: Unfused-FewShotCDRRawDrugEmbedCell_NL32_32_DO0-1_AFrelu_LR0-01_DR0-99_DS50_preds.csv
# 	Precision@1: 0.9804
# 	Precision@2: 0.9118
# 	Precision@3: 0.8889
# 	Precision@4: 0.8676
# 	Precision@5: 0.8431
# 	Precision@10: 0.8359
#
# Model: Unfused-FewShotCDRRawDrugEmbedCell_NL32_32_DO0-1_AFsigmoid_LR0-01_DR0-99_DS500_preds.csv
# 	Precision@1: 0.9804
# 	Precision@2: 0.9118
# 	Precision@3: 0.8954
# 	Precision@4: 0.8775
# 	Precision@5: 0.8471
# 	Precision@10: 0.8436
#
# Model: Unfused-FewShotCDRRawDrugEmbedCell_NL64_DO0-1_AFsigmoid_LR0-001_DR0-99_DS500_preds.csv
# 	Precision@1: 0.9804
# 	Precision@2: 0.9118
# 	Precision@3: 0.9085
# 	Precision@4: 0.8725
# 	Precision@5: 0.8431
# 	Precision@10: 0.8385
#
# Model: Unfused-FewShotCDRRawDrugEmbedCell_NL64_32_DO0-1_AFrelu_LR0-01_DR0-99_DS500_preds.csv
# 	Precision@1: 0.9804
# 	Precision@2: 0.9118
# 	Precision@3: 0.8954
# 	Precision@4: 0.8775
# 	Precision@5: 0.8431
# 	Precision@10: 0.8333
#
# Model: Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_64_DO0-3_AFrelu_LR0-001_DR0-99_DS500_preds.csv
# 	Precision@1: 0.9804
# 	Precision@2: 0.9118
# 	Precision@3: 0.902
# 	Precision@4: 0.8676
# 	Precision@5: 0.8588
# 	Precision@10: 0.8359
#
# Best model with repsect to precision@1:
# Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS50 (0.9804)

# %%
bestModel5 = modelEval.iterateModels(datasets[0], at=5, thresh=0.85)
# Out:
# Model: Unfused-FewShotCDRRawDrugEmbedCell_NL16_16_16_DO0-1_AFrelu_LR0-001_DR0-99_DS500_preds.csv
# 	Precision@1: 0.9216
# 	Precision@2: 0.902
# 	Precision@3: 0.8889
# 	Precision@4: 0.8676
# 	Precision@5: 0.851
# 	Precision@10: 0.841
#
# Model: Unfused-FewShotCDRRawDrugEmbedCell_NL32_16_8_DO0-1_AFrelu_LR0-001_DR0-99_DS500_preds.csv
# 	Precision@1: 0.9216
# 	Precision@2: 0.9118
# 	Precision@3: 0.8824
# 	Precision@4: 0.8627
# 	Precision@5: 0.8549
# 	Precision@10: 0.841
#
# Model: Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS50_preds.csv
# 	Precision@1: 0.9608
# 	Precision@2: 0.902
# 	Precision@3: 0.8693
# 	Precision@4: 0.8627
# 	Precision@5: 0.8588
# 	Precision@10: 0.8282
#
# Model: Unfused-FewShotCDRRawDrugEmbedCell_NL32_DO0-3_AFrelu_LR0-01_DR0-99_DS50_preds.csv
# 	Precision@1: 0.902
# 	Precision@2: 0.8627
# 	Precision@3: 0.8824
# 	Precision@4: 0.8725
# 	Precision@5: 0.8627
# 	Precision@10: 0.8333
#
# Best model with repsect to precision@5:
# Unfused-FewShotCDRRawDrugEmbedCell_NL32_DO0-3_AFrelu_LR0-01_DR0-99_DS50 (0.8627)

# %%
print(f"Best model same @ k=1 and k=5: {bestModel1==bestModel5}")
# Out:
# Best model same @ k=1 and k=5: False

# %%
model = 'Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500'

# %% [markdown]
# ## Eval best on test set

# %%
testPreds, testWrong, testCounts = modelEval.iterateModels(datasets[0], modelName=bestModel)
# Out:
# Average Cell Line precision @ k
# Model: Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500
# 	Precision@1: 0.9804
# 	Precision@2: 0.9412
# 	Precision@3: 0.8954
# 	Precision@4: 0.8529
# 	Precision@5: 0.8235
# 	Precision@10: 0.8436
#
# Top ranked drug for each cell line:
#
# # cell lines without highly effective drug among top-3 predictions: 0
#
# # of unique drugs among top-3 predictions: 14

# %%
testDist = getPredDist(testPreds)
# Out:
# Avg varaince of predictions for each drug: 0.0

# %%
testDist.head(10)
# Out:
#            drug  predCount  predRange       avg      variance
# 0     alvocidib         46   0.000258  0.005327  1.411161e-09
# 1    bortezomib         44   0.001238  0.201913  4.515943e-08
# 2     selinexor         43   0.000632  0.021062  8.805842e-09
# 3   napabucasin         42   0.000015  0.000252  5.036178e-12
# 4        FK-866         42   0.000976  0.062940  1.981761e-08
# 5     LY3023414         41   0.000311  0.024119  3.085067e-09
# 6  epothilone-b         41   0.002615  0.803302  2.127116e-07
# 7    ganetespib         41   0.000285  0.009294  1.914690e-09
# 8        YM-155         41   0.001703  0.784905  7.809360e-08
# 9   genz-644282         41   0.000064  0.790760  1.071531e-10

# %%
testCounts
# Out:
#                           1   2   3  total
# dolastatin-10            30   5   0     35
# romidepsin                6  17   8     31
# maytansinol-isobutyrate   6   0   0      6
# triptolide                4   8   1     13
# 10-hydroxycamptothecin    2  12  16     30
# alvespimycin              2   3  13     18
# YM-155                    1   1   1      3
# sangivamycin              1   0   0      1
# epothilone-b              0   3   5      8
# genz-644282               0   1   4      5
# echinomycin               0   1   1      2
# nemorubicin               0   1   0      1
# BGT226                    0   0   2      2
# gemcitabine               0   0   1      1

# %%
testCancer = modelEval.iterateModels(datasets[0], modelName=bestModel, by='cancer')
testCancer
# Out:
#                               p1        p2        p3        p4        p5
# Liver Cancer                1.00  1.000000  1.000000  1.000000  0.900000
# Bladder Cancer              1.00  1.000000  1.000000  0.916667  0.933333
# Head and Neck Cancer        1.00  1.000000  1.000000  0.916667  0.866667
# Colon/Colorectal Cancer     1.00  1.000000  1.000000  0.875000  0.900000
# Endometrial/Uterine Cancer  1.00  1.000000  0.888889  0.916667  0.866667
# Skin Cancer                 1.00  1.000000  0.866667  0.800000  0.760000
# Ovarian Cancer              1.00  1.000000  0.833333  0.812500  0.850000
# Lung Cancer                 1.00  0.961538  0.897436  0.846154  0.815385
# Brain Cancer                1.00  0.875000  0.750000  0.750000  0.750000
# Esophageal Cancer           1.00  0.833333  0.888889  0.916667  0.800000
# Breast Cancer               1.00  0.833333  0.888889  0.833333  0.800000
# Pancreatic Cancer           0.75  0.750000  0.833333  0.812500  0.750000

# %%
round(testCancer.mean(), 4)
# Out:
# p1    0.9792
# p2    0.9378
# p3    0.9040
# p4    0.8663
# p5    0.8327
# dtype: float64

# %% [markdown]
# ## Evaluate best model on newcancer set

# %%
newPreds, newWrong, newCounts = modelEval.iterateModels(datasets[1], modelName=bestModel)
newCounts
# Out:
# Average Cell Line precision @ k
# Model: Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500
# 	Precision@1: 0.9846
# 	Precision@2: 0.9231
# 	Precision@3: 0.8872
# 	Precision@4: 0.8615
# 	Precision@5: 0.8338
# 	Precision@10: 0.8314
#
# Top ranked drug for each cell line:
# No true effective drugs identified in top 3 for ACH-000268 (top drug: sangivamycin)
#
# # cell lines without highly effective drug among top-3 predictions: 1
#
# # of unique drugs among top-3 predictions: 14
#                           1   2   3  total
# dolastatin-10            33  13   0     46
# maytansinol-isobutyrate  15   0   0     15
# romidepsin                8  22  16     46
# triptolide                5  10   1     16
# 10-hydroxycamptothecin    4   9  20     33
# genz-644282               1   1   8     10
# sangivamycin              1   0   0      1
# alvespimycin              0   6  12     18
# epothilone-b              0   4   4      8
# YM-155                    0   1   1      2
# BGT226                    0   1   0      1
# echinomycin               0   0   3      3
# gemcitabine               0   0   1      1
# verubulin                 0   0   1      1

# %%
newDist = getPredDist(newPreds)
# Out:
# Avg varaince of predictions for each drug: 0.0

# %%
newCancer = modelEval.iterateModels(datasets[1], modelName=bestModel, by='Cancer')
newCancer
# Out:
#                           p1        p2        p3        p4        p5
# Prostate Cancer     1.000000  1.000000  1.000000  0.875000  0.900000
# Gallbladder Cancer  1.000000  1.000000  1.000000  0.750000  0.600000
# Sarcoma             1.000000  1.000000  0.944444  0.875000  0.866667
# Rhabdoid            1.000000  1.000000  0.916667  0.875000  0.900000
# Thyroid Cancer      1.000000  1.000000  0.916667  0.875000  0.850000
# Neuroblastoma       1.000000  1.000000  0.777778  0.833333  0.866667
# Bone Cancer         1.000000  0.944444  0.851852  0.861111  0.888889
# Gastric Cancer      1.000000  0.928571  0.928571  0.928571  0.885714
# Bile Duct Cancer    1.000000  0.900000  0.933333  0.950000  0.840000
# Kidney Cancer       0.923077  0.769231  0.794872  0.750000  0.692308

# %%
round(newCancer.mean(), 4)
# Out:
# p1    0.9923
# p2    0.9542
# p3    0.9064
# p4    0.8573
# p5    0.8290
# dtype: float64
