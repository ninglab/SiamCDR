# %% [markdown]
# # Import

# %%
import os, joblib
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Input
from tensorflow.keras.models import load_model, Model

# %%
current = os.getcwd()
os.chdir('../modelEval')

# %%
from scripts.evalModel import precision, getPredDist, countDrugsK

# %%
os.chdir('../../../baselines/DeepDSC')

# %%
from deepdsc import DeepDSC

# %%
os.chdir(current)

# %% [markdown]
# # Load Data

# %% [markdown]
# ## RNA

# %%
trainRNA = pd.read_csv('../../data/processed/RNA_train_cancergenes.csv', index_col=0)
valRNA = pd.read_csv('../../data/processed/RNA_val_cancergenes.csv', index_col=0)
testRNA = pd.read_csv('../../data/processed/RNA_test_cancergenes.csv', index_col=0)
newRNA = pd.read_csv('../../data/processed/RNA_newcancer_cancergenes.csv', index_col=0)

# %% [markdown]
# ## Drugs

# %%
drugs = pd.read_csv('../../data/processed/drug_fingerprints.csv', index_col=0)

# %% [markdown]
# ## CDR

# %%
cdr = pd.read_csv('../../data/processed/drugCellLinePairsData.csv')
cdrFilt = cdr.loc[:, ['DepMap_ID', 'cancer_type', 'name', 'ic50', 'auc', 'effectiveCont', 'effective']]
cdrFilt.rename(columns={'DepMap_ID': 'cell_line', 'name': 'drug', 'effective': 'true'}, inplace=True)
cdrFilt.head()
# Out:
#     cell_line        cancer_type         drug      ic50       auc  \
# 0  ACH-000320  Pancreatic Cancer  floxuridine  0.007879  0.336463
# 1  ACH-001145     Ovarian Cancer  floxuridine  0.041552  0.485618
# 2  ACH-000873  Esophageal Cancer  floxuridine  0.097745  0.548483
# 3  ACH-000855  Esophageal Cancer  floxuridine  0.037349  0.631609
# 4  ACH-000488  Esophageal Cancer  floxuridine  0.071628  0.598061
#
#    effectiveCont  true
# 0       6.692422     0
# 1       5.053845     0
# 2       4.697597     0
# 3       4.052632     0
# 4       3.801377     0

# %% [markdown]
# # Process data

# %% [markdown]
# ## Combine RNA

# %%
allRNA = pd.concat([trainRNA, valRNA, testRNA])
allRNA.shape
# Out:
# (352, 463)

# %% [markdown]
# # Make result dfs

# %%
rows = ['fold0', 'fold1', 'fold2', 'fold3', 'fold4']
cols = ['p1', 'p2', 'p3', 'p4', 'p5', 'p10', 'nWrong', 'nUnique', 'variance']

# %%
clTest = pd.DataFrame(index=rows, columns=cols)
clNew = pd.DataFrame(index=rows, columns=cols)

ctTest = pd.DataFrame(index=rows, columns=cols[:5])
ctNew = pd.DataFrame(index=rows, columns=cols[:5])

# %% [markdown]
# # Define

# %% [markdown]
# ## visualization functions

# %%
def minMaxNorm(series):
    return (series - series.min()) / (series.max() - series.min())


def vizImportance(series, drugColor='#377eb8', cellColor='#e41a1c', norm=True):
    # process series / importance data
    if norm:
        series = minMaxNorm(series)
    series = series[series > 0.0].sort_values(ascending=False)
    
    # define bar colors
    colors = []
    for idx in series.index:
        if idx.startswith('drug'):
            colors.append(drugColor)
        else:
            colors.append(cellColor)
    
    # plot feature importance
    plt.figure(figsize=(20, 10))
    bars = plt.bar(series.index, series.values, color=colors)
    
    # plot avg importance by feature type
    avgCellImportance = series[series.index.str.startswith('cell')].mean()
    avgCellLine = plt.axhline(avgCellImportance, color=cellColor,
                linestyle='dashed', linewidth=3, label='Avg relative cell line feature importance')
    
    avgDrugImportance = series[series.index.str.startswith('drug')].mean()
    avgDrugLine = plt.axhline(avgDrugImportance, color=drugColor, 
                linestyle='dashed', linewidth=3, label='Avg relative drug feature importance')

    
    # create legend
    drugLeg = mpatches.Patch(color=drugColor, label='Drug features')
    cellLeg = mpatches.Patch(color=cellColor, label='Cell line features')
    plt.legend(handles=[drugLeg, cellLeg, avgDrugLine, avgCellLine], loc=1, fontsize=20)
    
    # format plot
    plt.xlim([0-0.5,len(series)-0.5])
    plt.xticks([])
    plt.ylim([0.0,1.0])
    plt.yticks([0, 1], fontsize=20)
    plt.show()

# %% [markdown]
# ## AE path

# %%
aePath = '/fs/scratch/PCON0041/PatrickLawrence/cancer-drug-response/autoencoders/RNA-batchcorrect'
aeModel = 'Encoder_Hidden_64_32_AFlkyu_LR1e-05_DR99_DS10_GC1'
aePath = os.path.join(aePath, aeModel)

# %%
AE = load_model(aePath)
AE._trainable = False
print(AE.summary())
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 463)]             0
#
#  Encoder_Hidden1 (Dense)     (None, 64)                29696
#
#  Encoder_Hidden2 (Dense)     (None, 32)                2080
#
#  Latent (Dense)              (None, 32)                1056
#
# =================================================================
# Total params: 32,832
# Trainable params: 0
# Non-trainable params: 32,832
# _________________________________________________________________
# None

# %% [markdown]
# ## Func to init and train model

# %%
basePath = '../../models/baselines/DeepDSC'

# %%
# best model: 
#    'DeepDSC_Encoder_Hidden_64_32_AFlkyu_LR1e-05_DR99_DS10_GC1_DNN_Hidden_128_16_DO3_AFrelu_LR001_DR96_DS5'

initParams = {
    'encoder': aePath,
    'nodes': [128, 16],
    'dropout': 0.3,
    'activation': 'relu',
    'learning_rate': 0.001,
    'decay_rate': 0.96,
    'decay_steps': 5
}

fitParams = {
    'epochs': 1000,
    'batch_size': 512,
    'patience': 2,
    'delta': 0.01
}

# %%
def getDNN(cdr, fold):
    # define model path
    modelName = f'DeepDSC_{fold}'
    modelPath = os.path.join(basePath, modelName)
    
    # init DNN
    np.random.seed(5)
    dnn = DeepDSC(**initParams)
    print(dnn.model.summary())
    
    # take random sample from data for validation
    cellLines = cdr.loc[:, ['cancer_type', 'cell_line']].copy().drop_duplicates(keep='first')

    valCL = list(cellLines.groupby('cancer_type').sample(frac=0.15)['cell_line'])
    valCDR = cdr[cdr.cell_line.isin(valCL)]
    valDrug = tf.convert_to_tensor(drugs.loc[list(valCDR.drug), :], dtype=tf.float32)
    valRNA = tf.convert_to_tensor(allRNA.loc[list(valCDR.cell_line), :], dtype=tf.float32)
    valGT = tf.convert_to_tensor(valCDR.true, dtype=tf.float32)

    trainCDR = cdr[~cdr.cell_line.isin(valCL)]
    trainDrug = tf.convert_to_tensor(drugs.loc[list(trainCDR.drug), :], dtype=tf.float32)
    trainRNA = tf.convert_to_tensor(allRNA.loc[list(trainCDR.cell_line), :], dtype=tf.float32)
    trainGT = tf.convert_to_tensor(trainCDR.true, dtype=tf.float32)
    
    # fit DNN
    history = dnn.fit(trainDrug=trainDrug, trainRNA=AE(trainRNA), trainGT=trainGT,
                      valDrug=valDrug, valRNA=AE(valRNA), valGT=valGT,
                      save=True, out=modelPath, **fitParams)
    
    # attach AE to DNN
    print("\n[INFO] saving model with autoencoder...")
    rawDrug = Input((256,))
    rawRNA = Input((463,))
    embedRNA = AE(rawRNA)
    output = dnn.model([embedRNA, rawDrug])
    model = Model(inputs=[rawRNA, rawDrug], outputs=output)
    print(model.summary())
    
    # resave complete model
    model.save(modelPath)
    
    return dnn

# %% [markdown]
# # 5-fold CV

# %% [markdown]
# ## encoder newcancer data

# %%
newCDR = cdrFilt[cdrFilt.cell_line.isin(newRNA.index)]

newData = [tf.convert_to_tensor(drugs.loc[list(newCDR.drug), :], dtype=tf.float32), 
            tf.convert_to_tensor(newRNA.loc[list(newCDR.cell_line), :], dtype=tf.float32)]

# %% [markdown]
# ## Load folds

# %%
foldDF = pd.read_csv('../../data/processed/cellLinesForCV.csv')
foldDF.head()
# Out:
#         fold0       fold1       fold2       fold3       fold4
# 0  ACH-000026  ACH-000011  ACH-000973  ACH-000802  ACH-000434
# 1  ACH-000593  ACH-000905  ACH-000384  ACH-000018  ACH-000841
# 2  ACH-000396  ACH-000720  ACH-000896  ACH-000839  ACH-000738
# 3  ACH-000486  ACH-000834  ACH-000566  ACH-000142  ACH-000178
# 4  ACH-000609  ACH-000776  ACH-000323  ACH-000289  ACH-000791

# %% [markdown]
# ## run

# %%
models = {}
np.random.seed(0)
for f in foldDF.columns:
    print(f)
    # get cell lines to use in test fold
    testCellLines = list(foldDF[f])
    trainCellLines = list(foldDF.drop(f, axis=1).to_numpy().reshape(-1))
    
    # split data into test and train sets
    testCDR = cdrFilt[cdrFilt.cell_line.isin(testCellLines)].copy()
    trainCDR = cdrFilt[cdrFilt.cell_line.isin(trainCellLines)].copy()
    
    # get trained model
    dnn = getDNN(trainCDR, f)
    
    # get raw RNA + Drug test data
    testData = [tf.convert_to_tensor(drugs.loc[list(testCDR.drug), :], dtype=tf.float32), 
                tf.convert_to_tensor(allRNA.loc[list(testCDR.cell_line), :], dtype=tf.float32)]
    
    # Test results (cell line)
    testCDR['pred'] = dnn.predict(testData)
    testCDR.sort_values(by='pred', ascending=False, inplace=True)
    testCount, testWrong = countDrugsK(testCDR)
    clTest.loc[f, :] = precision(testCDR, thresh=0.1, at=1, by='cellLine', getResults=True) +\
                        [len(testWrong), len(testCount), round(testCDR.groupby('drug').pred.var().mean(),4)]
    
    # Test results (cancer)
    ctTest.loc[f, :] = list(precision(testCDR.copy(), thresh=0.1, by='cancer').mean())
    
    # New cancer results
    newPreds = newCDR.copy()
    newPreds['pred'] = dnn.predict(newData)
    newPreds.sort_values(by='pred', ascending=False, inplace=True)
    newCount, newWrong = countDrugsK(newPreds)
    newPrecision = precision(newPreds, thresh=0.1, at=1, by='cellLine', getResults=True)
    clNew.loc[f, :] =  newPrecision +\
                        [len(newWrong), len(newCount), round(newPreds.groupby('drug').pred.var().mean(),4)]
    
    # New cancer results (cancer)
    ctNew.loc[f, :] = list(precision(newPreds.copy(), thresh=0.1, by='cancer').mean())
    
    # Keep model
    models[f] = dnn


# cell line test
clTest.loc['mean', :] = clTest.iloc[:5,:].mean()
clTest.loc['std', :] = clTest.iloc[:5,:].std()
clTest.iloc[:, :6] = clTest.iloc[:, :6].astype(float).round(4)

# cancer test
ctTest.loc['mean', :] = ctTest.iloc[:5,:].mean()
ctTest.loc['std', :] = ctTest.iloc[:5,:].std()
ctTest = ctTest.astype(float).round(4)

# cell line new
clNew.loc['mean', :] = clNew.iloc[:5,:].mean()
clNew.loc['std', :] = clNew.iloc[:5,:].std()
clNew.iloc[:, :6] = clNew.iloc[:, :6].astype(float).round(4)

# cancer new
ctNew.loc['mean', :] = ctNew.iloc[:5,:].mean()
ctNew.loc['std', :] = ctNew.iloc[:5,:].std()
ctNew = ctNew.astype(float).round(4)

# %% [markdown]
# # Results

# %% [markdown]
# ## Test set

# %%
clTest

# %%
ctTest

# %% [markdown]
# ## New cancer set

# %%
clNew

# %%
ctNew

# %% [markdown]
# # Save CV results

# %%
clTest.to_csv('../../data/results/DeepDSC-cellLineTest.csv', index=False)
ctTest.to_csv('../../data/results/DeepDSC-cancerTest.csv', index=False)
clNew.to_csv('../../data/results/DeepDSC-cellLineNew.csv', index=False)
ctNew.to_csv('../../data/results/DeepDSC-cancerNew.csv', index=False)

# %% [markdown]
# # Examine preds

# %%
newPreds[newPreds.cell_line == 'ACH-000268']

# %%
newPreds[newPreds.drug == 'sangivamycin']

# %% [markdown]
# # Load best model

# %%
modelName = f'Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold1'
modelPath = os.path.join(basePath, modelName)
dnn = load_model(modelPath)

# %%
dnn.summary()
# Out:
# Model: "FS-CDR"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_14 (InputLayer)          [(None, 256)]        0           []
#
#  input_15 (InputLayer)          [(None, 463)]        0           []
#
#  pairEncoder (Functional)       (None, 320)          38016       ['input_14[0][0]',
#                                                                   'input_15[0][0]']
#
#  dense_18 (Dense)               (None, 64)           20544       ['pairEncoder[0][0]']
#
#  dropout_12 (Dropout)           (None, 64)           0           ['dense_18[0][0]']
#
#  dense_19 (Dense)               (None, 64)           4160        ['dropout_12[0][0]']
#
#  dropout_13 (Dropout)           (None, 64)           0           ['dense_19[0][0]']
#
#  dense_20 (Dense)               (None, 1)            65          ['dropout_13[0][0]']
#
# ==================================================================================================
# Total params: 62,785
# Trainable params: 24,769
# Non-trainable params: 38,016
# __________________________________________________________________________________________________

# %% [markdown]
# ## Split into encoder and DNN to enable calc of gradient wrt embedding layer

# %% [markdown]
# ### Encoder

# %%
encoder = dnn.get_layer('pairEncoder')

# %% [markdown]
# ### DNN

# %%
subDNN = Sequential()
subDNN.add(Input(shape=(encoder.outputs[0].shape[1])))
for layer in dnn.layers[3:]:
    subDNN.add(layer)

# %%
subDNN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 64)                20544
#
#  dropout_12 (Dropout)        (None, 64)                0
#
#  dense_19 (Dense)            (None, 64)                4160
#
#  dropout_13 (Dropout)        (None, 64)                0
#
#  dense_20 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 24,769
# Trainable params: 24,769
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Get test and training data for best fold

# %%
f = 'fold1'
testCellLines = list(foldDF[f])
trainCellLines = list(foldDF.drop(f, axis=1).to_numpy().reshape(-1))   

# split data into test and train sets
testCDR = cdrFilt[cdrFilt.cell_line.isin(testCellLines)].copy()
trainCDR = cdrFilt[cdrFilt.cell_line.isin(trainCellLines)].copy()

# get raw RNA + Drug data
testData = [tf.convert_to_tensor(drugs.loc[list(testCDR.drug), :], dtype=tf.float32), 
            tf.convert_to_tensor(allRNA.loc[list(testCDR.cell_line), :], dtype=tf.float32)]

trainData = [tf.convert_to_tensor(drugs.loc[list(trainCDR.drug), :], dtype=tf.float32), 
            tf.convert_to_tensor(allRNA.loc[list(trainCDR.cell_line), :], dtype=tf.float32)]

# %% [markdown]
# # Get preds on testset

# %%
testCDR['pred'] = dnn(testData)
testCDR.sort_values(by='pred', ascending=False, inplace=True)

# %%
testCount, testWrong = countDrugsK(testCDR, getPcnt=True)
print(testCount.pcntCorrect.mean())
testCount.sort_values(by='total', ascending=False)
# Out:
# 0.8256202025328756
#                           1   2   3  total  pcntCorrect
# dolastatin-10            28  18   1     47     0.957447
# romidepsin                9  22  12     43     1.000000
# YM-155                    3  13  15     31     0.806452
# triptolide               22   0   0     22     1.000000
# sangivamycin              3   5  14     22     0.636364
# alvespimycin              0   4  10     14     0.642857
# echinomycin               1   3   7     11     0.909091
# maytansinol-isobutyrate   5   2   0      7     1.000000
# epothilone-b              0   1   3      4     0.750000
# nemorubicin               0   1   2      3     0.333333
# OTS167                    0   0   2      2     1.000000
# genz-644282               0   1   1      2     1.000000
# 10-hydroxycamptothecin    0   0   1      1     1.000000
# BGT226                    0   0   1      1     1.000000
# vincristine               0   0   1      1     0.000000
# gemcitabine               0   1   0      1     1.000000
# SB-743921                 0   0   1      1     1.000000

# %%
len(testCount)
# Out:
# 17

# %%
testCDR.head(15)
# Out:
#         cell_line                 cancer_type                     drug  \
# 34453  ACH-000775                 Lung Cancer  maytansinol-isobutyrate
# 34456  ACH-000023           Pancreatic Cancer  maytansinol-isobutyrate
# 34434  ACH-000961  Endometrial/Uterine Cancer  maytansinol-isobutyrate
# 34439  ACH-000469                Brain Cancer  maytansinol-isobutyrate
# 34420  ACH-000582                 Skin Cancer  maytansinol-isobutyrate
# 34451  ACH-000959     Colon/Colorectal Cancer  maytansinol-isobutyrate
# 34444  ACH-000627                 Lung Cancer  maytansinol-isobutyrate
# 34463  ACH-000967     Colon/Colorectal Cancer  maytansinol-isobutyrate
# 34446  ACH-000027                Brain Cancer  maytansinol-isobutyrate
# 34447  ACH-000671                Liver Cancer  maytansinol-isobutyrate
# 34432  ACH-000018              Bladder Cancer  maytansinol-isobutyrate
# 34421  ACH-000091              Ovarian Cancer  maytansinol-isobutyrate
# 6578   ACH-000563                 Lung Cancer               triptolide
# 37731  ACH-000643               Breast Cancer            dolastatin-10
# 6502   ACH-000961  Endometrial/Uterine Cancer               triptolide
#
#            ic50       auc  effectiveCont  true      pred
# 34453  0.039415  0.448498       8.059934     1  0.977856
# 34456  0.000197  0.094991      15.866964     1  0.977840
# 34434  0.000508  0.101651       9.996686     1  0.975516
# 34439  0.000411  0.062728      10.753055     1  0.975113
# 34420  0.000627  0.046342      10.708053     1  0.974488
# 34451  0.000543  0.085598      10.363954     1  0.974480
# 34444  0.000197  0.049145      11.717008     1  0.974293
# 34463  0.001464  0.177808      11.069494     1  0.974166
# 34446  0.001755  0.289428      10.739382     1  0.974157
# 34447  0.000567  0.247582      12.023957     1  0.974126
# 34432  0.001964  0.254828       7.841925     1  0.973940
# 34421  0.000508  0.110809       9.957549     1  0.973072
# 6578   0.000430  0.028105      11.747239     1  0.967985
# 37731  0.001541  0.211212       8.295262     1  0.966867
# 6502   0.000185  0.073317      12.725848     1  0.966863

# %%
plt.figure(figsize=(20, 15))
plt.scatter(x=testCDR.pred, y=testCDR.effectiveCont)
plt.axhline(7.2734, color='red', linestyle='dashed', linewidth=3.5)
plt.xlim([0,1])
plt.show()

# %%
len(set(testCDR[testCDR.pred >= 0.5].drug))
# Out:
# 26

# %%
len(set(testCDR[(testCDR.pred >= 0.5) & (testCDR.true == 1)].drug))
# Out:
# 24

# %%
testCDR[testCDR.pred > 0.5].true.sum() / len(testCDR[testCDR.pred > 0.5])
# Out:
# 0.7153284671532847

# %%
plt.figure(figsize=(20, 15))
plt.scatter(x=testCDR.pred, y=testCDR.auc)
plt.gca().invert_yaxis()
plt.xlim([0,1])
plt.show()

# %%
plt.figure(figsize=(20, 15))
plt.scatter(x=testCDR.pred, y=np.log2(testCDR.ic50))
plt.axhline(np.log2(0.06), color='red', linestyle='dashed', linewidth=3.5)
plt.gca().invert_yaxis()
plt.xlim([0,1])
plt.show()

# %% [markdown]
# # Calc gradient of DNN wrt the embedding layer

# %% [markdown]
# ## Get embdded data

# %%
trainEmbed = encoder(trainData)

# %% [markdown]
# ## Calc gradient

# %%
with tf.GradientTape() as tape:
    tape.watch(trainEmbed)
    output = subDNN(trainEmbed)
    
result = output
gradients = tape.gradient(output, trainEmbed)

# %% [markdown]
# ## Define feature names

# %%
ftNames = [f"drugFT{i}" for i in range(256)]
ftNames.extend([f"cellFT{i}" for i in range(64)])

# %% [markdown]
# # Plot by avg weight / importance

# %%
avgImportance = pd.DataFrame(gradients).mean()
avgImportance.index = ftNames

# %%
vizImportance(avgImportance)
# Out:
# <ipython-input-50-5c2e99bd4072>:40: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   plt.xticks([])

# %% [markdown]
# # Plot by max weight / importance

# %%
maxImportance = pd.DataFrame(gradients).max()
maxImportance.index = ftNames

# %%
vizImportance(maxImportance)
# Out:
# <ipython-input-50-5c2e99bd4072>:40: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   plt.xticks([])
