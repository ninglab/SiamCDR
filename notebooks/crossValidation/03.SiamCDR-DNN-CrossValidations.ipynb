# %% [markdown]
# # Import

# %%
import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Input
from tensorflow.keras.models import load_model, Model

# %%
current = os.getcwd()
os.chdir('../modelEval')

# %%
from scripts.evalModel import precision, getPredDist, countDrugsK

# %%
os.chdir('../../src/models/')

# %%
from fsCDR import fsCDR

# %%
os.chdir(current)

# %% [markdown]
# # Load Data

# %% [markdown]
# ## RNA

# %%
trainRNA = pd.read_csv('../../data/processed/RNA_train_cancergenes.csv', index_col=0)
valRNA = pd.read_csv('../../data/processed/RNA_val_cancergenes.csv', index_col=0)
testRNA = pd.read_csv('../../data/processed/RNA_test_cancergenes.csv', index_col=0)
newRNA = pd.read_csv('../../data/processed/RNA_newcancer_cancergenes.csv', index_col=0)

# %% [markdown]
# ## Drugs

# %%
drugs = pd.read_csv('../../data/processed/drug_fingerprints.csv', index_col=0)

# %% [markdown]
# ## CDR

# %%
cdr = pd.read_csv('../../data/processed/drugCellLinePairsData.csv')
cdrFilt = cdr.loc[:, ['DepMap_ID', 'cancer_type', 'name', 'ic50', 'auc', 'lower_limit', 'effectiveCont', 'effective']]
cdrFilt.rename(columns={'DepMap_ID': 'cell_line', 'name': 'drug', 'effective': 'true'}, inplace=True)
cdrFilt.head()
# Out:
#     cell_line        cancer_type         drug      ic50       auc  \
# 0  ACH-000320  Pancreatic Cancer  floxuridine  0.007879  0.336463
# 1  ACH-001145     Ovarian Cancer  floxuridine  0.041552  0.485618
# 2  ACH-000873  Esophageal Cancer  floxuridine  0.097745  0.548483
# 3  ACH-000855  Esophageal Cancer  floxuridine  0.037349  0.631609
# 4  ACH-000488  Esophageal Cancer  floxuridine  0.071628  0.598061
#
#    lower_limit  effectiveCont  true
# 0     0.105140       6.692422     0
# 1     0.099077       5.053845     0
# 2     0.060055       4.697597     0
# 3     0.390028       4.052632     0
# 4     0.236216       3.801377     0

# %% [markdown]
# # Process data

# %% [markdown]
# ## Combine RNA

# %%
allRNA = pd.concat([trainRNA, valRNA])
allRNA.shape
# Out:
# (300, 463)

# %% [markdown]
# # Make result dfs

# %%
rows = ['fold0', 'fold1', 'fold2', 'fold3', 'fold4']
cols = ['p1', 'p2', 'p3', 'p4', 'p5', 'p10', 'nWrong', 'nUnique', 'variance']

# %%
clTest = pd.DataFrame(index=rows, columns=cols)
clNew = pd.DataFrame(index=rows, columns=cols)

ctTest = pd.DataFrame(index=rows, columns=cols[:5])
ctNew = pd.DataFrame(index=rows, columns=cols[:5])

# %% [markdown]
# # Define

# %% [markdown]
# ## paths

# %%
drugPath = None

# %%
rnaPath = '../../models/cellEncoders/'
rnaModel = 'CellLineFewShot_Layers2_Hidden64_DO0-1_AFrelu_LR0-001_DR0-99_DS1000'
rnaPath = os.path.join(rnaPath, rnaModel)

# %% [markdown]
# ## Func to init and train model

# %%
basePath = '../../models/SiamCDR/DNN'

# %%
def getDNN(trainCDR, valCDR, fold):
    # define model path
    modelName = f'RawDrug-EmbedCell-DNN_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_CV{fold}'
    modelPath = os.path.join(basePath, modelName)
    
    # init DNN
    np.random.seed(5)
    dnn = fsCDR(cellLineModelPath=rnaPath, 
                drugModelPath='None', 
                fusionModelPath='None',
                nodeList=[64, 64], 
                activation='relu', 
                dropout=0.1)
    
    trainData = (tf.convert_to_tensor(drugs.loc[list(trainCDR.drug), :], dtype=tf.float32), 
                 tf.convert_to_tensor(allRNA.loc[list(trainCDR.cell_line), :], dtype=tf.float32),
                 tf.convert_to_tensor(trainCDR.true, dtype=tf.float32))
    
    valData = (tf.convert_to_tensor(drugs.loc[list(valCDR.drug), :], dtype=tf.float32), 
               tf.convert_to_tensor(allRNA.loc[list(valCDR.cell_line), :], dtype=tf.float32),
               tf.convert_to_tensor(valCDR.true, dtype=tf.float32))
    
    # fit DNN
    history = dnn.fit(train=trainData, 
                      val=valData, 
                      learningRate=0.01, 
                      decayRate=0.99, 
                      decaySteps=500,
                      earlyStopping=True, 
                      patience=10,
                      minDelta=0.001,
                      batchSize=256, 
                      epochs=250, 
                      saveModel=True, 
                      modelPath=modelPath)
    
    return dnn

# %% [markdown]
# # 5-fold CV

# %% [markdown]
# ## encoder newcancer data

# %%
testCDR = cdrFilt[cdrFilt.cell_line.isin(testRNA.index)]

testData = [tf.convert_to_tensor(drugs.loc[list(testCDR.drug), :], dtype=tf.float32), 
            tf.convert_to_tensor(testRNA.loc[list(testCDR.cell_line), :], dtype=tf.float32)]

newCDR = cdrFilt[cdrFilt.cell_line.isin(newRNA.index)]

newData = [tf.convert_to_tensor(drugs.loc[list(newCDR.drug), :], dtype=tf.float32), 
            tf.convert_to_tensor(newRNA.loc[list(newCDR.cell_line), :], dtype=tf.float32)]

# %% [markdown]
# ## Load folds

# %%
foldDF = pd.read_csv('../../data/processed/cellLinesForCV.csv')
foldDF.head()
# Out:
#         fold0       fold1       fold2       fold3       fold4
# 0  ACH-000741  ACH-000026  ACH-000720  ACH-000566  ACH-000890
# 1  ACH-000396  ACH-000753  ACH-000018  ACH-000011  ACH-000845
# 2  ACH-000839  ACH-000973  ACH-000905  ACH-000142  ACH-000875
# 3  ACH-000273  ACH-000231  ACH-000558  ACH-000756  ACH-000869
# 4  ACH-000323  ACH-000137  ACH-000469  ACH-000232  ACH-000572

# %% [markdown]
# ## run

# %%
models = {}
np.random.seed(1738)
for f in foldDF.columns:
    print(f)
    # get cell lines to use in test fold
    testCellLines = list(foldDF[f])
    trainCellLines = list(foldDF.drop(f, axis=1).to_numpy().reshape(-1))
    
    # split data into test and train sets
    trainCDR = cdrFilt[cdrFilt.cell_line.isin(trainCellLines)].copy()
    valCDR = cdrFilt[cdrFilt.cell_line.isin(testCellLines)].copy()
    
    # get trained model
    dnn = getDNN(trainCDR, valCDR, f)
    
    # Test results (cell line)
    testPreds = testCDR.copy()
    testPreds['pred'] = dnn.predict(testData)
    testPreds.sort_values(by='pred', ascending=False, inplace=True)
    testCount, testWrong = countDrugsK(testPreds)
    clTest.loc[f, :] = precision(testPreds, thresh=0.1, at=1, by='cellLine', getResults=True) +\
                        [len(testWrong), len(testCount), round(testPreds.groupby('drug').pred.var().mean(),4)]
    
    # Test results (cancer)
    ctTest.loc[f, :] = list(precision(testPreds.copy(), thresh=0.1, by='cancer').mean())
    
    # New cancer results
    newPreds = newCDR.copy()
    newPreds['pred'] = dnn.predict(newData)
    newPreds.sort_values(by='pred', ascending=False, inplace=True)
    newCount, newWrong = countDrugsK(newPreds)
    newPrecision = precision(newPreds, thresh=0.1, at=1, by='cellLine', getResults=True)
    clNew.loc[f, :] =  newPrecision +\
                        [len(newWrong), len(newCount), round(newPreds.groupby('drug').pred.var().mean(),4)]
    
    # New cancer results (cancer)
    ctNew.loc[f, :] = list(precision(newPreds.copy(), thresh=0.1, by='cancer').mean())
    
    # Keep model
    models[f] = dnn


# cell line test
clTest.loc['mean', :] = clTest.iloc[:5,:].mean()
clTest.loc['std', :] = clTest.iloc[:5,:].std()
clTest.iloc[:, :6] = clTest.iloc[:, :6].astype(float).round(4)

# cancer test
ctTest.loc['mean', :] = ctTest.iloc[:5,:].mean()
ctTest.loc['std', :] = ctTest.iloc[:5,:].std()
ctTest = ctTest.astype(float).round(4)

# cell line new
clNew.loc['mean', :] = clNew.iloc[:5,:].mean()
clNew.loc['std', :] = clNew.iloc[:5,:].std()
clNew.iloc[:, :6] = clNew.iloc[:, :6].astype(float).round(4)

# cancer new
ctNew.loc['mean', :] = ctNew.iloc[:5,:].mean()
ctNew.loc['std', :] = ctNew.iloc[:5,:].std()
ctNew = ctNew.astype(float).round(4)
# Out:
# fold0
# [INFO] loading cell line feature extractor...
# /users/PAS1475/lawrencep487/.conda/envs/tf-gpu/lib/python3.8/site-packages/keras/layers/core/lambda_layer.py:303: UserWarning: siamese is not loaded, but a Lambda layer uses it. It may cause errors.
#   function = cls._parse_function_from_config(config, custom_objects,
# [INFO] drug feature extractor not loaded. Using raw features...
# [INFO] fusion extractor not loaded. Concatenating drug and cell line features...
# [INFO] building CDR model...
# [INFO] compiling model...
# [INFO] training model...
# Epoch 1/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold0/assets
# 142/142 - 3s - loss: 0.2503 - val_loss: 0.2054 - 3s/epoch - 25ms/step
# Epoch 2/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold0/assets
# 142/142 - 3s - loss: 0.2047 - val_loss: 0.1856 - 3s/epoch - 23ms/step
# Epoch 3/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold0/assets
# 142/142 - 3s - loss: 0.1980 - val_loss: 0.1821 - 3s/epoch - 23ms/step
# Epoch 4/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold0/assets
# 142/142 - 4s - loss: 0.1946 - val_loss: 0.1803 - 4s/epoch - 27ms/step
# Epoch 5/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold0/assets
# 142/142 - 4s - loss: 0.1923 - val_loss: 0.1799 - 4s/epoch - 26ms/step
# Epoch 6/250
# 142/142 - 3s - loss: 0.1874 - val_loss: 0.1835 - 3s/epoch - 18ms/step
# Epoch 7/250
# 142/142 - 3s - loss: 0.1890 - val_loss: 0.1804 - 3s/epoch - 21ms/step
# Epoch 8/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold0/assets
# 142/142 - 4s - loss: 0.1875 - val_loss: 0.1767 - 4s/epoch - 26ms/step
# Epoch 9/250
# 142/142 - 2s - loss: 0.1861 - val_loss: 0.1803 - 2s/epoch - 16ms/step
# Epoch 10/250
# 142/142 - 2s - loss: 0.1851 - val_loss: 0.1837 - 2s/epoch - 16ms/step
# Epoch 11/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold0/assets
# 142/142 - 3s - loss: 0.1859 - val_loss: 0.1763 - 3s/epoch - 24ms/step
# Epoch 12/250
# 142/142 - 2s - loss: 0.1846 - val_loss: 0.1822 - 2s/epoch - 16ms/step
# Epoch 13/250
# 142/142 - 2s - loss: 0.1827 - val_loss: 0.1771 - 2s/epoch - 16ms/step
# Epoch 14/250
# 142/142 - 2s - loss: 0.1841 - val_loss: 0.1795 - 2s/epoch - 15ms/step
# Epoch 15/250
# 142/142 - 2s - loss: 0.1826 - val_loss: 0.1812 - 2s/epoch - 15ms/step
# Epoch 16/250
# 142/142 - 2s - loss: 0.1819 - val_loss: 0.1810 - 2s/epoch - 15ms/step
# Epoch 17/250
# 142/142 - 2s - loss: 0.1814 - val_loss: 0.1785 - 2s/epoch - 15ms/step
# Epoch 18/250
# 142/142 - 2s - loss: 0.1814 - val_loss: 0.1799 - 2s/epoch - 15ms/step
# 	Precision@1: 0.9412
# 	Precision@2: 0.9118
# 	Precision@3: 0.8954
# 	Precision@4: 0.8529
# 	Precision@5: 0.8353
# 	Precision@10: 0.8359
#
# No true effective drugs identified in top 3 for ACH-000268 (top drug: sangivamycin)
# 	Precision@1: 0.9692
# 	Precision@2: 0.9308
# 	Precision@3: 0.9026
# 	Precision@4: 0.8808
# 	Precision@5: 0.8585
# 	Precision@10: 0.8275
#
# fold1
# [INFO] loading cell line feature extractor...
# /users/PAS1475/lawrencep487/.conda/envs/tf-gpu/lib/python3.8/site-packages/keras/layers/core/lambda_layer.py:303: UserWarning: siamese is not loaded, but a Lambda layer uses it. It may cause errors.
#   function = cls._parse_function_from_config(config, custom_objects,
# [INFO] drug feature extractor not loaded. Using raw features...
# [INFO] fusion extractor not loaded. Concatenating drug and cell line features...
# [INFO] building CDR model...
# [INFO] compiling model...
# [INFO] training model...
# Epoch 1/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold1/assets
# 146/146 - 4s - loss: 0.2372 - val_loss: 0.1960 - 4s/epoch - 27ms/step
# Epoch 2/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold1/assets
# 146/146 - 3s - loss: 0.1993 - val_loss: 0.1879 - 3s/epoch - 23ms/step
# Epoch 3/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold1/assets
# 146/146 - 3s - loss: 0.1930 - val_loss: 0.1821 - 3s/epoch - 23ms/step
# Epoch 4/250
# 146/146 - 2s - loss: 0.1884 - val_loss: 0.1829 - 2s/epoch - 16ms/step
# Epoch 5/250
# 146/146 - 2s - loss: 0.1880 - val_loss: 0.1824 - 2s/epoch - 15ms/step
# Epoch 6/250
# 146/146 - 2s - loss: 0.1863 - val_loss: 0.1830 - 2s/epoch - 15ms/step
# Epoch 7/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold1/assets
# 146/146 - 3s - loss: 0.1856 - val_loss: 0.1810 - 3s/epoch - 24ms/step
# Epoch 8/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold1/assets
# 146/146 - 4s - loss: 0.1846 - val_loss: 0.1797 - 4s/epoch - 27ms/step
# Epoch 9/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold1/assets
# 146/146 - 3s - loss: 0.1825 - val_loss: 0.1794 - 3s/epoch - 23ms/step
# Epoch 10/250
# 146/146 - 2s - loss: 0.1840 - val_loss: 0.1800 - 2s/epoch - 16ms/step
# Epoch 11/250
# 146/146 - 2s - loss: 0.1824 - val_loss: 0.1835 - 2s/epoch - 16ms/step
# Epoch 12/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold1/assets
# 146/146 - 3s - loss: 0.1823 - val_loss: 0.1789 - 3s/epoch - 23ms/step
# Epoch 13/250
# 146/146 - 2s - loss: 0.1832 - val_loss: 0.1833 - 2s/epoch - 17ms/step
# Epoch 14/250
# 146/146 - 3s - loss: 0.1837 - val_loss: 0.1818 - 3s/epoch - 17ms/step
# Epoch 15/250
# 146/146 - 3s - loss: 0.1826 - val_loss: 0.1809 - 3s/epoch - 17ms/step
# Epoch 16/250
# 146/146 - 2s - loss: 0.1811 - val_loss: 0.1844 - 2s/epoch - 17ms/step
# Epoch 17/250
# 146/146 - 2s - loss: 0.1801 - val_loss: 0.1853 - 2s/epoch - 17ms/step
# Epoch 18/250
# 146/146 - 2s - loss: 0.1800 - val_loss: 0.1824 - 2s/epoch - 17ms/step
# 	Precision@1: 0.9412
# 	Precision@2: 0.9118
# 	Precision@3: 0.8954
# 	Precision@4: 0.8775
# 	Precision@5: 0.8431
# 	Precision@10: 0.8282
#
# No true effective drugs identified in top 3 for ACH-000268 (top drug: BGT226)
# 	Precision@1: 0.9846
# 	Precision@2: 0.9385
# 	Precision@3: 0.9026
# 	Precision@4: 0.8731
# 	Precision@5: 0.8646
# 	Precision@10: 0.8235
#
# fold2
# [INFO] loading cell line feature extractor...
# /users/PAS1475/lawrencep487/.conda/envs/tf-gpu/lib/python3.8/site-packages/keras/layers/core/lambda_layer.py:303: UserWarning: siamese is not loaded, but a Lambda layer uses it. It may cause errors.
#   function = cls._parse_function_from_config(config, custom_objects,
# [INFO] drug feature extractor not loaded. Using raw features...
# [INFO] fusion extractor not loaded. Concatenating drug and cell line features...
# [INFO] building CDR model...
# [INFO] compiling model...
# [INFO] training model...
# Epoch 1/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold2/assets
# 149/149 - 4s - loss: 0.2413 - val_loss: 0.2002 - 4s/epoch - 24ms/step
# Epoch 2/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold2/assets
# 149/149 - 4s - loss: 0.1997 - val_loss: 0.1921 - 4s/epoch - 25ms/step
# Epoch 3/250
# 149/149 - 3s - loss: 0.1958 - val_loss: 0.2059 - 3s/epoch - 17ms/step
# Epoch 4/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold2/assets
# 149/149 - 4s - loss: 0.1973 - val_loss: 0.1903 - 4s/epoch - 26ms/step
# Epoch 5/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold2/assets
# 149/149 - 4s - loss: 0.1906 - val_loss: 0.1873 - 4s/epoch - 25ms/step
# Epoch 6/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold2/assets
# 149/149 - 4s - loss: 0.1901 - val_loss: 0.1861 - 4s/epoch - 25ms/step
# Epoch 7/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold2/assets
# 149/149 - 4s - loss: 0.1872 - val_loss: 0.1860 - 4s/epoch - 28ms/step
# Epoch 8/250
# 149/149 - 3s - loss: 0.1840 - val_loss: 0.1865 - 3s/epoch - 18ms/step
# Epoch 9/250
# 149/149 - 3s - loss: 0.1858 - val_loss: 0.1911 - 3s/epoch - 20ms/step
# Epoch 10/250
# 149/149 - 3s - loss: 0.1859 - val_loss: 0.1912 - 3s/epoch - 19ms/step
# Epoch 11/250
# 149/149 - 2s - loss: 0.1942 - val_loss: 0.1873 - 2s/epoch - 17ms/step
# Epoch 12/250
# 149/149 - 2s - loss: 0.1901 - val_loss: 0.1873 - 2s/epoch - 16ms/step
# Epoch 13/250
# 149/149 - 2s - loss: 0.1890 - val_loss: 0.1874 - 2s/epoch - 16ms/step
# Epoch 14/250
# 149/149 - 3s - loss: 0.1882 - val_loss: 0.1902 - 3s/epoch - 18ms/step
# Epoch 15/250
# 149/149 - 2s - loss: 0.1872 - val_loss: 0.1900 - 2s/epoch - 15ms/step
# Epoch 16/250
# 149/149 - 2s - loss: 0.1850 - val_loss: 0.1871 - 2s/epoch - 15ms/step
# 	Precision@1: 0.9412
# 	Precision@2: 0.902
# 	Precision@3: 0.8758
# 	Precision@4: 0.848
# 	Precision@5: 0.8314
# 	Precision@10: 0.8462
#
# No true effective drugs identified in top 3 for ACH-000268 (top drug: sangivamycin)
# 	Precision@1: 0.9692
# 	Precision@2: 0.9385
# 	Precision@3: 0.9026
# 	Precision@4: 0.8731
# 	Precision@5: 0.8462
# 	Precision@10: 0.8196
#
# fold3
# [INFO] loading cell line feature extractor...
# /users/PAS1475/lawrencep487/.conda/envs/tf-gpu/lib/python3.8/site-packages/keras/layers/core/lambda_layer.py:303: UserWarning: siamese is not loaded, but a Lambda layer uses it. It may cause errors.
#   function = cls._parse_function_from_config(config, custom_objects,
# [INFO] drug feature extractor not loaded. Using raw features...
# [INFO] fusion extractor not loaded. Concatenating drug and cell line features...
# [INFO] building CDR model...
# [INFO] compiling model...
# [INFO] training model...
# Epoch 1/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold3/assets
# 148/148 - 4s - loss: 0.2428 - val_loss: 0.2015 - 4s/epoch - 27ms/step
# Epoch 2/250
# 148/148 - 3s - loss: 0.1980 - val_loss: 0.2017 - 3s/epoch - 18ms/step
# Epoch 3/250
# 148/148 - 3s - loss: 0.1925 - val_loss: 0.2044 - 3s/epoch - 18ms/step
# Epoch 4/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold3/assets
# 148/148 - 4s - loss: 0.1876 - val_loss: 0.1952 - 4s/epoch - 26ms/step
# Epoch 5/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold3/assets
# 148/148 - 4s - loss: 0.1874 - val_loss: 0.1901 - 4s/epoch - 29ms/step
# Epoch 6/250
# 148/148 - 3s - loss: 0.1846 - val_loss: 0.1952 - 3s/epoch - 20ms/step
# Epoch 7/250
# 148/148 - 3s - loss: 0.1824 - val_loss: 0.1903 - 3s/epoch - 20ms/step
# Epoch 8/250
# 148/148 - 3s - loss: 0.1813 - val_loss: 0.1929 - 3s/epoch - 22ms/step
# Epoch 9/250
# 148/148 - 5s - loss: 0.1807 - val_loss: 0.1911 - 5s/epoch - 37ms/step
# Epoch 10/250
# 148/148 - 3s - loss: 0.1810 - val_loss: 0.1905 - 3s/epoch - 20ms/step
# Epoch 11/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold3/assets
# 148/148 - 7s - loss: 0.1794 - val_loss: 0.1901 - 7s/epoch - 45ms/step
# Epoch 12/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold3/assets
# 148/148 - 5s - loss: 0.1799 - val_loss: 0.1880 - 5s/epoch - 33ms/step
# Epoch 13/250
# 148/148 - 5s - loss: 0.1777 - val_loss: 0.1884 - 5s/epoch - 31ms/step
# Epoch 14/250
# 148/148 - 4s - loss: 0.1771 - val_loss: 0.1912 - 4s/epoch - 28ms/step
# Epoch 15/250
# 148/148 - 5s - loss: 0.1779 - val_loss: 0.1949 - 5s/epoch - 32ms/step
# Epoch 16/250
# 148/148 - 4s - loss: 0.1794 - val_loss: 0.1901 - 4s/epoch - 30ms/step
# Epoch 17/250
# 148/148 - 3s - loss: 0.1781 - val_loss: 0.1901 - 3s/epoch - 18ms/step
# Epoch 18/250
# 148/148 - 3s - loss: 0.1782 - val_loss: 0.1900 - 3s/epoch - 19ms/step
# Epoch 19/250
# 148/148 - 2s - loss: 0.1777 - val_loss: 0.1887 - 2s/epoch - 16ms/step
# Epoch 20/250
# 148/148 - 3s - loss: 0.1771 - val_loss: 0.1903 - 3s/epoch - 17ms/step
# Epoch 21/250
# 148/148 - 3s - loss: 0.1764 - val_loss: 0.1896 - 3s/epoch - 18ms/step
# Epoch 22/250
# 148/148 - 2s - loss: 0.1770 - val_loss: 0.1915 - 2s/epoch - 16ms/step
# No true effective drugs identified in top 3 for ACH-000164 (top drug: epothilone-b)
# 	Precision@1: 0.9608
# 	Precision@2: 0.9216
# 	Precision@3: 0.8824
# 	Precision@4: 0.8431
# 	Precision@5: 0.8314
# 	Precision@10: 0.8487
#
# No true effective drugs identified in top 3 for ACH-000250 (top drug: dolastatin-10)
# No true effective drugs identified in top 3 for ACH-000268 (top drug: sangivamycin)
# 	Precision@1: 0.9692
# 	Precision@2: 0.9308
# 	Precision@3: 0.9077
# 	Precision@4: 0.8769
# 	Precision@5: 0.8646
# 	Precision@10: 0.8294
#
# fold4
# [INFO] loading cell line feature extractor...
# /users/PAS1475/lawrencep487/.conda/envs/tf-gpu/lib/python3.8/site-packages/keras/layers/core/lambda_layer.py:303: UserWarning: siamese is not loaded, but a Lambda layer uses it. It may cause errors.
#   function = cls._parse_function_from_config(config, custom_objects,
# [INFO] drug feature extractor not loaded. Using raw features...
# [INFO] fusion extractor not loaded. Concatenating drug and cell line features...
# [INFO] building CDR model...
# [INFO] compiling model...
# [INFO] training model...
# Epoch 1/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold4/assets
# 145/145 - 4s - loss: 0.2429 - val_loss: 0.2066 - 4s/epoch - 25ms/step
# Epoch 2/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold4/assets
# 145/145 - 3s - loss: 0.1968 - val_loss: 0.2008 - 3s/epoch - 24ms/step
# Epoch 3/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold4/assets
# 145/145 - 4s - loss: 0.1917 - val_loss: 0.1981 - 4s/epoch - 26ms/step
# Epoch 4/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold4/assets
# 145/145 - 4s - loss: 0.1875 - val_loss: 0.1950 - 4s/epoch - 25ms/step
# Epoch 5/250
# 145/145 - 3s - loss: 0.1856 - val_loss: 0.1960 - 3s/epoch - 18ms/step
# Epoch 6/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold4/assets
# 145/145 - 4s - loss: 0.1843 - val_loss: 0.1918 - 4s/epoch - 27ms/step
# Epoch 7/250
# 145/145 - 3s - loss: 0.1821 - val_loss: 0.1959 - 3s/epoch - 18ms/step
# Epoch 8/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold4/assets
# 145/145 - 3s - loss: 0.1817 - val_loss: 0.1908 - 3s/epoch - 24ms/step
# Epoch 9/250
# 145/145 - 3s - loss: 0.1811 - val_loss: 0.1997 - 3s/epoch - 17ms/step
# Epoch 10/250
# 145/145 - 3s - loss: 0.1806 - val_loss: 0.1913 - 3s/epoch - 18ms/step
# Epoch 11/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold4/assets
# 145/145 - 3s - loss: 0.1808 - val_loss: 0.1889 - 3s/epoch - 23ms/step
# Epoch 12/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold4/assets
# 145/145 - 4s - loss: 0.1790 - val_loss: 0.1889 - 4s/epoch - 26ms/step
# Epoch 13/250
# 145/145 - 2s - loss: 0.1793 - val_loss: 0.1903 - 2s/epoch - 15ms/step
# Epoch 14/250
# 145/145 - 2s - loss: 0.1790 - val_loss: 0.1934 - 2s/epoch - 14ms/step
# Epoch 15/250
# 145/145 - 2s - loss: 0.1801 - val_loss: 0.1934 - 2s/epoch - 15ms/step
# Epoch 16/250
# 145/145 - 2s - loss: 0.1775 - val_loss: 0.1962 - 2s/epoch - 15ms/step
# Epoch 17/250
# 145/145 - 2s - loss: 0.1777 - val_loss: 0.1902 - 2s/epoch - 14ms/step
# Epoch 18/250
# 145/145 - 2s - loss: 0.1759 - val_loss: 0.1891 - 2s/epoch - 16ms/step
# Epoch 19/250
# 145/145 - 2s - loss: 0.1770 - val_loss: 0.1925 - 2s/epoch - 16ms/step
# Epoch 20/250
# INFO:tensorflow:Assets written to: ../../models/fsCDR/DNN/crossValidation/Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold4/assets
# 145/145 - 3s - loss: 0.1783 - val_loss: 0.1887 - 3s/epoch - 23ms/step
# Epoch 21/250
# 145/145 - 2s - loss: 0.1766 - val_loss: 0.1905 - 2s/epoch - 16ms/step
# 	Precision@1: 0.9608
# 	Precision@2: 0.9216
# 	Precision@3: 0.9216
# 	Precision@4: 0.8775
# 	Precision@5: 0.8353
# 	Precision@10: 0.8436
#
# No true effective drugs identified in top 3 for ACH-000268 (top drug: sangivamycin)
# 	Precision@1: 0.9692
# 	Precision@2: 0.9385
# 	Precision@3: 0.9026
# 	Precision@4: 0.8923
# 	Precision@5: 0.8615
# 	Precision@10: 0.8196

# %% [markdown]
# # Results

# %% [markdown]
# ## Test set

# %%
print("Trained-on cancer test set: cell line-wise precision@k")
clTest
# Out:
#            p1      p2      p3      p4      p5     p10    nWrong  nUnique  \
# fold0  0.9412  0.9118  0.8954  0.8529  0.8353  0.8359         0       15
# fold1  0.9412  0.9118  0.8954  0.8775  0.8431  0.8282         0       14
# fold2  0.9412   0.902  0.8758   0.848  0.8314  0.8462         0       14
# fold3  0.9608  0.9216  0.8824  0.8431  0.8314  0.8487         1       16
# fold4  0.9608  0.9216  0.9216  0.8775  0.8353  0.8436         0       15
# mean    0.949  0.9137  0.8941  0.8598  0.8353  0.8405       0.2     14.8
# std    0.0107  0.0082  0.0175  0.0165  0.0048  0.0084  0.447214  0.83666
#
#        variance
# fold0    0.0001
# fold1       0.0
# fold2       0.0
# fold3       0.0
# fold4       0.0
# mean    0.00002
# std    0.000045

# %%
print("Trained-on cancer test set: cancer-wise precision@k")
ctTest
# Out:
#            p1      p2      p3      p4      p5
# fold0  0.9306  0.9158  0.9051  0.8618  0.8391
# fold1  0.9450  0.9158  0.9051  0.8834  0.8541
# fold2  0.9306  0.9126  0.8752  0.8542  0.8395
# fold3  0.9728  0.9369  0.8877  0.8507  0.8387
# fold4  0.9728  0.9314  0.9327  0.8869  0.8463
# mean   0.9503  0.9225  0.9012  0.8674  0.8436
# std    0.0213  0.0109  0.0216  0.0167  0.0067

# %% [markdown]
# ## New cancer set

# %%
print("Novel cancer test set: cell line-wise precision@k")
clNew
# Out:
#            p1      p2      p3      p4      p5     p10    nWrong nUnique  \
# fold0  0.9692  0.9308  0.9026  0.8808  0.8585  0.8275         1      16
# fold1  0.9846  0.9385  0.9026  0.8731  0.8646  0.8235         1      15
# fold2  0.9692  0.9385  0.9026  0.8731  0.8462  0.8196         1      14
# fold3  0.9692  0.9308  0.9077  0.8769  0.8646  0.8294         2      16
# fold4  0.9692  0.9385  0.9026  0.8923  0.8615  0.8196         1      14
# mean   0.9723  0.9354  0.9036  0.8792  0.8591  0.8239       1.2    15.0
# std    0.0069  0.0042  0.0023   0.008  0.0077  0.0045  0.447214     1.0
#
#        variance
# fold0    0.0001
# fold1       0.0
# fold2    0.0001
# fold3    0.0001
# fold4    0.0001
# mean    0.00008
# std    0.000045

# %%
print("Novel cancer test set: cancer-wise precision@k")
ctNew
# Out:
#            p1      p2      p3      p4      p5
# fold0  0.9723  0.9497  0.9236  0.8801  0.8583
# fold1  0.9923  0.9597  0.9236  0.8690  0.8628
# fold2  0.9756  0.9545  0.9238  0.8886  0.8428
# fold3  0.9846  0.9507  0.9233  0.8791  0.8733
# fold4  0.9723  0.9590  0.9241  0.8918  0.8581
# mean   0.9794  0.9547  0.9237  0.8817  0.8591
# std    0.0088  0.0046  0.0003  0.0090  0.0110

# %% [markdown]
# # Save CV results

# %%
clTest.to_csv('../../data/results/trainedOnCellLine_RawDrug-EmbedCell-DNN.csv', index=False)
ctTest.to_csv('../../data/results/trainedOnCancer_RawDrug-EmbedCell-DNN.csv', index=False)
clNew.to_csv('../../data/results/novelCellLine_RawDrug-EmbedCell-DNN.csv', index=False)
ctNew.to_csv('../../data/results/novelCancer_RawDrug-EmbedCell-DNN.csv', index=False)

# %% [markdown]
# # Examine preds

# %% [markdown]
# # Load model

# %%
modelName = f'Unfused-FewShotCDRRawDrugEmbedCell_NL64_64_DO0-1_AFrelu_LR0-01_DR0-99_DS500_fold1'
modelPath = os.path.join(basePath, modelName)
dnn = load_model(modelPath)

# %%
dnn.summary()
# Out:
# Model: "FS-CDR"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 256)]        0           []
#
#  input_10 (InputLayer)          [(None, 463)]        0           []
#
#  pairEncoder (Functional)       (None, 320)          38016       ['input_9[0][0]',
#                                                                   'input_10[0][0]']
#
#  dense_12 (Dense)               (None, 64)           20544       ['pairEncoder[0][0]']
#
#  dropout_8 (Dropout)            (None, 64)           0           ['dense_12[0][0]']
#
#  dense_13 (Dense)               (None, 64)           4160        ['dropout_8[0][0]']
#
#  dropout_9 (Dropout)            (None, 64)           0           ['dense_13[0][0]']
#
#  dense_14 (Dense)               (None, 1)            65          ['dropout_9[0][0]']
#
# ==================================================================================================
# Total params: 62,785
# Trainable params: 24,769
# Non-trainable params: 38,016
# __________________________________________________________________________________________________

# %% [markdown]
# ## Split into encoder and DNN to enable calc of gradient wrt embedding layer

# %% [markdown]
# ### Encoder

# %%
encoder = dnn.get_layer('pairEncoder')

# %% [markdown]
# ### DNN

# %%
subDNN = Sequential()
subDNN.add(Input(shape=(encoder.outputs[0].shape[1])))
for layer in dnn.layers[3:]:
    subDNN.add(layer)

# %%
subDNN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 64)                20544
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_13 (Dense)            (None, 64)                4160
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  dense_14 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 24,769
# Trainable params: 24,769
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Get test and training data for best fold

# %%
f = 'fold1'
testCellLines = list(foldDF[f])
trainCellLines = list(foldDF.drop(f, axis=1).to_numpy().reshape(-1))   

# split data into test and train sets
testCDR = cdrFilt[cdrFilt.cell_line.isin(testCellLines)].copy()
trainCDR = cdrFilt[cdrFilt.cell_line.isin(trainCellLines)].copy()

# get raw RNA + Drug data
testData = [tf.convert_to_tensor(drugs.loc[list(testCDR.drug), :], dtype=tf.float32), 
            tf.convert_to_tensor(allRNA.loc[list(testCDR.cell_line), :], dtype=tf.float32)]

trainData = [tf.convert_to_tensor(drugs.loc[list(trainCDR.drug), :], dtype=tf.float32), 
            tf.convert_to_tensor(allRNA.loc[list(trainCDR.cell_line), :], dtype=tf.float32)]

# %% [markdown]
# # Get preds on trained-on cancer test set

# %%
testCDR['pred'] = dnn(testData)
testCDR.sort_values(by='pred', ascending=False, inplace=True)
# Out:
# <ipython-input-21-456b75539c94>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testCDR['pred'] = dnn(testData)
# <ipython-input-21-456b75539c94>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testCDR.sort_values(by='pred', ascending=False, inplace=True)

# %%
testCancerResults = precision(testCDR, thresh=0.1, by='cancer')
testCancerResults.loc['Overall', :] = testCancerResults.mean(axis=0)
round(testCancerResults, 4)
# Out:
#                                 p1      p2      p3      p4      p5
# Bladder Cancer              1.0000  1.0000  1.0000  1.0000  0.9333
# Brain Cancer                1.0000  0.8750  0.8333  0.8125  0.7500
# Breast Cancer               1.0000  0.8333  0.8889  0.8333  0.8667
# Colon/Colorectal Cancer     1.0000  1.0000  0.9167  0.9375  0.8500
# Endometrial/Uterine Cancer  1.0000  1.0000  0.8889  0.9167  0.8667
# Esophageal Cancer           1.0000  0.8333  0.8889  0.8333  0.7333
# Head and Neck Cancer        1.0000  1.0000  1.0000  0.9167  0.9333
# Liver Cancer                1.0000  1.0000  1.0000  1.0000  1.0000
# Lung Cancer                 0.9231  0.8462  0.8974  0.8654  0.8769
# Ovarian Cancer              1.0000  1.0000  0.9167  0.9375  0.8000
# Pancreatic Cancer           0.7500  0.7500  0.8333  0.8125  0.7500
# Skin Cancer                 1.0000  1.0000  0.8667  0.8500  0.8000
# Overall                     0.9728  0.9282  0.9109  0.8929  0.8467

# %%
testCount, testWrong = countDrugsK(testCDR, getPcnt=True)
print(testCount.pcntCorrect.mean())
testCount.sort_values(by='total', ascending=False)
# Out:
# 0.4607295975873051
#                           1   2   3  total  pcntCorrect
# dolastatin-10            35   5   0     78     0.487179
# romidepsin                5  22   8     69     0.492754
# 10-hydroxycamptothecin    6   6  24     66     0.454545
# echinomycin               1  14  12     52     0.480769
# triptolide                5   6   1     24     0.500000
# alvespimycin              0   2   6     16     0.500000
# maytansinol-isobutyrate   6   0   0     12     0.500000
# YM-155                    0   0   5      9     0.444444
# exatecan-mesylate         1   4   0      8     0.375000
# epothilone-b              0   0   2      3     0.333333
# nemorubicin               0   0   1      2     0.500000

# %% [markdown]
# # Get preds on novel cancer set

# %%
newCDR['pred'] = dnn(newData)
newCDR.sort_values(by='pred', ascending=False, inplace=True)
# Out:
# <ipython-input-22-85c7742b2baa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newCDR['pred'] = dnn(newData)
# <ipython-input-22-85c7742b2baa>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newCDR.sort_values(by='pred', ascending=False, inplace=True)

# %%
newCancerResults = precision(newCDR, thresh=0.1, by='cancer')
newCancerResults.loc['Overall', :] = newCancerResults.mean(axis=0)
round(newCancerResults, 4)
# Out:
#                         p1      p2      p3      p4      p5
# Bile Duct Cancer    1.0000  0.9000  0.8667  0.8500  0.8800
# Bone Cancer         1.0000  0.9444  0.9259  0.8889  0.9111
# Gallbladder Cancer  1.0000  1.0000  1.0000  0.7500  0.8000
# Gastric Cancer      1.0000  1.0000  0.9524  0.9464  0.9143
# Kidney Cancer       0.9231  0.8077  0.7949  0.7500  0.7231
# Neuroblastoma       1.0000  1.0000  1.0000  0.8333  0.8000
# Prostate Cancer     1.0000  1.0000  1.0000  1.0000  0.9000
# Rhabdoid            1.0000  1.0000  0.9167  0.9375  0.9000
# Sarcoma             0.8333  0.9167  0.9444  0.9167  0.8667
# Thyroid Cancer      1.0000  1.0000  0.9583  0.9375  0.8500
# Overall             0.9756  0.9569  0.9359  0.8810  0.8545

# %%
newCount, newWrong = countDrugsK(newCDR, getPcnt=True)
print(newCount.pcntCorrect.mean())
newCount.sort_values(by='total', ascending=False)
